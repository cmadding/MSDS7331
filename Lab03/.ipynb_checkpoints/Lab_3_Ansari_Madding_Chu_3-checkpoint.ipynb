# %% [markdown]
# # Data Mining 7331 - Fall 2019
# ## Lab 3 - Use collaborative filtering to build a custom recommendation system
#
# * **Allen Ansari**
# * **Chad Madding**
# * **Yongjun (Ian) Chu**

# %% [markdown]
# ### Table of Contents<a id="top"></a>
# * **[Business Understanding](#Business_Understanding)**
#     * **[10 points]** Describe the purpose of the data set you selected (i.e., why was this data collected in the first place?). How will you measure the effectiveness of a good algorithm? Why does your chosen validation method make sense for this specific dataset and the stakeholders needs?
# * **[Data Understanding - Description](#Data_Understanding_Description)**
#     * **[10 points]** Describe the meaning and type of data (scale, values, etc.) for each attribute in the data file. Verify data quality: Are there missing values? Duplicate data? Outliers? Are those mistakes? How do you deal with these problems?
# * **[Data Understanding - Visualization](#Data_Understanding_Visualization)**
#     * **[10 points]** Visualize any important attributes appropriately. Important: Provide an interpretation for any charts or graphs.
# * **[Modeling and Evaluation - Train & Adjust Parameters](#Modeling_and_Evaluation_Train_and_adjust_parameters)**
#     * **[10 points]** Create user-item matrices or item-item matrices using collaborative filtering.
# * **[Modeling and Evaluation - Evaluate & Compare](#Modeling_and_Evaluation_Evaluate_and_Compare)**
#     * **[10 points]** Determine performance of the recommendations using different performance measures and explain what each measure.
# * **[Modeling and Evaluation - Visualize Results](#Modeling_and_Evaluation_Visualize_Results)**
#     * **[10 points]** Use tables/visualization to discuss the found results. Explain each visualization in detail.
# * **[Modeling and Evaluation - Summarize The Ramifications](#Modeling_and_Evaluation_Summarize_The_Ramifications)**
#     * **[20 points]** Describe your results. What findings are the most interesting and why?
# * **[Deployment](#Deployment)**
#     * **[10 points]** Be critical of your performance and tell the reader how you current model might be usable by other parties. Did you achieve your goals? If not, can you reign in the utility of your modeling?
#         - How useful is your model for interested parties (i.e., the companies or organizations that might want to use it)?
#         - How would your deploy your model for interested parties?
#         - What other data should be collected?
#         - How often would the model need to be updated, etc.?
# * **[Exceptional Work](#Exceptional_Work)**
#     * **[10 points]** You have free reign to provide additional analyses or combine analyses.

# %% [markdown]
# <a href="#top">Back to Top</a>
# ### Business Understanding<a id="Business Understanding"></a>
# * Describe the purpose of the data set you selected (i.e., why was this data collected in the first place?). How will you measure the effectiveness of a good algorithm? Why does your chosen validation method make sense for this specific dataset and the stakeholders needs?

# %% [markdown]
# For this project, we use the MovieLens 20M Dataset from Kaggle (see the original reference below).
# These datasets, ﬁrst released in 1998, describe people’s expressed preferences for movies. These preferences or ratings entered by users enable the recommender system at MovieLens web site to provide personalized movie recommendations for users. The MovieLens datasets are heavily downloaded (140,000+ downloads2 in 2014) and referenced in the research literature (7,500+ references to “movielens” in Google Scholar). These datasets promote the incredible growth of personalization and recommendation research, offering substantial value in exploring and validating ideas. Because movie preferences are highly subject to personal tastes, the movie domain is well-suited to testing personalization technology. Additionally, movies are a common interest, making algorithmic output easy to discuss and resulting extensive accessibility of movies as a content domain.
#
# Here we will build an effective recommendation system, by comparing two recommenders based on collaborative filtering: item_similarity recommender and ranking_factorization recommender provided by GraphLab Create. To measure the effectivelness of a recommender, we will first split the whole data into training set and validation set. By training a recommender with train set, we examine how it will perform with the validation set by checking the user_RMSE and movie item_RMSE. A better model would have statistically smaller (with 95% confidence) per user RMSE. In addition, we will also compare the per-user-recall for k-items and per-user-precision for k-items. Statistical comparisons can be completed to find superior performing models based on these values.
#
# The item-based collaborative filtering recommendation systems are right choices for this specific dataset and the stakeholders needs. The main idea is to use information from others' behavior since a user can only rate limited number of movies. The validatoin method we use here makes a lot of sense. By randomly splitting the data into 80% training and 20% testing sets for each user, we test the performance of the recommenders for each user by comparing the movies recommendated and movies actually rated positively. The values on per-user-precision and per-user-recall will tell us how well the models predicted.
#
# * F. Maxwell Harper and Joseph A. Konstan. 2015. The MovieLens Datasets: History and Context. ACM Transactions on Interactive Intelligent Systems (TiiS) 5, 4, Article 19 (December 2015), 19 pages. DOI=http://dx.doi.org/10.1145/2827872

# %% [markdown]
# <a href="#top">Back to Top</a>
# ### Data Understanding - Description<a id="Data_Understanding_Description"></a>
# * Describe the meaning and type of data (scale, values, etc.) for each attribute in the data file. Verify data quality: Are there missing values? Duplicate data? Outliers? Are those mistakes? How do you deal with these problems?
#
# This dataset (ml-20m) describes 5-star rating and free-text tagging activity from [MovieLens](http://movielens.org), a movie recommendation service. It contains 20000263 ratings and 465564 tag applications across 27278 movies. These data were created by 138493 users between January 09, 1995 and March 31, 2015. This dataset was generated on March 31, 2015, and updated on October 17, 2016 to update links.csv and add genome-* files.
#
# Users were selected at random for inclusion. All selected users had rated at least 20 movies. No demographic information is included. Each user is represented by an id, and no other information is provided.
#
# The data are contained in six files, `genome-scores.csv`, `genome-tags.csv`, `links.csv`, `movies.csv`, `ratings.csv` and `tags.csv`. For this projecct, we are only concerned about movies.csv and ratings.csv.
#
# This and other GroupLens data sets are publicly available for download at <http://grouplens.org/datasets/>.

# %%
#load needed libraries
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
from scipy import spatial

#enable inline plotting
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

import re
import os

# %%
#import of data
print(os.listdir("ml-20m"))

#genomescores = pd.read_csv("ml-20m/genome-scores.csv")
#genometags = pd.read_csv("ml-20m/genome-tags.csv")
#links = pd.read_csv("ml-20m/links.csv")
movies = pd.read_csv("ml-20m/movies.csv")
ratings = pd.read_csv("ml-20m/ratings.csv")
#tags = pd.read_csv("ml-20m/tags.csv")
# Out:
# ['.gitignore', 'genome-scores.csv', 'genome-tags.csv', 'graphlabDF.csv', 'links.csv', 'mergedDF.csv', 'movies.csv', 'posters', 'ratings.csv', 'README.txt', 'result.csv', 'result1.csv', 'tags.csv']

# %%
#show the information for each feature in movies dataset
print(movies.head())
print(movies.info())
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27278 entries, 0 to 27277
# Data columns (total 3 columns):
# movieId    27278 non-null int64
# title      27278 non-null object
# genres     27278 non-null object
# dtypes: int64(1), object(2)
# memory usage: 639.4+ KB
# None

# %%
#add the poster file name for each movieId within new column 'poster'
movies['poster']=movies.apply(lambda x:'ml-20m/posters/%s.jpg' %(x['movieId']), axis=1)
#create a 'year' column
movies['year'] = movies['title'].str.extract('.*\((.*)\).*', expand=True)
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres                poster  year
# 0  Adventure|Animation|Children|Comedy|Fantasy  ml-20m/posters/1.jpg  1995
# 1                   Adventure|Children|Fantasy  ml-20m/posters/2.jpg  1995
# 2                               Comedy|Romance  ml-20m/posters/3.jpg  1995
# 3                         Comedy|Drama|Romance  ml-20m/posters/4.jpg  1995
# 4                                       Comedy  ml-20m/posters/5.jpg  1995

# %%
#show the information for each feature in ratings dataset
print(ratings.head())
print(ratings.info())
# Out:
#    userId  movieId  rating   timestamp
# 0       1        2     3.5  1112486027
# 1       1       29     3.5  1112484676
# 2       1       32     3.5  1112484819
# 3       1       47     3.5  1112484727
# 4       1       50     3.5  1112484580
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000263 entries, 0 to 20000262
# Data columns (total 4 columns):
# userId       int64
# movieId      int64
# rating       float64
# timestamp    int64
# dtypes: float64(1), int64(3)
# memory usage: 610.4 MB
# None

# %%
#generate the final source dataset to be used for all the analysis
result = pd.merge(movies,
                 ratings[['userId', 'movieId', 'rating']],
                 on='movieId')
print(result.head())
print(result.info())
# Out:
#    movieId             title                                       genres  \
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 2        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 3        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 4        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
#
#                  poster  year  userId  rating
# 0  ml-20m/posters/1.jpg  1995       3     4.0
# 1  ml-20m/posters/1.jpg  1995       6     5.0
# 2  ml-20m/posters/1.jpg  1995       8     4.0
# 3  ml-20m/posters/1.jpg  1995      10     4.0
# 4  ml-20m/posters/1.jpg  1995      11     4.5
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20000263 entries, 0 to 20000262
# Data columns (total 7 columns):
# movieId    int64
# title      object
# genres     object
# poster     object
# year       object
# userId     int64
# rating     float64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 1.2+ GB
# None

# %% [markdown]
# The source dataset has 20000263 rows and 7 columns (movieId, title, genres, poster, year, userId, rating).

# %%
#Checking for any missing values in "result" dataset

# Total missing values for each feature
result.isnull().sum()
# Out:
# movieId     0
# title       0
# genres      0
# poster      0
# year       86
# userId      0
# rating      0
# dtype: int64

# %% [markdown]
# There are only 86 missing values in column year. Since in the following data analysis, "year" is not used, we will just leave as it is.

# %%
#Are there any duplicate entries in the dataset?

duplicateRowsDF = result[result.duplicated(keep='first')]

print("Duplicate Rows except first occurrence based on all columns are :")
print(duplicateRowsDF)

#print(f"\nThere are {len(duplicateRowsDF)} duplicated entries in the dataset!")
# Out:
# Duplicate Rows except first occurrence based on all columns are :
# Empty DataFrame
# Columns: [movieId, title, genres, poster, year, userId, rating]
# Index: []

# %% [markdown]
# No duplicate rows were found.

# %%
#check for any outliers

#Since rating is the only feature that may have meaningful ourliers, we just make a boxplot of rating.
#boxplot of vaiable rating
plt.style.use('ggplot')
fig1, ax1 = plt.subplots()
ax1.set_title('Rating Distribution Plot')
ax1.boxplot(result['rating'])
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0xa6f3788>],
#  'caps': [<matplotlib.lines.Line2D at 0xa715a48>,
#   <matplotlib.lines.Line2D at 0xa723048>],
#  'fliers': [<matplotlib.lines.Line2D at 0xa723c88>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0xa723608>],
#  'whiskers': [<matplotlib.lines.Line2D at 0xa6f3f88>,
#   <matplotlib.lines.Line2D at 0xa715488>]}

# %% [markdown]
# The data range of "rating" is obviously from 0 to 5. Therefore, there are no outliers in the dataset.

# %%
#generate the final simplified dataset to build a recommendation system
result1= result[["userId", "title", "rating"]]
print(result1.head())
print(result1.info())
# Out:
#    userId             title  rating
# 0       3  Toy Story (1995)     4.0
# 1       6  Toy Story (1995)     5.0
# 2       8  Toy Story (1995)     4.0
# 3      10  Toy Story (1995)     4.0
# 4      11  Toy Story (1995)     4.5
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20000263 entries, 0 to 20000262
# Data columns (total 3 columns):
# userId    int64
# title     object
# rating    float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 610.4+ MB
# None

# %%
#find what movies got the most ratings
result1.groupby('title')['rating'].count().sort_values(ascending=False).head(10)
# Out:
# title
# Pulp Fiction (1994)                          67310
# Forrest Gump (1994)                          66172
# Shawshank Redemption, The (1994)             63366
# Silence of the Lambs, The (1991)             63299
# Jurassic Park (1993)                         59715
# Star Wars: Episode IV - A New Hope (1977)    54502
# Braveheart (1995)                            53769
# Terminator 2: Judgment Day (1991)            52244
# Matrix, The (1999)                           51334
# Schindler's List (1993)                      50054
# Name: rating, dtype: int64

# %%
#Export our data set to use for GraphLab
result1.to_csv(r'ml-20m\result1.csv', index = None, header=True)

# %% [markdown]
# <a href="#top">Back to Top</a>
# ### Data Understanding - Visualization<a id="Data_Understanding_Visualization"></a>
# * Visualize any important attributes appropriately. Important: Provide an interpretation for any charts or graphs.

# %%
#looking at the rating average for each movie
avg_ratings= result1.groupby('title', as_index=False).mean()

avg_ratings.hist(column='rating', figsize=(10,5))
plt.title("Histogram of movie rating averages")
# Out:
# Text(0.5,1,'Histogram of movie rating averages')

# %%
avg_ratings.head()
# Out:
#                                                title        userId    rating
# 0                   "Great Performances" Cats (1998)  66414.658065  2.748387
# 1  #chicagoGirl: The Social Network Takes on a Di...  65392.666667  3.666667
# 2                                 $ (Dollars) (1971)  83316.958333  2.833333
# 3                                    $5 a Day (2008)  57626.461538  2.871795
# 4                                       $9.99 (2008)  73360.909091  3.009091

# %% [markdown]
# It appears that the distribution of movie rating averages is near a normal distribution, centered around at 3.5.

# %%
#looking at the distribution of the ratings
result1.hist(column='rating', figsize=(10,5))
plt.title("Histogram of movie ratings")
# Out:
# Text(0.5,1,'Histogram of movie ratings')

# %% [markdown]
# Based on the plot above, it appears that the movies having a rating close 4 have the most counts, over 5,000,000.

# %%
#looking at the number of ratings per movieid
ratings_movie= result1.groupby('title')['rating'].count().clip(upper=4000)
ratings_movie.hist(figsize=(10,5))
plt.title("Histogram of the number of ratings for each movie")
# Out:
# Text(0.5,1,'Histogram of the number of ratings for each movie')

# %% [markdown]
# The above histogram shows that most of the movies (> 20, 000) have less than 500 ratings.

# %%
#looking at the numbr of ratings per user
ratings_user= result1.groupby('userId')['rating'].count().clip(upper=500)
ratings_user.hist(figsize=(10,5))
plt.title("Histogram of the number of ratings for each user")
# Out:
# Text(0.5,1,'Histogram of the number of ratings for each user')

# %% [markdown]
# The above histogram shows that most of the users rated movies 100 or less times in the dataset.

# %%
#plot the Genres vs average_ratings to show top 10 most popular genres

plt.style.use('ggplot')
# %matplotlib inline

plt.figure(1, figsize=(10,5))
result_grouped = result.groupby(by=['genres'])
average_rating = result_grouped.rating.sum() / result_grouped.rating.count()
new = average_rating.sort_values(ascending=False).head(10)
ax=new.plot(kind='bar', colormap = "plasma") 
plt.ylabel("Averaged rating", fontsize = 14, labelpad = 0)
plt.title("The top 10 rated genres")
# Out:
# Text(0.5,1,'The top 10 rated genres')

# %% [markdown]
# The top 10 rated genres based on averaged ratings are ploted above. It appears that movies that are musical, drama or mystery in the dataset are highly rated.

# %% [markdown]
# <a href="#top">Back to Top</a>
# ### Modeling and Evaluation - Train & Adjust Parameters<a id="Modeling_and_Evaluation_Train_and_adjust_parameters"></a>
# * Create user-item matrices or item-item matrices using collaborative filtering.
#
# We will be using a user-item matrices for our recommendation system. The utility matrices will be sparce due to the fact that every user did not review every movie. So in the data we are more likely to see mostly null values.
#
# We will use matrix factorization to build recommender systems. Specifically, we will use item_similarity and ranking_factorization recommenders from GraphLab Create. First, we would like to find the best parameter setting for each recommender.

# %%
# Import Graphlab and load the data file to build a recommendation system

import graphlab as gl

data = gl.SFrame.read_csv("ml-20m/result1.csv", 
                          column_type_hints={"rating":float})
#model = gl.recommender.create(data, user_id="userId", item_id="movieId", target="rating")
#results = model.recommend(users=None, k=5)
#model.save("my_model")
# Out:
# [INFO] graphlab.cython.cy_server: GraphLab Create v2.1 started. Logging: C:\Users\04616598\AppData\Local\Temp\graphlab_server_1575052404.log.0
# This non-commercial license of GraphLab Create for academic use is assigned to cmadding@smu.edu and will expire on November 18, 2020.
# Finished parsing file C:\Users\04616598\Box Sync\Documents\Data Sciance\msds_7331MachineLearningI\MSDS7331\Lab03\ml-20m\result1.csv
# Parsing completed. Parsed 100 lines in 0.801854 secs.
# Read 1528914 lines. Lines per second: 1.7909e+006
# Finished parsing file C:\Users\04616598\Box Sync\Documents\Data Sciance\msds_7331MachineLearningI\MSDS7331\Lab03\ml-20m\result1.csv
# Parsing completed. Parsed 20000263 lines in 5.83362 secs.

# %%
#generate a train and a test sub-datasets for parameter tuning and performance comparison
train, test = gl.recommender.util.random_split_by_user(data, random_seed = 75205,
                                                    user_id="userId", item_id="title",
                                                    max_num_users=100, item_test_proportion=0.2)

# %% [markdown]
# To reduce the computation time, we only chose 100 users for train/test datasets.

# %%
print(test)
# Out:
# +--------+-------------------------------+--------+
# | userId |             title             | rating |
# +--------+-------------------------------+--------+
# | 29110  |        Toy Story (1995)       |  5.0   |
# | 75676  |        Toy Story (1995)       |  5.0   |
# | 115585 |        Toy Story (1995)       |  4.0   |
# | 118929 |        Toy Story (1995)       |  4.0   |
# | 120813 |        Toy Story (1995)       |  4.0   |
# | 49190  |         Jumanji (1995)        |  3.0   |
# | 63232  |         Jumanji (1995)        |  2.5   |
# | 104017 |    Grumpier Old Men (1995)    |  1.5   |
# | 104017 |    Waiting to Exhale (1995)   |  1.5   |
# | 37402  | Father of the Bride Part I... |  3.0   |
# +--------+-------------------------------+--------+
# [2512 rows x 3 columns]
# Note: Only the head of the SFrame is printed.
# You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.

# %% [markdown]
# #### Find the best parameters for item_similarity recommender

# %% [markdown]
# The graphlab method, "model_paramter_search", doesn't support the item_similarity_recommender currently.
# We havet to manually find the best parameters. There are esentially only two parameters that may need to be optimzed: only_top_k and similarity_type. Since our user_item matrix obtained is sparse, choosing "cosine" is the best choice. Therefore, we only need to optimze the values for only_top_k. Here we are to find which one gives the best validation results among 5 values: 5,10,15,20,25. The default value is 64. However, bigger value will require significantly more conputational power. We feel like that choosing 5 to 25 is a reasonable range.

# %%
#find the best parameter for only_top_k
from IPython.display import display
from IPython.display import Image

gl.canvas.set_target('ipynb')

top_k = [5,10,15,20,25]
item_item = []

for i in range(len(top_k)):
    item_simi = gl.recommender.item_similarity_recommender.create(train, 
                                  user_id="userId", 
                                  item_id="title", 
                                  target="rating",
                                  only_top_k= top_k[i],
                                  similarity_type="cosine")
    
    item_item.append(item_simi)
# Out:
# Recsys training: model = item_similarity
# Preparing data set.
#     Data has 19997751 observations with 138493 users and 26729 items.
#     Data prepared in: 14.1571s
# Training model from provided data.
# Gathering per-item and per-user statistics.
# +--------------------------------+------------+
# | Elapsed Time (Item Statistics) | % Complete |
# +--------------------------------+------------+
# | 5.957ms                        | 0.5        |
# | 248.308ms                      | 100        |
# +--------------------------------+------------+
# Setting up lookup tables.
# Processing data in one pass using dense lookup tables.
# +-------------------------------------+------------------+-----------------+
# | Elapsed Time (Constructing Lookups) | Total % Complete | Items Processed |
# +-------------------------------------+------------------+-----------------+
# | 1.24s                               | 0                | 0               |
# | 2.25s                               | 2.25             | 655             |
# | 3.24s                               | 4.5              | 1262            |
# | 4.24s                               | 7.5              | 2028            |
# | 5.24s                               | 10               | 2677            |
# | 6.24s                               | 12.5             | 3352            |
# | 7.24s                               | 15               | 4040            |
# | 8.24s                               | 17.5             | 4721            |
# | 9.24s                               | 20.5             | 5481            |
# | 10.24s                              | 23.25            | 6262            |
# | 11.24s                              | 26.25            | 7033            |
# | 12.24s                              | 29               | 7754            |
# | 13.24s                              | 31.5             | 8468            |
# | 14.24s                              | 34.25            | 9196            |
# | 15.24s                              | 37               | 9941            |
# | 16.24s                              | 40.25            | 10775           |
# | 17.24s                              | 43.25            | 11560           |
# | 18.24s                              | 46.5             | 12490           |
# | 19.24s                              | 49.25            | 13220           |
# | 20.23s                              | 52.25            | 13994           |
# | 21.24s                              | 55.25            | 14806           |
# | 22.24s                              | 57.75            | 15488           |
# | 23.23s                              | 60.5             | 16206           |
# | 24.24s                              | 63               | 16871           |
# | 25.24s                              | 65.5             | 17552           |
# | 26.23s                              | 68.25            | 18269           |
# | 27.23s                              | 70.5             | 18884           |
# | 28.23s                              | 72.75            | 19470           |
# | 29.24s                              | 75               | 20056           |
# | 30.23s                              | 77.25            | 20648           |
# | 31.23s                              | 79.25            | 21203           |
# | 32.23s                              | 81.5             | 21799           |
# | 33.23s                              | 83.5             | 22351           |
# | 34.23s                              | 85.5             | 22901           |
# | 35.23s                              | 87.5             | 23443           |
# | 36.23s                              | 89.5             | 23971           |
# | 37.23s                              | 91.5             | 24489           |
# | 38.23s                              | 93.5             | 25003           |
# | 39.23s                              | 95.25            | 25505           |
# | 40.23s                              | 97.25            | 25999           |
# | 41.23s                              | 99               | 26515           |
# | 44.17s                              | 100              | 26729           |
# +-------------------------------------+------------------+-----------------+
# Finalizing lookup tables.
# Generating candidate set for working with new users.
# Finished training in 46.032s
# Recsys training: model = item_similarity
# Preparing data set.
#     Data has 19997751 observations with 138493 users and 26729 items.
#     Data prepared in: 14.1462s
# Training model from provided data.
# Gathering per-item and per-user statistics.
# +--------------------------------+------------+
# | Elapsed Time (Item Statistics) | % Complete |
# +--------------------------------+------------+
# | 2.992ms                        | 0.5        |
# | 315.159ms                      | 100        |
# +--------------------------------+------------+
# Setting up lookup tables.
# Processing data in one pass using dense lookup tables.
# +-------------------------------------+------------------+-----------------+
# | Elapsed Time (Constructing Lookups) | Total % Complete | Items Processed |
# +-------------------------------------+------------------+-----------------+
# | 1.19s                               | 0                | 0               |
# | 2.20s                               | 2.25             | 664             |
# | 3.20s                               | 5                | 1397            |
# | 4.20s                               | 7.5              | 2041            |
# | 5.19s                               | 10               | 2681            |
# | 6.19s                               | 12.5             | 3377            |
# | 7.20s                               | 15.25            | 4076            |
# | 8.20s                               | 17.75            | 4806            |
# | 9.20s                               | 21.5             | 5779            |
# | 10.19s                              | 25               | 6738            |
# | 11.19s                              | 28.25            | 7578            |
# | 12.20s                              | 31.5             | 8472            |
# | 13.20s                              | 34.5             | 9262            |
# | 14.20s                              | 37.75            | 10103           |
# | 15.20s                              | 40.75            | 10917           |
# | 16.20s                              | 43.5             | 11658           |
# | 17.19s                              | 46.25            | 12382           |
# | 18.20s                              | 49               | 13117           |
# | 19.19s                              | 51.75            | 13874           |
# | 20.19s                              | 54.5             | 14584           |
# | 21.19s                              | 56.75            | 15233           |
# | 22.19s                              | 59.25            | 15860           |
# | 23.19s                              | 61.5             | 16478           |
# | 24.19s                              | 63.75            | 17085           |
# | 25.19s                              | 66.25            | 17717           |
# | 26.19s                              | 68.25            | 18307           |
# | 27.19s                              | 70.75            | 18912           |
# | 28.19s                              | 72.75            | 19491           |
# | 29.19s                              | 75               | 20072           |
# | 30.19s                              | 77               | 20625           |
# | 31.19s                              | 79.25            | 21244           |
# | 32.19s                              | 81.5             | 21807           |
# | 33.19s                              | 83.5             | 22354           |
# | 34.19s                              | 85.5             | 22906           |
# | 35.19s                              | 87.5             | 23446           |
# | 36.19s                              | 89.75            | 24000           |
# | 37.19s                              | 91.75            | 24527           |
# | 38.19s                              | 93.5             | 25027           |
# | 39.19s                              | 95.5             | 25530           |
# | 40.19s                              | 97.25            | 26025           |
# | 41.19s                              | 99               | 26525           |
# | 44.23s                              | 100              | 26729           |
# +-------------------------------------+------------------+-----------------+
# Finalizing lookup tables.
# Generating candidate set for working with new users.
# Finished training in 45.1154s
# Recsys training: model = item_similarity
# Preparing data set.
#     Data has 19997751 observations with 138493 users and 26729 items.
#     Data prepared in: 14.5591s
# Training model from provided data.
# Gathering per-item and per-user statistics.
# +--------------------------------+------------+
# | Elapsed Time (Item Statistics) | % Complete |
# +--------------------------------+------------+
# | 3.989ms                        | 0.5        |
# | 253.322ms                      | 100        |
# +--------------------------------+------------+
# Setting up lookup tables.
# Processing data in one pass using dense lookup tables.
# +-------------------------------------+------------------+-----------------+
# | Elapsed Time (Constructing Lookups) | Total % Complete | Items Processed |
# +-------------------------------------+------------------+-----------------+
# | 1.12s                               | 0                | 0               |
# | 2.12s                               | 2.5              | 679             |
# | 3.12s                               | 5.25             | 1427            |
# | 4.11s                               | 7.75             | 2090            |
# | 5.12s                               | 10.25            | 2757            |
# | 6.12s                               | 12.75            | 3450            |
# | 7.11s                               | 15.5             | 4150            |
# | 8.12s                               | 18.5             | 4948            |
# | 9.12s                               | 21.5             | 5762            |
# | 10.11s                              | 25.5             | 6854            |
# | 11.12s                              | 28.5             | 7649            |
# | 12.12s                              | 31.25            | 8396            |
# | 13.11s                              | 34.25            | 9164            |
# | 14.11s                              | 37.25            | 9961            |
# | 15.11s                              | 40               | 10729           |
# | 16.11s                              | 43               | 11538           |
# | 17.13s                              | 46               | 12346           |
# | 18.12s                              | 48.75            | 13066           |
# | 19.12s                              | 51.5             | 13766           |
# | 20.11s                              | 54               | 14455           |
# | 21.12s                              | 56.5             | 15160           |
# | 22.11s                              | 59.25            | 15843           |
# | 23.11s                              | 61.75            | 16512           |
# | 24.11s                              | 64.25            | 17208           |
# | 25.11s                              | 66.75            | 17851           |
# | 26.11s                              | 69.25            | 18510           |
# | 27.11s                              | 71.25            | 19097           |
# | 28.12s                              | 73.75            | 19723           |
# | 29.11s                              | 76               | 20320           |
# | 30.11s                              | 78               | 20869           |
# | 31.11s                              | 80               | 21440           |
# | 32.11s                              | 82.25            | 22018           |
# | 33.11s                              | 84.25            | 22570           |
# | 34.11s                              | 86.5             | 23145           |
# | 35.11s                              | 88.5             | 23681           |
# | 36.11s                              | 90.5             | 24203           |
# | 37.11s                              | 92.25            | 24712           |
# | 38.11s                              | 94.25            | 25228           |
# | 39.11s                              | 96               | 25725           |
# | 40.11s                              | 98               | 26242           |
# | 43.70s                              | 100              | 26729           |
# +-------------------------------------+------------------+-----------------+
# Finalizing lookup tables.
# Generating candidate set for working with new users.
# Finished training in 44.4481s
# Recsys training: model = item_similarity
# Preparing data set.
#     Data has 19997751 observations with 138493 users and 26729 items.
#     Data prepared in: 14.2639s
# Training model from provided data.
# Gathering per-item and per-user statistics.
# +--------------------------------+------------+
# | Elapsed Time (Item Statistics) | % Complete |
# +--------------------------------+------------+
# | 2.992ms                        | 0.5        |
# | 269.28ms                       | 100        |
# +--------------------------------+------------+
# Setting up lookup tables.
# Processing data in one pass using dense lookup tables.
# +-------------------------------------+------------------+-----------------+
# | Elapsed Time (Constructing Lookups) | Total % Complete | Items Processed |
# +-------------------------------------+------------------+-----------------+
# | 1.17s                               | 0                | 0               |
# | 2.17s                               | 2.5              | 697             |
# | 3.18s                               | 5.25             | 1437            |
# | 4.17s                               | 7.75             | 2109            |
# | 5.17s                               | 10.25            | 2804            |
# | 6.17s                               | 13               | 3482            |
# | 7.17s                               | 15.5             | 4175            |
# | 8.18s                               | 18.5             | 5005            |
# | 9.17s                               | 22.5             | 6021            |
# | 10.17s                              | 26               | 6957            |
# | 11.19s                              | 28.75            | 7745            |
# | 12.17s                              | 32               | 8563            |
# | 13.17s                              | 35               | 9412            |
# | 14.17s                              | 38.25            | 10245           |
# | 15.17s                              | 41.25            | 11065           |
# | 16.17s                              | 44               | 11790           |
# | 17.18s                              | 46.75            | 12518           |
# | 18.17s                              | 49.5             | 13236           |
# | 19.17s                              | 52.25            | 14000           |
# | 20.17s                              | 54.75            | 14697           |
# | 21.17s                              | 57.25            | 15331           |
# | 22.17s                              | 59.75            | 15983           |
# | 23.17s                              | 62               | 16620           |
# | 24.17s                              | 64.5             | 17245           |
# | 25.17s                              | 66.75            | 17878           |
# | 26.17s                              | 69.25            | 18523           |
# | 27.17s                              | 71.5             | 19120           |
# | 28.17s                              | 73.5             | 19709           |
# | 29.17s                              | 75.75            | 20305           |
# | 30.17s                              | 78               | 20893           |
# | 31.17s                              | 80               | 21442           |
# | 32.16s                              | 82.25            | 21993           |
# | 33.16s                              | 84.25            | 22549           |
# | 34.16s                              | 86.25            | 23113           |
# | 35.16s                              | 88.5             | 23656           |
# | 36.16s                              | 90.25            | 24178           |
# | 37.16s                              | 92.25            | 24698           |
# | 38.16s                              | 94.25            | 25202           |
# | 39.16s                              | 96               | 25708           |
# | 40.16s                              | 98               | 26201           |
# | 41.16s                              | 99.75            | 26717           |
# | 43.95s                              | 100              | 26729           |
# +-------------------------------------+------------------+-----------------+
# Finalizing lookup tables.
# Generating candidate set for working with new users.
# Finished training in 44.7623s
# Recsys training: model = item_similarity
# Preparing data set.
#     Data has 19997751 observations with 138493 users and 26729 items.
#     Data prepared in: 14.3377s
# Training model from provided data.
# Gathering per-item and per-user statistics.
# +--------------------------------+------------+
# | Elapsed Time (Item Statistics) | % Complete |
# +--------------------------------+------------+
# | 3.99ms                         | 0.5        |
# | 283.243ms                      | 100        |
# +--------------------------------+------------+
# Setting up lookup tables.
# Processing data in one pass using dense lookup tables.
# +-------------------------------------+------------------+-----------------+
# | Elapsed Time (Constructing Lookups) | Total % Complete | Items Processed |
# +-------------------------------------+------------------+-----------------+
# | 1.20s                               | 0                | 0               |
# | 2.20s                               | 2.5              | 686             |
# | 3.20s                               | 5.25             | 1428            |
# | 4.20s                               | 7.75             | 2095            |
# | 5.20s                               | 10.25            | 2774            |
# | 6.20s                               | 12.75            | 3470            |
# | 7.20s                               | 15.5             | 4152            |
# | 8.20s                               | 18               | 4871            |
# | 9.20s                               | 21.25            | 5680            |
# | 10.20s                              | 24               | 6421            |
# | 11.20s                              | 26.75            | 7174            |
# | 12.20s                              | 29.5             | 7909            |
# | 13.20s                              | 32.25            | 8639            |
# | 14.20s                              | 35               | 9371            |
# | 15.20s                              | 38.25            | 10224           |
# | 16.20s                              | 40.75            | 10950           |
# | 17.20s                              | 43.75            | 11725           |
# | 18.20s                              | 46.75            | 12522           |
# | 19.20s                              | 50               | 13396           |
# | 20.19s                              | 52.75            | 14147           |
# | 21.19s                              | 56               | 14975           |
# | 22.19s                              | 58.75            | 15709           |
# | 23.19s                              | 61.5             | 16442           |
# | 24.19s                              | 64               | 17137           |
# | 25.20s                              | 66.5             | 17812           |
# | 26.20s                              | 69               | 18468           |
# | 27.19s                              | 71.25            | 19066           |
# | 28.19s                              | 73.25            | 19642           |
# | 29.19s                              | 75.75            | 20258           |
# | 30.19s                              | 77.75            | 20846           |
# | 31.19s                              | 80               | 21392           |
# | 32.19s                              | 82               | 21977           |
# | 33.19s                              | 84.25            | 22544           |
# | 34.19s                              | 86.25            | 23085           |
# | 35.19s                              | 88.25            | 23614           |
# | 36.19s                              | 90.25            | 24148           |
# | 37.19s                              | 92               | 24653           |
# | 38.19s                              | 94               | 25163           |
# | 39.19s                              | 96               | 25666           |
# | 40.19s                              | 97.75            | 26186           |
# | 41.19s                              | 99.75            | 26686           |
# | 44.04s                              | 100              | 26729           |
# +-------------------------------------+------------------+-----------------+
# Finalizing lookup tables.
# Generating candidate set for working with new users.
# Finished training in 44.8092s

# %% [markdown]
# We want to compare which model gives the best perfromance overall. So we decided to use graphlab compare( ) method for comparison.

# %%
comparisonstruct = gl.compare(test,item_item)
# Out:
# PROGRESS: Evaluate model M0
#
# Precision and recall summary statistics by cutoff
# +--------+----------------+-----------------+
# | cutoff | mean_precision |   mean_recall   |
# +--------+----------------+-----------------+
# |   1    |      0.42      | 0.0281205111405 |
# |   2    |      0.38      | 0.0533654490354 |
# |   3    | 0.383333333333 | 0.0792510595951 |
# |   4    |     0.3525     |  0.101588976168 |
# |   5    |      0.34      |  0.116841188211 |
# |   6    |     0.325      |  0.134145298892 |
# |   7    |      0.31      |  0.144162278202 |
# |   8    |    0.29625     |  0.154643488801 |
# |   9    |      0.29      |  0.166621235043 |
# |   10   |     0.284      |  0.178229822645 |
# +--------+----------------+-----------------+
# [10 rows x 3 columns]
#
# PROGRESS: Evaluate model M1
#
# Precision and recall summary statistics by cutoff
# +--------+----------------+-----------------+
# | cutoff | mean_precision |   mean_recall   |
# +--------+----------------+-----------------+
# |   1    |      0.42      | 0.0389659720143 |
# |   2    |      0.4       | 0.0659583162329 |
# |   3    |      0.35      | 0.0816366753228 |
# |   4    |     0.3375     | 0.0963050710629 |
# |   5    |     0.314      |  0.107715423678 |
# |   6    | 0.313333333333 |  0.127512083534 |
# |   7    | 0.301428571429 |  0.137564003763 |
# |   8    |    0.28875     |  0.148548023611 |
# |   9    | 0.277777777778 |  0.156438470107 |
# |   10   |     0.266      |  0.166824964872 |
# +--------+----------------+-----------------+
# [10 rows x 3 columns]
#
# PROGRESS: Evaluate model M2
#
# Precision and recall summary statistics by cutoff
# +--------+----------------+-----------------+
# | cutoff | mean_precision |   mean_recall   |
# +--------+----------------+-----------------+
# |   1    |      0.39      | 0.0254952922607 |
# |   2    |      0.36      | 0.0598132898025 |
# |   3    | 0.326666666667 | 0.0722886065895 |
# |   4    |     0.3075     |  0.085766363305 |
# |   5    |     0.314      |  0.107784322206 |
# |   6    | 0.308333333333 |  0.123517626936 |
# |   7    | 0.294285714286 |  0.133521986575 |
# |   8    |     0.285      |  0.142695358214 |
# |   9    | 0.274444444444 |  0.154285860228 |
# |   10   |     0.269      |  0.164990114619 |
# +--------+----------------+-----------------+
# [10 rows x 3 columns]
#
# PROGRESS: Evaluate model M3
#
# Precision and recall summary statistics by cutoff
# +--------+----------------+-----------------+
# | cutoff | mean_precision |   mean_recall   |
# +--------+----------------+-----------------+
# |   1    |      0.36      | 0.0286978716258 |
# |   2    |     0.355      | 0.0526966439732 |
# |   3    | 0.346666666667 | 0.0835781123706 |
# |   4    |     0.335      | 0.0980919027735 |
# |   5    |     0.324      |  0.112830750586 |
# |   6    | 0.313333333333 |  0.12445176312  |
# |   7    | 0.297142857143 |  0.134952793246 |
# |   8    |    0.28375     |  0.144611486645 |
# |   9    |      0.28      |  0.160210192935 |
# |   10   |     0.274      |  0.168334311747 |
# +--------+----------------+-----------------+
# [10 rows x 3 columns]
#
# PROGRESS: Evaluate model M4
#
# Precision and recall summary statistics by cutoff
# +--------+----------------+-----------------+
# | cutoff | mean_precision |   mean_recall   |
# +--------+----------------+-----------------+
# |   1    |      0.36      | 0.0360754578327 |
# |   2    |      0.36      | 0.0599011035713 |
# |   3    |      0.33      | 0.0791615072631 |
# |   4    |     0.325      | 0.0969235660643 |
# |   5    |      0.31      |  0.108480739626 |
# |   6    |     0.305      |  0.123767475775 |
# |   7    | 0.292857142857 |  0.134494649393 |
# |   8    |    0.28875     |  0.150062361941 |
# |   9    | 0.281111111111 |  0.160492979633 |
# |   10   |     0.272      |  0.171205582819 |
# +--------+----------------+-----------------+
# [10 rows x 3 columns]
#
# Model compare metric: precision_recall

# %% [markdown]
# We want to compare which model gives the best perfromance overall.

# %%
gl.show_comparison(comparisonstruct,item_item)

# %% [markdown]
# From the above graph, it is clear that all five models performed equally well based on the overall precision and recall values for all 18 cutoff vlaues chosen. Since with only_top_k equal to 5 requires the least memory and computation time, we chose "only_top_k = 5" for all the following item_similarity recommender.

# %% [markdown]
# #### Find the best parameters for ranking_factorization recommender

# %% [markdown]
# A RankingFactorizationRecommender learns latent factors for each user and item and uses them to rank recommended items according to the likelihood of observing those (user, item) pairs. This is commonly desired when performing collaborative filtering for implicit feedback datasets or datasets with explicit ratings for which ranking prediction is desired.
#
# RankingFactorizationRecommender contains a number of options that tailor to a variety of datasets and evaluation metrics, making this one of the most powerful models in the GraphLab Create recommender toolkit.

# %%
#optimize parameters to find the best model parameters
params = {'user_id': 'userId', 
          'item_id': 'title', 
          'target': 'rating',
          'num_factors': [8, 12, 16, 24, 32], 
          'regularization':[0.001] ,
          'linear_regularization': [0.001]}

job = gl.model_parameter_search.create( (train,test),
        gl.recommender.ranking_factorization_recommender.create,
        params,
        max_models=5,
        environment=None)
# Out:
# [INFO] graphlab.deploy.job: Validating job.
# [INFO] graphlab.deploy.job: Creating a LocalAsync environment called 'async'.
# [INFO] graphlab.deploy.map_job: Validation complete. Job: 'Model-Parameter-Search-Nov-29-2019-12-38-3800000' ready for execution
# [INFO] graphlab.deploy.map_job: Job: 'Model-Parameter-Search-Nov-29-2019-12-38-3800000' scheduled.
# [INFO] graphlab.deploy.job: Validating job.
# [INFO] graphlab.deploy.map_job: A job with name 'Model-Parameter-Search-Nov-29-2019-12-38-3800000' already exists. Renaming the job to 'Model-Parameter-Search-Nov-29-2019-12-38-3800000-3715c'.
# [INFO] graphlab.deploy.map_job: Validation complete. Job: 'Model-Parameter-Search-Nov-29-2019-12-38-3800000-3715c' ready for execution
# [INFO] graphlab.deploy.map_job: Job: 'Model-Parameter-Search-Nov-29-2019-12-38-3800000-3715c' scheduled.

# %%
job.get_status()
# Out:
# {'Canceled': 0, 'Completed': 0, 'Failed': 0, 'Pending': 5, 'Running': 0}

# %%
job_result = job.get_results()

job_result.head()
# Out:
# Columns:
# 	model_id	int
# 	item_id	str
# 	linear_regularization	float
# 	max_iterations	int
# 	num_factors	int
# 	num_sampled_negative_examples	int
# 	ranking_regularization	float
# 	regularization	float
# 	target	str
# 	user_id	str
# 	training_precision@5	float
# 	training_recall@5	float
# 	training_rmse	float
# 	validation_precision@5	float
# 	validation_recall@5	float
# 	validation_rmse	float
#
# Rows: 5
#
# Data:
# +----------+---------+-----------------------+----------------+-------------+-------------------------------+
# | model_id | item_id | linear_regularization | max_iterations | num_factors | num_sampled_negative_examples |
# +----------+---------+-----------------------+----------------+-------------+-------------------------------+
# |    1     |  title  |         0.001         |       50       |      8      |               8               |
# |    0     |  title  |         0.001         |       50       |      16     |               4               |
# |    3     |  title  |         0.001         |       50       |      16     |               4               |
# |    2     |  title  |         0.001         |       25       |      16     |               4               |
# |    4     |  title  |         0.001         |       50       |      12     |               8               |
# +----------+---------+-----------------------+----------------+-------------+-------------------------------+
# +------------------------+----------------+--------+---------+----------------------+
# | ranking_regularization | regularization | target | user_id | training_precision@5 |
# +------------------------+----------------+--------+---------+----------------------+
# |          0.25          |     0.001      | rating |  userId |    0.388517831226    |
# |          0.1           |     0.001      | rating |  userId |    0.388517831226    |
# |          0.1           |     0.001      | rating |  userId |    0.388517831226    |
# |          0.5           |     0.001      | rating |  userId |    0.388517831226    |
# |          0.5           |     0.001      | rating |  userId |    0.388517831226    |
# +------------------------+----------------+--------+---------+----------------------+
# +-------------------+----------------+------------------------+---------------------+
# | training_recall@5 | training_rmse  | validation_precision@5 | validation_recall@5 |
# +-------------------+----------------+------------------------+---------------------+
# |   0.023685956787  | 0.990556004906 |         0.176          |   0.0362479412494   |
# |   0.023685956787  | 0.984196107922 |         0.176          |   0.0362479412494   |
# |   0.023685956787  | 0.984183762727 |         0.176          |   0.0362479412494   |
# |   0.023685956787  | 0.990917539997 |         0.176          |   0.0362479412494   |
# |   0.023685956787  | 0.997895756403 |         0.176          |   0.0359441645663   |
# +-------------------+----------------+------------------------+---------------------+
# +-----------------+
# | validation_rmse |
# +-----------------+
# |  1.00183437186  |
# |  0.994801917413 |
# |  0.99487354209  |
# |  1.00276943136  |
# |  1.00920680982  |
# +-----------------+
# [5 rows x 16 columns]

# %%
#display the best parameters found
bst_prms = job.get_best_params()
bst_prms
# Out:
# {'item_id': 'title',
#  'linear_regularization': 0.001,
#  'max_iterations': 50,
#  'num_factors': 16,
#  'num_sampled_negative_examples': 4,
#  'ranking_regularization': 0.1,
#  'regularization': 0.001,
#  'target': 'rating',
#  'user_id': 'userId'}

# %%
models = job.get_models()
models
# Out:
# [Class                            : RankingFactorizationRecommender
#
#  Schema
#  ------
#  User ID                          : userId
#  Item ID                          : title
#  Target                           : rating
#  Additional observation features  : 0
#  User side features               : []
#  Item side features               : []
#
#  Statistics
#  ----------
#  Number of observations           : 19997751
#  Number of users                  : 138493
#  Number of items                  : 26729
#
#  Training summary
#  ----------------
#  Training time                    : 209.776
#
#  Model Parameters
#  ----------------
#  Model class                      : RankingFactorizationRecommender
#  num_factors                      : 16
#  binary_target                    : 0
#  side_data_factorization          : 1
#  solver                           : auto
#  nmf                              : 0
#  max_iterations                   : 50
#
#  Regularization Settings
#  -----------------------
#  regularization                   : 0.001
#  regularization_type              : normal
#  linear_regularization            : 0.001
#  ranking_regularization           : 0.1
#  unobserved_rating_value          : -1.79769313486e+308
#  num_sampled_negative_examples    : 4
#  ials_confidence_scaling_type     : auto
#  ials_confidence_scaling_factor   : 1
#
#  Optimization Settings
#  ---------------------
#  init_random_sigma                : 0.01
#  sgd_convergence_interval         : 4
#  sgd_convergence_threshold        : 0.0
#  sgd_max_trial_iterations         : 5
#  sgd_sampling_block_size          : 131072
#  sgd_step_adjustment_interval     : 4
#  sgd_step_size                    : 0.0
#  sgd_trial_sample_minimum_size    : 10000
#  sgd_trial_sample_proportion      : 0.125
#  step_size_decrease_rate          : 0.75
#  additional_iterations_if_unhealthy : 5
#  adagrad_momentum_weighting       : 0.9
#  num_tempering_iterations         : 4
#  tempering_regularization_start_value : 0.0
#  track_exact_loss                 : 0,
#  Class                            : RankingFactorizationRecommender
#
#  Schema
#  ------
#  User ID                          : userId
#  Item ID                          : title
#  Target                           : rating
#  Additional observation features  : 0
#  User side features               : []
#  Item side features               : []
#
#  Statistics
#  ----------
#  Number of observations           : 19997751
#  Number of users                  : 138493
#  Number of items                  : 26729
#
#  Training summary
#  ----------------
#  Training time                    : 239.5455
#
#  Model Parameters
#  ----------------
#  Model class                      : RankingFactorizationRecommender
#  num_factors                      : 8
#  binary_target                    : 0
#  side_data_factorization          : 1
#  solver                           : auto
#  nmf                              : 0
#  max_iterations                   : 50
#
#  Regularization Settings
#  -----------------------
#  regularization                   : 0.001
#  regularization_type              : normal
#  linear_regularization            : 0.001
#  ranking_regularization           : 0.25
#  unobserved_rating_value          : -1.79769313486e+308
#  num_sampled_negative_examples    : 8
#  ials_confidence_scaling_type     : auto
#  ials_confidence_scaling_factor   : 1
#
#  Optimization Settings
#  ---------------------
#  init_random_sigma                : 0.01
#  sgd_convergence_interval         : 4
#  sgd_convergence_threshold        : 0.0
#  sgd_max_trial_iterations         : 5
#  sgd_sampling_block_size          : 131072
#  sgd_step_adjustment_interval     : 4
#  sgd_step_size                    : 0.0
#  sgd_trial_sample_minimum_size    : 10000
#  sgd_trial_sample_proportion      : 0.125
#  step_size_decrease_rate          : 0.75
#  additional_iterations_if_unhealthy : 5
#  adagrad_momentum_weighting       : 0.9
#  num_tempering_iterations         : 4
#  tempering_regularization_start_value : 0.0
#  track_exact_loss                 : 0,
#  Class                            : RankingFactorizationRecommender
#
#  Schema
#  ------
#  User ID                          : userId
#  Item ID                          : title
#  Target                           : rating
#  Additional observation features  : 0
#  User side features               : []
#  Item side features               : []
#
#  Statistics
#  ----------
#  Number of observations           : 19997751
#  Number of users                  : 138493
#  Number of items                  : 26729
#
#  Training summary
#  ----------------
#  Training time                    : 225.4163
#
#  Model Parameters
#  ----------------
#  Model class                      : RankingFactorizationRecommender
#  num_factors                      : 16
#  binary_target                    : 0
#  side_data_factorization          : 1
#  solver                           : auto
#  nmf                              : 0
#  max_iterations                   : 25
#
#  Regularization Settings
#  -----------------------
#  regularization                   : 0.001
#  regularization_type              : normal
#  linear_regularization            : 0.001
#  ranking_regularization           : 0.5
#  unobserved_rating_value          : -1.79769313486e+308
#  num_sampled_negative_examples    : 4
#  ials_confidence_scaling_type     : auto
#  ials_confidence_scaling_factor   : 1
#
#  Optimization Settings
#  ---------------------
#  init_random_sigma                : 0.01
#  sgd_convergence_interval         : 4
#  sgd_convergence_threshold        : 0.0
#  sgd_max_trial_iterations         : 5
#  sgd_sampling_block_size          : 131072
#  sgd_step_adjustment_interval     : 4
#  sgd_step_size                    : 0.0
#  sgd_trial_sample_minimum_size    : 10000
#  sgd_trial_sample_proportion      : 0.125
#  step_size_decrease_rate          : 0.75
#  additional_iterations_if_unhealthy : 5
#  adagrad_momentum_weighting       : 0.9
#  num_tempering_iterations         : 4
#  tempering_regularization_start_value : 0.0
#  track_exact_loss                 : 0,
#  Class                            : RankingFactorizationRecommender
#
#  Schema
#  ------
#  User ID                          : userId
#  Item ID                          : title
#  Target                           : rating
#  Additional observation features  : 0
#  User side features               : []
#  Item side features               : []
#
#  Statistics
#  ----------
#  Number of observations           : 19997751
#  Number of users                  : 138493
#  Number of items                  : 26729
#
#  Training summary
#  ----------------
#  Training time                    : 216.934
#
#  Model Parameters
#  ----------------
#  Model class                      : RankingFactorizationRecommender
#  num_factors                      : 16
#  binary_target                    : 0
#  side_data_factorization          : 1
#  solver                           : auto
#  nmf                              : 0
#  max_iterations                   : 50
#
#  Regularization Settings
#  -----------------------
#  regularization                   : 0.001
#  regularization_type              : normal
#  linear_regularization            : 0.001
#  ranking_regularization           : 0.1
#  unobserved_rating_value          : -1.79769313486e+308
#  num_sampled_negative_examples    : 4
#  ials_confidence_scaling_type     : auto
#  ials_confidence_scaling_factor   : 1
#
#  Optimization Settings
#  ---------------------
#  init_random_sigma                : 0.01
#  sgd_convergence_interval         : 4
#  sgd_convergence_threshold        : 0.0
#  sgd_max_trial_iterations         : 5
#  sgd_sampling_block_size          : 131072
#  sgd_step_adjustment_interval     : 4
#  sgd_step_size                    : 0.0
#  sgd_trial_sample_minimum_size    : 10000
#  sgd_trial_sample_proportion      : 0.125
#  step_size_decrease_rate          : 0.75
#  additional_iterations_if_unhealthy : 5
#  adagrad_momentum_weighting       : 0.9
#  num_tempering_iterations         : 4
#  tempering_regularization_start_value : 0.0
#  track_exact_loss                 : 0,
#  Class                            : RankingFactorizationRecommender
#
#  Schema
#  ------
#  User ID                          : userId
#  Item ID                          : title
#  Target                           : rating
#  Additional observation features  : 0
#  User side features               : []
#  Item side features               : []
#
#  Statistics
#  ----------
#  Number of observations           : 19997751
#  Number of users                  : 138493
#  Number of items                  : 26729
#
#  Training summary
#  ----------------
#  Training time                    : 243.466
#
#  Model Parameters
#  ----------------
#  Model class                      : RankingFactorizationRecommender
#  num_factors                      : 12
#  binary_target                    : 0
#  side_data_factorization          : 1
#  solver                           : auto
#  nmf                              : 0
#  max_iterations                   : 50
#
#  Regularization Settings
#  -----------------------
#  regularization                   : 0.001
#  regularization_type              : normal
#  linear_regularization            : 0.001
#  ranking_regularization           : 0.5
#  unobserved_rating_value          : -1.79769313486e+308
#  num_sampled_negative_examples    : 8
#  ials_confidence_scaling_type     : auto
#  ials_confidence_scaling_factor   : 1
#
#  Optimization Settings
#  ---------------------
#  init_random_sigma                : 0.01
#  sgd_convergence_interval         : 4
#  sgd_convergence_threshold        : 0.0
#  sgd_max_trial_iterations         : 5
#  sgd_sampling_block_size          : 131072
#  sgd_step_adjustment_interval     : 4
#  sgd_step_size                    : 0.0
#  sgd_trial_sample_minimum_size    : 10000
#  sgd_trial_sample_proportion      : 0.125
#  step_size_decrease_rate          : 0.75
#  additional_iterations_if_unhealthy : 5
#  adagrad_momentum_weighting       : 0.9
#  num_tempering_iterations         : 4
#  tempering_regularization_start_value : 0.0
#  track_exact_loss                 : 0]

# %%
comparisonstruct = gl.compare(test,models)
gl.show_comparison(comparisonstruct,models)
# Out:
# PROGRESS: Evaluate model M0
#
# Precision and recall summary statistics by cutoff
# +--------+----------------+-----------------+
# | cutoff | mean_precision |   mean_recall   |
# +--------+----------------+-----------------+
# |   1    |      0.23      | 0.0100477230193 |
# |   2    |     0.205      | 0.0185206829317 |
# |   3    |      0.19      | 0.0258405534522 |
# |   4    |     0.1875     | 0.0323531375112 |
# |   5    |     0.176      | 0.0362479412494 |
# |   6    | 0.166666666667 | 0.0388332849138 |
# |   7    | 0.162857142857 | 0.0449372005518 |
# |   8    |    0.15125     | 0.0501890404482 |
# |   9    | 0.141111111111 | 0.0517024139916 |
# |   10   |     0.129      | 0.0520663484179 |
# +--------+----------------+-----------------+
# [10 rows x 3 columns]
#
# PROGRESS: Evaluate model M1
#
# Precision and recall summary statistics by cutoff
# +--------+----------------+-----------------+
# | cutoff | mean_precision |   mean_recall   |
# +--------+----------------+-----------------+
# |   1    |      0.23      | 0.0100477230193 |
# |   2    |      0.2       | 0.0178956829317 |
# |   3    | 0.196666666667 | 0.0265961090077 |
# |   4    |     0.195      | 0.0328187876057 |
# |   5    |     0.176      | 0.0362479412494 |
# |   6    |      0.17      |  0.040778311777 |
# |   7    | 0.162857142857 | 0.0475946176345 |
# |   8    |    0.15125     | 0.0495806917651 |
# |   9    | 0.137777777778 | 0.0502509851174 |
# |   10   |     0.132      | 0.0568393515077 |
# +--------+----------------+-----------------+
# [10 rows x 3 columns]
#
# PROGRESS: Evaluate model M2
#
# Precision and recall summary statistics by cutoff
# +--------+----------------+-----------------+
# | cutoff | mean_precision |   mean_recall   |
# +--------+----------------+-----------------+
# |   1    |      0.23      | 0.0100477230193 |
# |   2    |      0.2       | 0.0178956829317 |
# |   3    | 0.196666666667 | 0.0265961090077 |
# |   4    |     0.195      | 0.0328187876057 |
# |   5    |     0.176      | 0.0362479412494 |
# |   6    |      0.17      |  0.040778311777 |
# |   7    | 0.162857142857 | 0.0475946176345 |
# |   8    |    0.15125     | 0.0495806917651 |
# |   9    | 0.137777777778 | 0.0502509851174 |
# |   10   |     0.132      | 0.0568393515077 |
# +--------+----------------+-----------------+
# [10 rows x 3 columns]
#
# PROGRESS: Evaluate model M3
#
# Precision and recall summary statistics by cutoff
# +--------+----------------+-----------------+
# | cutoff | mean_precision |   mean_recall   |
# +--------+----------------+-----------------+
# |   1    |      0.23      | 0.0100477230193 |
# |   2    |     0.205      | 0.0185206829317 |
# |   3    |      0.19      | 0.0258405534522 |
# |   4    |     0.1875     | 0.0323531375112 |
# |   5    |     0.176      | 0.0362479412494 |
# |   6    | 0.166666666667 | 0.0388332849138 |
# |   7    | 0.162857142857 | 0.0449372005518 |
# |   8    |    0.15125     | 0.0501890404482 |
# |   9    | 0.141111111111 | 0.0517024139916 |
# |   10   |     0.129      | 0.0520663484179 |
# +--------+----------------+-----------------+
# [10 rows x 3 columns]
#
# PROGRESS: Evaluate model M4
#
# Precision and recall summary statistics by cutoff
# +--------+----------------+-----------------+
# | cutoff | mean_precision |   mean_recall   |
# +--------+----------------+-----------------+
# |   1    |      0.24      | 0.0113905801622 |
# |   2    |     0.205      | 0.0189097024371 |
# |   3    |      0.2       | 0.0266636765753 |
# |   4    |      0.2       | 0.0326574336046 |
# |   5    |     0.176      | 0.0359441645663 |
# |   6    |     0.175      | 0.0412111686616 |
# |   7    | 0.162857142857 | 0.0470901862259 |
# |   8    |    0.15125     | 0.0496683442041 |
# |   9    | 0.146666666667 | 0.0561206712032 |
# |   10   |      0.14      | 0.0599449213458 |
# +--------+----------------+-----------------+
# [10 rows x 3 columns]
#
# Model compare metric: precision_recall

# %% [markdown]
# From the above precision-recall graph, it appears that all five models performed equally well based on the overall precision and recall values for all cutoff vlaues chosen. We chose to use the best parameters obtained above for the ranking_factorization_recommender in the following sections.

# %% [markdown]
# <a href="#top">Back to Top</a>
# ### Modeling and Evaluation - Evaluate & Compare<a id="Modeling_and_Evaluation_Evaluate_and_Compare"></a>
# * Determine performance of the recommendations using different performance measures and explain what each measure.

# %% [markdown]
# #### Evaluate item_similarity recommender using the optimal parameter settings

# %%
from IPython.display import display
from IPython.display import Image

gl.canvas.set_target('ipynb')

item_item = gl.recommender.item_similarity_recommender.create(train, 
                                  user_id="userId", 
                                  item_id="title", 
                                  target="rating",
                                  only_top_k= 5,
                                  similarity_type="cosine")
    
rmse_results = item_item.evaluate(test)
# Out:
# Recsys training: model = item_similarity
# Preparing data set.
#     Data has 19997751 observations with 138493 users and 26729 items.
#     Data prepared in: 12.2453s
# Training model from provided data.
# Gathering per-item and per-user statistics.
# +--------------------------------+------------+
# | Elapsed Time (Item Statistics) | % Complete |
# +--------------------------------+------------+
# | 2.992ms                        | 0.5        |
# | 246.34ms                       | 100        |
# +--------------------------------+------------+
# Setting up lookup tables.
# Processing data in one pass using dense lookup tables.
# +-------------------------------------+------------------+-----------------+
# | Elapsed Time (Constructing Lookups) | Total % Complete | Items Processed |
# +-------------------------------------+------------------+-----------------+
# | 1.20s                               | 0                | 0               |
# | 2.20s                               | 2.75             | 751             |
# | 3.20s                               | 5.75             | 1548            |
# | 4.20s                               | 8.5              | 2337            |
# | 5.20s                               | 11.5             | 3135            |
# | 6.20s                               | 14.5             | 3912            |
# | 7.20s                               | 17.5             | 4703            |
# | 8.21s                               | 21               | 5621            |
# | 9.20s                               | 24               | 6455            |
# | 10.20s                              | 27.25            | 7320            |
# | 11.20s                              | 30.5             | 8155            |
# | 12.20s                              | 33.5             | 8977            |
# | 13.20s                              | 36.5             | 9800            |
# | 14.20s                              | 40.25            | 10761           |
# | 15.20s                              | 43.25            | 11581           |
# | 16.20s                              | 46.25            | 12408           |
# | 17.20s                              | 49.5             | 13235           |
# | 18.20s                              | 52.75            | 14119           |
# | 19.20s                              | 56               | 15032           |
# | 20.20s                              | 59               | 15831           |
# | 21.20s                              | 62               | 16588           |
# | 22.20s                              | 65               | 17387           |
# | 23.20s                              | 68.25            | 18260           |
# | 24.20s                              | 71               | 19027           |
# | 25.20s                              | 74               | 19779           |
# | 26.20s                              | 76.5             | 20460           |
# | 27.20s                              | 79               | 21137           |
# | 28.20s                              | 81.5             | 21784           |
# | 29.19s                              | 83.75            | 22412           |
# | 30.20s                              | 86               | 23039           |
# | 31.19s                              | 88.25            | 23654           |
# | 32.19s                              | 90.5             | 24247           |
# | 33.19s                              | 92.75            | 24838           |
# | 34.19s                              | 95               | 25426           |
# | 35.19s                              | 97.25            | 26019           |
# | 36.19s                              | 99.5             | 26605           |
# | 38.57s                              | 100              | 26729           |
# +-------------------------------------+------------------+-----------------+
# Finalizing lookup tables.
# Generating candidate set for working with new users.
# Finished training in 39.1274s
# Precision and recall summary statistics by cutoff
# +--------+----------------+-----------------+
# | cutoff | mean_precision |   mean_recall   |
# +--------+----------------+-----------------+
# |   1    |      0.42      | 0.0281205111405 |
# |   2    |     0.375      | 0.0530206214492 |
# |   3    | 0.383333333333 | 0.0792510595951 |
# |   4    |     0.3475     |  0.09963408895  |
# |   5    |     0.336      |  0.114857061227 |
# |   6    | 0.321666666667 |  0.132161171907 |
# |   7    | 0.307142857143 |  0.142108706774 |
# |   8    |     0.295      |  0.153214917373 |
# |   9    | 0.288888888889 |  0.165192663614 |
# |   10   |     0.283      |  0.176801251216 |
# +--------+----------------+-----------------+
# [10 rows x 3 columns]
#
# ('\nOverall RMSE: ', 3.645177876609552)
#
# Per User RMSE (best)
# +--------+-------+---------------+
# | userId | count |      rmse     |
# +--------+-------+---------------+
# | 100197 |   4   | 2.06026246036 |
# +--------+-------+---------------+
# [1 rows x 3 columns]
#
#
# Per User RMSE (worst)
# +--------+-------+---------------+
# | userId | count |      rmse     |
# +--------+-------+---------------+
# | 135464 |   5   | 4.89664701711 |
# +--------+-------+---------------+
# [1 rows x 3 columns]
#
#
# Per Item RMSE (best)
# +------------------+-------+---------------+
# |      title       | count |      rmse     |
# +------------------+-------+---------------+
# | Rambo III (1988) |   1   | 0.48960763216 |
# +------------------+-------+---------------+
# [1 rows x 3 columns]
#
#
# Per Item RMSE (worst)
# +-------------------------------+-------+------+
# |             title             | count | rmse |
# +-------------------------------+-------+------+
# | Battle of Algiers, The (La... |   1   | 5.0  |
# +-------------------------------+-------+------+
# [1 rows x 3 columns]

# %%
print rmse_results.viewkeys()
# Out:
# dict_keys(['rmse_by_user', 'precision_recall_overall', 'rmse_by_item', 'precision_recall_by_user', 'rmse_overall'])

# %%
rmse_results['rmse_by_user']
# Out:
# Columns:
# 	userId	int
# 	count	int
# 	rmse	float
#
# Rows: 100
#
# Data:
# +--------+-------+---------------+
# | userId | count |      rmse     |
# +--------+-------+---------------+
# | 23724  |   23  | 3.61376677252 |
# | 104017 |   30  | 3.33980175754 |
# | 100197 |   4   | 2.06026246036 |
# | 18783  |   18  |  3.6136072748 |
# | 37446  |   19  | 3.56623567359 |
# |  4414  |   8   | 3.14696455789 |
# | 128210 |   7   | 3.22878931079 |
# | 134645 |   75  | 4.16426873959 |
# | 132030 |   13  | 4.27855730415 |
# | 115880 |   21  | 4.42229721245 |
# +--------+-------+---------------+
# [100 rows x 3 columns]
# Note: Only the head of the SFrame is printed.
# You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.

# %%
from matplotlib import pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')

rmsevals = rmse_results['rmse_by_user']['rmse']
rmsevals = rmsevals[rmse_results['rmse_by_user']['count']>10]

plt.hist(rmsevals,bins=20)
plt.title('RMSE by User')
plt.show()

# %% [markdown]
# The RMSE values range from 2.5 to 4.6, with most of them located within 3.5-4.0.

# %%
rmse_results['precision_recall_by_user']
# Out:
# Columns:
# 	userId	int
# 	cutoff	int
# 	precision	float
# 	recall	float
# 	count	int
#
# Rows: 1800
#
# Data:
# +--------+--------+----------------+--------+-------+
# | userId | cutoff |   precision    | recall | count |
# +--------+--------+----------------+--------+-------+
# |  3014  |   1    |      0.0       |  0.0   |   10  |
# |  3014  |   2    |      0.0       |  0.0   |   10  |
# |  3014  |   3    |      0.0       |  0.0   |   10  |
# |  3014  |   4    |      0.0       |  0.0   |   10  |
# |  3014  |   5    |      0.0       |  0.0   |   10  |
# |  3014  |   6    | 0.166666666667 |  0.1   |   10  |
# |  3014  |   7    | 0.142857142857 |  0.1   |   10  |
# |  3014  |   8    |     0.125      |  0.1   |   10  |
# |  3014  |   9    | 0.111111111111 |  0.1   |   10  |
# |  3014  |   10   |      0.2       |  0.2   |   10  |
# +--------+--------+----------------+--------+-------+
# [1800 rows x 5 columns]
# Note: Only the head of the SFrame is printed.
# You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.

# %% [markdown]
# It looks like that for userId = 3014, if we recommend based on item_similarity algorithm 5 movies or less, none of them were rated positively by this user.

# %%
import graphlab.aggregate as agg

# we will be using these aggregations
agg_list = [agg.AVG('precision'),agg.STD('precision'),agg.AVG('recall'),agg.STD('recall')]

# apply these functions to each group (we will group the results by 'k' which is the cutoff)
# the cutoff is the number of top items to look for see the following URL for the actual equation
# https://dato.com/products/create/docs/generated/graphlab.recommender.util.precision_recall_by_user.html#graphlab.recommender.util.precision_recall_by_user
rmse_results['precision_recall_by_user'].groupby('cutoff',agg_list)
# Out:
# Columns:
# 	cutoff	int
# 	Avg of precision	float
# 	Stdv of precision	float
# 	Avg of recall	float
# 	Stdv of recall	float
#
# Rows: 18
#
# Data:
# +--------+------------------+-------------------+-----------------+
# | cutoff | Avg of precision | Stdv of precision |  Avg of recall  |
# +--------+------------------+-------------------+-----------------+
# |   36   |  0.173333333333  |   0.161068960003  |  0.333358060101 |
# |   2    |      0.375       |   0.402336923486  | 0.0530206214492 |
# |   46   |      0.155       |   0.149626346204  |  0.36831414537  |
# |   31   |  0.186451612903  |   0.168211501572  |  0.314543919733 |
# |   26   |  0.201538461538  |   0.175842856151  |  0.294585544449 |
# |   8    |      0.295       |   0.252809216604  |  0.153214917373 |
# |   5    |      0.336       |   0.279828518918  |  0.114857061227 |
# |   16   |     0.250625     |   0.209444018475  |  0.235471866491 |
# |   41   |  0.165609756098  |   0.155918151472  |  0.359201869644 |
# |   4    |      0.3475      |   0.295582052906  |  0.09963408895  |
# +--------+------------------+-------------------+-----------------+
# +-----------------+
# |  Stdv of recall |
# +-----------------+
# |  0.225097355344 |
# | 0.0861472947071 |
# |  0.222896321029 |
# |  0.228583896859 |
# |  0.219221437584 |
# |  0.169391175227 |
# |  0.145662468077 |
# |  0.19927222296  |
# |  0.225815163698 |
# |  0.136634570133 |
# +-----------------+
# [18 rows x 5 columns]
# Note: Only the head of the SFrame is printed.
# You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.

# %% [markdown]
# #### Evaluate ranking_factorization recommender

# %% [markdown]
# We use the best parameters obtained above for the following ranking_factorization_recommender.

# %%
rec1 = gl.recommender.ranking_factorization_recommender.create(train, 
                                  user_id="userId", 
                                  item_id="title", 
                                  target="rating",
                                  num_factors=32,                 # override the default value
                                  regularization=1e-03,           # override the default value
                                  linear_regularization = 1e-3,   # override the default value
                                  ranking_regularization = 0.1,   # override the default value
                                  num_sampled_negative_examples = 4, # override the default value
                                  max_iterations = 50   )   # override the default value

rmse_results = rec1.evaluate(test)
# Out:
# Recsys training: model = ranking_factorization_recommender
# Preparing data set.
#     Data has 19997751 observations with 138493 users and 26729 items.
#     Data prepared in: 12.0438s
# Training ranking_factorization_recommender for recommendations.
# +--------------------------------+--------------------------------------------------+----------+
# | Parameter                      | Description                                      | Value    |
# +--------------------------------+--------------------------------------------------+----------+
# | num_factors                    | Factor Dimension                                 | 32       |
# | regularization                 | L2 Regularization on Factors                     | 0.001    |
# | solver                         | Solver used for training                         | sgd      |
# | linear_regularization          | L2 Regularization on Linear Coefficients         | 0.001    |
# | ranking_regularization         | Rank-based Regularization Weight                 | 0.1      |
# | max_iterations                 | Maximum Number of Iterations                     | 50       |
# +--------------------------------+--------------------------------------------------+----------+
#   Optimizing model using SGD; tuning step size.
#   Using 2499718 / 19997751 points for tuning the step size.
# +---------+-------------------+------------------------------------------+
# | Attempt | Initial Step Size | Estimated Objective Value                |
# +---------+-------------------+------------------------------------------+
# | 0       | 0.00368454        | Not Viable                               |
# | 1       | 0.000921136       | 1.48704                                  |
# | 2       | 0.000460568       | 1.47664                                  |
# | 3       | 0.000230284       | 1.46966                                  |
# | 4       | 0.000115142       | 1.46788                                  |
# | 5       | 5.7571e-005       | 1.47151                                  |
# | 6       | 2.87855e-005      | 1.47991                                  |
# | 7       | 1.43927e-005      | 1.49562                                  |
# +---------+-------------------+------------------------------------------+
# | Final   | 0.000115142       | 1.46788                                  |
# +---------+-------------------+------------------------------------------+
# Starting Optimization.
# +---------+--------------+-------------------+-----------------------+-------------+
# | Iter.   | Elapsed Time | Approx. Objective | Approx. Training RMSE | Step Size   |
# +---------+--------------+-------------------+-----------------------+-------------+
# | Initial | 0us          | 1.53197           | 1.05199               |             |
# +---------+--------------+-------------------+-----------------------+-------------+
# | 1       | 11.70s       | 1.49206           | 0.992094              | 0.000115142 |
# | 2       | 23.37s       | 1.48148           | 0.98554               |             |
# | 3       | 35.01s       | 1.48091           | 0.984808              |             |
# | 4       | 46.65s       | 1.48052           | 0.984468              |             |
# | 5       | 58.32s       | 1.48085           | 0.984412              | 1.1277e-005 |
# | 6       | 1m 9s        | 1.48094           | 0.98437               |             |
# | 7       | 1m 21s       | 1.4808            | 0.984257              |             |
# | 8       | 1m 33s       | 1.48097           | 0.984283              | 6.4687e-006 |
# | 9       | 1m 44s       | 1.48101           | 0.984255              |             |
# | 10      | 1m 56s       | 1.48126           | 0.984282              |             |
# | 11      | 2m 8s        | 1.48097           | 0.984161              |             |
# | 12      | 2m 19s       | 1.48113           | 0.98421               |             |
# | 13      | 2m 31s       | 1.48097           | 0.984137              |             |
# | 14      | 2m 42s       | 1.48111           | 0.984183              |             |
# | 15      | 2m 54s       | 1.48111           | 0.984168              |             |
# | 16      | 3m 6s        | 1.48118           | 0.984192              |             |
# | 17      | 3m 18s       | 1.48114           | 0.984173              |             |
# | 18      | 3m 30s       | 1.48119           | 0.984187              |             |
# | 19      | 3m 41s       | 1.48116           | 0.984177              |             |
# | 20      | 3m 53s       | 1.48116           | 0.984177              |             |
# | 21      | 4m 5s        | 1.48118           | 0.98418               |             |
# | 22      | 4m 16s       | 1.48118           | 0.984181              |             |
# | 23      | 4m 28s       | 1.48117           | 0.984175              |             |
# | 24      | 4m 40s       | 1.48117           | 0.984176              |             |
# +---------+--------------+-------------------+-----------------------+-------------+
# Optimization Complete: Convergence on objective within bounds.
# Computing final objective value and training RMSE.
#        Final objective value: 1.48179
#        Final training RMSE: 0.984412
# Precision and recall summary statistics by cutoff
# +--------+----------------+-----------------+
# | cutoff | mean_precision |   mean_recall   |
# +--------+----------------+-----------------+
# |   1    |      0.23      | 0.0100477230193 |
# |   2    |     0.205      | 0.0185206829317 |
# |   3    |      0.19      | 0.0258405534522 |
# |   4    |     0.1875     | 0.0323531375112 |
# |   5    |     0.176      | 0.0362479412494 |
# |   6    | 0.166666666667 | 0.0388332849138 |
# |   7    | 0.162857142857 | 0.0449372005518 |
# |   8    |    0.15125     | 0.0501890404482 |
# |   9    | 0.141111111111 | 0.0517024139916 |
# |   10   |     0.129      | 0.0520663484179 |
# +--------+----------------+-----------------+
# [10 rows x 3 columns]
#
# ('\nOverall RMSE: ', 0.9947633585945826)
#
# Per User RMSE (best)
# +--------+-------+----------------+
# | userId | count |      rmse      |
# +--------+-------+----------------+
# | 11658  |   4   | 0.357645754433 |
# +--------+-------+----------------+
# [1 rows x 3 columns]
#
#
# Per User RMSE (worst)
# +--------+-------+---------------+
# | userId | count |      rmse     |
# +--------+-------+---------------+
# | 17686  |   16  | 2.24350908286 |
# +--------+-------+---------------+
# [1 rows x 3 columns]
#
#
# Per Item RMSE (best)
# +-----------------------+-------+-------------------+
# |         title         | count |        rmse       |
# +-----------------------+-------+-------------------+
# | Tropic Thunder (2008) |   1   | 0.000165235730171 |
# +-----------------------+-------+-------------------+
# [1 rows x 3 columns]
#
#
# Per Item RMSE (worst)
# +---------------------+-------+---------------+
# |        title        | count |      rmse     |
# +---------------------+-------+---------------+
# | Hotel Rwanda (2004) |   1   | 3.23341309418 |
# +---------------------+-------+---------------+
# [1 rows x 3 columns]

# %%
rmse_results['precision_recall_by_user'].groupby('cutoff',[agg.AVG('precision'),agg.STD('precision'),agg.AVG('recall'),agg.STD('recall')])
# Out:
# Columns:
# 	cutoff	int
# 	Avg of precision	float
# 	Stdv of precision	float
# 	Avg of recall	float
# 	Stdv of recall	float
#
# Rows: 18
#
# Data:
# +--------+------------------+-------------------+-----------------+
# | cutoff | Avg of precision | Stdv of precision |  Avg of recall  |
# +--------+------------------+-------------------+-----------------+
# |   36   | 0.0788888888889  |   0.106263706451  |  0.118167431729 |
# |   2    |      0.205       |   0.332377797092  | 0.0185206829317 |
# |   46   |  0.069347826087  |  0.0917532958361  |  0.134189985265 |
# |   31   | 0.0858064516129  |   0.115969424368  |  0.110518853516 |
# |   26   | 0.0911538461538  |   0.124112828035  | 0.0951163665888 |
# |   8    |     0.15125      |   0.219584123971  | 0.0501890404482 |
# |   5    |      0.176       |   0.256561883373  | 0.0362479412494 |
# |   16   |     0.10875      |   0.151456470644  | 0.0712800858058 |
# |   41   | 0.0741463414634  |   0.098163990073  |  0.128656531963 |
# |   4    |      0.1875      |   0.276981497577  | 0.0323531375112 |
# +--------+------------------+-------------------+-----------------+
# +-----------------+
# |  Stdv of recall |
# +-----------------+
# |  0.112192897548 |
# | 0.0412839576855 |
# |  0.118689258081 |
# |  0.108472616212 |
# |  0.10301767905  |
# | 0.0844558767041 |
# | 0.0603656822599 |
# | 0.0936888604259 |
# |  0.117092904906 |
# | 0.0587011219159 |
# +-----------------+
# [18 rows x 5 columns]
# Note: Only the head of the SFrame is printed.
# You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.

# %% [markdown]
# #### Which recommender is doing better: item_similarity or ranking_factorization?

# %%
comparison = gl.recommender.util.compare_models(test, [item_item, rec1])
# Out:
# PROGRESS: Evaluate model M0
#
# Precision and recall summary statistics by cutoff
# +--------+----------------+-----------------+
# | cutoff | mean_precision |   mean_recall   |
# +--------+----------------+-----------------+
# |   1    |      0.42      | 0.0281205111405 |
# |   2    |     0.375      | 0.0530206214492 |
# |   3    | 0.383333333333 | 0.0792510595951 |
# |   4    |     0.3475     |  0.09963408895  |
# |   5    |     0.336      |  0.114857061227 |
# |   6    | 0.321666666667 |  0.132161171907 |
# |   7    | 0.307142857143 |  0.142108706774 |
# |   8    |     0.295      |  0.153214917373 |
# |   9    | 0.288888888889 |  0.165192663614 |
# |   10   |     0.283      |  0.176801251216 |
# +--------+----------------+-----------------+
# [10 rows x 3 columns]
#
# ('\nOverall RMSE: ', 3.645177876609552)
#
# Per User RMSE (best)
# +--------+-------+---------------+
# | userId | count |      rmse     |
# +--------+-------+---------------+
# | 100197 |   4   | 2.06026246036 |
# +--------+-------+---------------+
# [1 rows x 3 columns]
#
#
# Per User RMSE (worst)
# +--------+-------+---------------+
# | userId | count |      rmse     |
# +--------+-------+---------------+
# | 135464 |   5   | 4.89664701711 |
# +--------+-------+---------------+
# [1 rows x 3 columns]
#
#
# Per Item RMSE (best)
# +------------------+-------+---------------+
# |      title       | count |      rmse     |
# +------------------+-------+---------------+
# | Rambo III (1988) |   1   | 0.48960763216 |
# +------------------+-------+---------------+
# [1 rows x 3 columns]
#
#
# Per Item RMSE (worst)
# +-------------------------------+-------+------+
# |             title             | count | rmse |
# +-------------------------------+-------+------+
# | Battle of Algiers, The (La... |   1   | 5.0  |
# +-------------------------------+-------+------+
# [1 rows x 3 columns]
#
# PROGRESS: Evaluate model M1
#
# Precision and recall summary statistics by cutoff
# +--------+----------------+-----------------+
# | cutoff | mean_precision |   mean_recall   |
# +--------+----------------+-----------------+
# |   1    |      0.23      | 0.0100477230193 |
# |   2    |     0.205      | 0.0185206829317 |
# |   3    |      0.19      | 0.0258405534522 |
# |   4    |     0.1875     | 0.0323531375112 |
# |   5    |     0.176      | 0.0362479412494 |
# |   6    | 0.166666666667 | 0.0388332849138 |
# |   7    | 0.162857142857 | 0.0449372005518 |
# |   8    |    0.15125     | 0.0501890404482 |
# |   9    | 0.141111111111 | 0.0517024139916 |
# |   10   |     0.129      | 0.0520663484179 |
# +--------+----------------+-----------------+
# [10 rows x 3 columns]
#
# ('\nOverall RMSE: ', 0.9947633585945826)
#
# Per User RMSE (best)
# +--------+-------+----------------+
# | userId | count |      rmse      |
# +--------+-------+----------------+
# | 11658  |   4   | 0.357645754433 |
# +--------+-------+----------------+
# [1 rows x 3 columns]
#
#
# Per User RMSE (worst)
# +--------+-------+---------------+
# | userId | count |      rmse     |
# +--------+-------+---------------+
# | 17686  |   16  | 2.24350908286 |
# +--------+-------+---------------+
# [1 rows x 3 columns]
#
#
# Per Item RMSE (best)
# +-----------------------+-------+-------------------+
# |         title         | count |        rmse       |
# +-----------------------+-------+-------------------+
# | Tropic Thunder (2008) |   1   | 0.000165235730171 |
# +-----------------------+-------+-------------------+
# [1 rows x 3 columns]
#
#
# Per Item RMSE (worst)
# +---------------------+-------+---------------+
# |        title        | count |      rmse     |
# +---------------------+-------+---------------+
# | Hotel Rwanda (2004) |   1   | 3.23341309418 |
# +---------------------+-------+---------------+
# [1 rows x 3 columns]

# %%
 comparisonstruct = gl.compare(test,[item_item, rec1])
# Out:
# PROGRESS: Evaluate model M0
#
# Precision and recall summary statistics by cutoff
# +--------+----------------+-----------------+
# | cutoff | mean_precision |   mean_recall   |
# +--------+----------------+-----------------+
# |   1    |      0.42      | 0.0281205111405 |
# |   2    |     0.375      | 0.0530206214492 |
# |   3    | 0.383333333333 | 0.0792510595951 |
# |   4    |     0.3475     |  0.09963408895  |
# |   5    |     0.336      |  0.114857061227 |
# |   6    | 0.321666666667 |  0.132161171907 |
# |   7    | 0.307142857143 |  0.142108706774 |
# |   8    |     0.295      |  0.153214917373 |
# |   9    | 0.288888888889 |  0.165192663614 |
# |   10   |     0.283      |  0.176801251216 |
# +--------+----------------+-----------------+
# [10 rows x 3 columns]
#
# PROGRESS: Evaluate model M1
#
# Precision and recall summary statistics by cutoff
# +--------+----------------+-----------------+
# | cutoff | mean_precision |   mean_recall   |
# +--------+----------------+-----------------+
# |   1    |      0.23      | 0.0100477230193 |
# |   2    |     0.205      | 0.0185206829317 |
# |   3    |      0.19      | 0.0258405534522 |
# |   4    |     0.1875     | 0.0323531375112 |
# |   5    |     0.176      | 0.0362479412494 |
# |   6    | 0.166666666667 | 0.0388332849138 |
# |   7    | 0.162857142857 | 0.0449372005518 |
# |   8    |    0.15125     | 0.0501890404482 |
# |   9    | 0.141111111111 | 0.0517024139916 |
# |   10   |     0.129      | 0.0520663484179 |
# +--------+----------------+-----------------+
# [10 rows x 3 columns]
#
# Model compare metric: precision_recall

# %%
gl.show_comparison(comparisonstruct,[item_item, rec1])

# %% [markdown]
# From the above graph, it is obvious that item_similarity recommender is doing better than ranking_facotorization recommender in our dataset for each cutoff value.

# %% [markdown]
# <a href="#top">Back to Top</a>
# ### Modeling and Evaluation - Visualize Results<a id="Modeling_and_Evaluation_Visualize_Results"></a>
# * Use tables/visualization to discuss the found results. Explain each visualization in detail.

# %% [markdown]
# #### We use the best recommender, item_similarity recommender, on the whole dataset for recommendations.

# %%
# This is a well known graphlab example that builds a recommendation system in 5 lines of code
from IPython.display import display
from IPython.display import Image

gl.canvas.set_target('ipynb')

model = gl.recommender.item_similarity_recommender.create(data, 
                                  user_id="userId", 
                                  item_id="title", 
                                  target="rating",
                                  only_top_k= 5,
                                  similarity_type="cosine")
    
results = model.recommend(users=None, k=5)
#model.save("my_model")
# Out:
# Recsys training: model = item_similarity
# Preparing data set.
#     Data has 20000263 observations with 138493 users and 26729 items.
#     Data prepared in: 14.6708s
# Training model from provided data.
# Gathering per-item and per-user statistics.
# +--------------------------------+------------+
# | Elapsed Time (Item Statistics) | % Complete |
# +--------------------------------+------------+
# | 3.99ms                         | 0.5        |
# | 277.259ms                      | 100        |
# +--------------------------------+------------+
# Setting up lookup tables.
# Processing data in one pass using dense lookup tables.
# +-------------------------------------+------------------+-----------------+
# | Elapsed Time (Constructing Lookups) | Total % Complete | Items Processed |
# +-------------------------------------+------------------+-----------------+
# | 1.16s                               | 0                | 0               |
# | 2.17s                               | 2.5              | 674             |
# | 3.17s                               | 5.25             | 1410            |
# | 4.16s                               | 7.5              | 2060            |
# | 5.16s                               | 10               | 2686            |
# | 6.16s                               | 12.5             | 3374            |
# | 7.16s                               | 15               | 4056            |
# | 8.17s                               | 17.75            | 4809            |
# | 9.16s                               | 20.75            | 5570            |
# | 10.16s                              | 23.5             | 6329            |
# | 11.16s                              | 26.5             | 7097            |
# | 12.16s                              | 29               | 7802            |
# | 13.17s                              | 32               | 8579            |
# | 14.17s                              | 35               | 9401            |
# | 15.17s                              | 38               | 10163           |
# | 16.16s                              | 40.5             | 10855           |
# | 17.16s                              | 43               | 11541           |
# | 18.16s                              | 45.75            | 12286           |
# | 19.16s                              | 48.25            | 12921           |
# | 20.16s                              | 50.75            | 13616           |
# | 21.16s                              | 53.25            | 14248           |
# | 22.16s                              | 55.75            | 14917           |
# | 23.16s                              | 58.5             | 15641           |
# | 24.16s                              | 60.75            | 16294           |
# | 25.16s                              | 63.5             | 16991           |
# | 26.17s                              | 66.25            | 17753           |
# | 27.16s                              | 69               | 18459           |
# | 28.16s                              | 71.5             | 19138           |
# | 29.16s                              | 74               | 19785           |
# | 30.16s                              | 76               | 20375           |
# | 31.16s                              | 78.5             | 20983           |
# | 32.16s                              | 80.5             | 21549           |
# | 33.16s                              | 82.5             | 22095           |
# | 34.16s                              | 84.5             | 22648           |
# | 35.16s                              | 86.5             | 23182           |
# | 36.16s                              | 88.5             | 23706           |
# | 37.16s                              | 90.5             | 24237           |
# | 38.16s                              | 92.5             | 24771           |
# | 39.16s                              | 94.5             | 25267           |
# | 40.16s                              | 96.25            | 25772           |
# | 41.16s                              | 98.25            | 26281           |
# | 44.56s                              | 100              | 26729           |
# +-------------------------------------+------------------+-----------------+
# Finalizing lookup tables.
# Generating candidate set for working with new users.
# Finished training in 45.4674s
# recommendations finished on 1000/138493 queries. users per second: 17592.6
# recommendations finished on 2000/138493 queries. users per second: 17140.6
# recommendations finished on 3000/138493 queries. users per second: 15586
# recommendations finished on 4000/138493 queries. users per second: 14854.7
# recommendations finished on 5000/138493 queries. users per second: 14702.2
# recommendations finished on 6000/138493 queries. users per second: 14324.1
# recommendations finished on 7000/138493 queries. users per second: 14094
# recommendations finished on 8000/138493 queries. users per second: 14023.5
# recommendations finished on 9000/138493 queries. users per second: 13926.1
# recommendations finished on 10000/138493 queries. users per second: 13811
# recommendations finished on 11000/138493 queries. users per second: 13650.4
# recommendations finished on 12000/138493 queries. users per second: 13657.4
# recommendations finished on 13000/138493 queries. users per second: 13837.4
# recommendations finished on 14000/138493 queries. users per second: 14009.5
# recommendations finished on 15000/138493 queries. users per second: 14148.8
# recommendations finished on 16000/138493 queries. users per second: 14285.7
# recommendations finished on 17000/138493 queries. users per second: 14276
# recommendations finished on 18000/138493 queries. users per second: 14188.8
# recommendations finished on 19000/138493 queries. users per second: 14143.2
# recommendations finished on 20000/138493 queries. users per second: 14122.2
# recommendations finished on 21000/138493 queries. users per second: 14075
# recommendations finished on 22000/138493 queries. users per second: 14050.3
# recommendations finished on 23000/138493 queries. users per second: 13993.7
# recommendations finished on 24000/138493 queries. users per second: 13982.7
# recommendations finished on 25000/138493 queries. users per second: 13918.3
# recommendations finished on 26000/138493 queries. users per second: 13903.8
# recommendations finished on 27000/138493 queries. users per second: 13976.4
# recommendations finished on 28000/138493 queries. users per second: 14058.6
# recommendations finished on 29000/138493 queries. users per second: 14115.3
# recommendations finished on 30000/138493 queries. users per second: 14188.8
# recommendations finished on 31000/138493 queries. users per second: 14173.7
# recommendations finished on 32000/138493 queries. users per second: 14122.2
# recommendations finished on 33000/138493 queries. users per second: 13809.8
# recommendations finished on 34000/138493 queries. users per second: 13802
# recommendations finished on 35000/138493 queries. users per second: 13783.8
# recommendations finished on 36000/138493 queries. users per second: 13772
# recommendations finished on 37000/138493 queries. users per second: 13765.9
# recommendations finished on 38000/138493 queries. users per second: 13735.3
# recommendations finished on 39000/138493 queries. users per second: 13735.3
# recommendations finished on 40000/138493 queries. users per second: 13740
# recommendations finished on 41000/138493 queries. users per second: 13799.8
# recommendations finished on 42000/138493 queries. users per second: 13852.8
# recommendations finished on 43000/138493 queries. users per second: 13899.1
# recommendations finished on 44000/138493 queries. users per second: 13921.7
# recommendations finished on 45000/138493 queries. users per second: 13900.3
# recommendations finished on 46000/138493 queries. users per second: 13892.5
# recommendations finished on 47000/138493 queries. users per second: 13880.9
# recommendations finished on 48000/138493 queries. users per second: 13861.9
# recommendations finished on 49000/138493 queries. users per second: 13847.5
# recommendations finished on 50000/138493 queries. users per second: 13833.8
# recommendations finished on 51000/138493 queries. users per second: 13824.4
# recommendations finished on 52000/138493 queries. users per second: 13800.7
# recommendations finished on 53000/138493 queries. users per second: 13788.7
# recommendations finished on 54000/138493 queries. users per second: 13794.8
# recommendations finished on 55000/138493 queries. users per second: 13838.7
# recommendations finished on 56000/138493 queries. users per second: 13881.3
# recommendations finished on 57000/138493 queries. users per second: 13919.3
# recommendations finished on 58000/138493 queries. users per second: 13936.1
# recommendations finished on 59000/138493 queries. users per second: 13919.5
# recommendations finished on 60000/138493 queries. users per second: 13903.5
# recommendations finished on 61000/138493 queries. users per second: 13875.5
# recommendations finished on 62000/138493 queries. users per second: 13820.8
# recommendations finished on 63000/138493 queries. users per second: 13813.4
# recommendations finished on 64000/138493 queries. users per second: 13803.2
# recommendations finished on 65000/138493 queries. users per second: 13793.4
# recommendations finished on 66000/138493 queries. users per second: 13772.4
# recommendations finished on 67000/138493 queries. users per second: 13769.1
# recommendations finished on 68000/138493 queries. users per second: 13788
# recommendations finished on 69000/138493 queries. users per second: 13820.3
# recommendations finished on 70000/138493 queries. users per second: 13854.6
# recommendations finished on 71000/138493 queries. users per second: 13844.8
# recommendations finished on 72000/138493 queries. users per second: 13840.6
# recommendations finished on 73000/138493 queries. users per second: 13833.9
# recommendations finished on 74000/138493 queries. users per second: 13819.7
# recommendations finished on 75000/138493 queries. users per second: 13811
# recommendations finished on 76000/138493 queries. users per second: 13802.4
# recommendations finished on 77000/138493 queries. users per second: 13791.7
# recommendations finished on 78000/138493 queries. users per second: 13793.4
# recommendations finished on 79000/138493 queries. users per second: 13773.5
# recommendations finished on 80000/138493 queries. users per second: 13763.6
# recommendations finished on 81000/138493 queries. users per second: 13753.9
# recommendations finished on 82000/138493 queries. users per second: 13779
# recommendations finished on 83000/138493 queries. users per second: 13808.2
# recommendations finished on 84000/138493 queries. users per second: 13836.8
# recommendations finished on 85000/138493 queries. users per second: 13864.9
# recommendations finished on 86000/138493 queries. users per second: 13870
# recommendations finished on 87000/138493 queries. users per second: 13857.5
# recommendations finished on 88000/138493 queries. users per second: 13856.1
# recommendations finished on 89000/138493 queries. users per second: 13841.8
# recommendations finished on 90000/138493 queries. users per second: 13844.9
# recommendations finished on 91000/138493 queries. users per second: 13833.1
# recommendations finished on 92000/138493 queries. users per second: 13836.2
# recommendations finished on 93000/138493 queries. users per second: 13829
# recommendations finished on 94000/138493 queries. users per second: 13801.6
# recommendations finished on 95000/138493 queries. users per second: 13800.9
# recommendations finished on 96000/138493 queries. users per second: 13822.1
# recommendations finished on 97000/138493 queries. users per second: 13844.8
# recommendations finished on 98000/138493 queries. users per second: 13859.3
# recommendations finished on 99000/138493 queries. users per second: 13883.2
# recommendations finished on 100000/138493 queries. users per second: 13887.5
# recommendations finished on 101000/138493 queries. users per second: 13876.4
# recommendations finished on 102000/138493 queries. users per second: 13865.6
# recommendations finished on 103000/138493 queries. users per second: 13858.8
# recommendations finished on 104000/138493 queries. users per second: 13855.7
# recommendations finished on 105000/138493 queries. users per second: 13847.3
# recommendations finished on 106000/138493 queries. users per second: 13831.8
# recommendations finished on 107000/138493 queries. users per second: 13818.4
# recommendations finished on 108000/138493 queries. users per second: 13819.4
# recommendations finished on 109000/138493 queries. users per second: 13813.4
# recommendations finished on 110000/138493 queries. users per second: 13835.2
# recommendations finished on 111000/138493 queries. users per second: 13853.2
# recommendations finished on 112000/138493 queries. users per second: 13874.4
# recommendations finished on 113000/138493 queries. users per second: 13880
# recommendations finished on 114000/138493 queries. users per second: 13873.6
# recommendations finished on 115000/138493 queries. users per second: 13870.8
# recommendations finished on 116000/138493 queries. users per second: 13869.6
# recommendations finished on 117000/138493 queries. users per second: 13858.6
# recommendations finished on 118000/138493 queries. users per second: 13857.5
# recommendations finished on 119000/138493 queries. users per second: 13848.5
# recommendations finished on 120000/138493 queries. users per second: 13845.9
# recommendations finished on 121000/138493 queries. users per second: 13840.2
# recommendations finished on 122000/138493 queries. users per second: 13834.7
# recommendations finished on 123000/138493 queries. users per second: 13835.4
# recommendations finished on 124000/138493 queries. users per second: 13854.7
# recommendations finished on 125000/138493 queries. users per second: 13872.1
# recommendations finished on 126000/138493 queries. users per second: 13890.8
# recommendations finished on 127000/138493 queries. users per second: 13910.8
# recommendations finished on 128000/138493 queries. users per second: 13914
# recommendations finished on 129000/138493 queries. users per second: 13908.1
# recommendations finished on 130000/138493 queries. users per second: 13911.2
# recommendations finished on 131000/138493 queries. users per second: 13902.5
# recommendations finished on 132000/138493 queries. users per second: 13889.5
# recommendations finished on 133000/138493 queries. users per second: 13891.2
# recommendations finished on 134000/138493 queries. users per second: 13884.3
# recommendations finished on 135000/138493 queries. users per second: 13880.3
# recommendations finished on 136000/138493 queries. users per second: 13862.3
# recommendations finished on 137000/138493 queries. users per second: 13757.3
# recommendations finished on 138000/138493 queries. users per second: 13547

# %%
results # the recommendation output
# Out:
# Columns:
# 	userId	int
# 	title	str
# 	score	float
# 	rank	int
#
# Rows: 692465
#
# Data:
# +--------+-------------------------------+-----------------+------+
# | userId |             title             |      score      | rank |
# +--------+-------------------------------+-----------------+------+
# |   3    | Men in Black (a.k.a. MIB) ... |  0.150095128121 |  1   |
# |   3    | Indiana Jones and the Last... |  0.116173562838 |  2   |
# |   3    |      Pulp Fiction (1994)      |  0.116167081231 |  3   |
# |   3    | Ghostbusters (a.k.a. Ghost... | 0.0855018442327 |  4   |
# |   3    | Star Trek: The Motion Pict... | 0.0738446208882 |  5   |
# |   6    |         Eraser (1996)         |  0.470468826592 |  1   |
# |   6    | Star Wars: Episode VI - Re... |  0.245952243606 |  2   |
# |   6    |      Broken Arrow (1996)      |  0.238403196136 |  3   |
# |   6    | Father of the Bride Part I... |  0.227084296445 |  4   |
# |   6    |   Back to the Future (1985)   |  0.214899217089 |  5   |
# +--------+-------------------------------+-----------------+------+
# [692465 rows x 4 columns]
# Note: Only the head of the SFrame is printed.
# You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.

# %% [markdown]
# In the above model creation, we have found the top five highest ranking items for each user. Two users are shown with their corresponding highest ranking items (that they have not rated yet).

# %%
#convert the results to a dataframe
user_rec = results.to_dataframe()
user3_rec = user_rec.loc[user_rec.userId==3]
user3_rec
# Out:
#    userId                                       title     score  rank
# 0       3            Men in Black (a.k.a. MIB) (1997)  0.150095     1
# 1       3   Indiana Jones and the Last Crusade (1989)  0.116174     2
# 2       3                         Pulp Fiction (1994)  0.116167     3
# 3       3  Ghostbusters (a.k.a. Ghost Busters) (1984)  0.085502     4
# 4       3        Star Trek: The Motion Picture (1979)  0.073845     5

# %%
user3_rec_1 = pd.merge(user3_rec,
                 movies,
                 on='title')
user3_rec_1.head()
# Out:
#    userId                                       title     score  rank  \
# 0       3            Men in Black (a.k.a. MIB) (1997)  0.150095     1
# 1       3   Indiana Jones and the Last Crusade (1989)  0.116174     2
# 2       3                         Pulp Fiction (1994)  0.116167     3
# 3       3  Ghostbusters (a.k.a. Ghost Busters) (1984)  0.085502     4
# 4       3        Star Trek: The Motion Picture (1979)  0.073845     5
#
#    movieId                       genres                   poster  year
# 0     1580         Action|Comedy|Sci-Fi  ml-20m/posters/1580.jpg  1997
# 1     1291             Action|Adventure  ml-20m/posters/1291.jpg  1989
# 2      296  Comedy|Crime|Drama|Thriller   ml-20m/posters/296.jpg  1994
# 3     2716         Action|Comedy|Sci-Fi  ml-20m/posters/2716.jpg  1984
# 4     1371             Adventure|Sci-Fi  ml-20m/posters/1371.jpg  1979

# %%
from matplotlib.pyplot import figure, imshow, axis
from matplotlib.image import imread
fig = figure(figsize=(24, 12))

for i in range (len(user3_rec_1)):
    filename=user3_rec_1['poster'].values[i]
    a=fig.add_subplot(1,len(user3_rec_1),i+1)
    image = imread(filename)
    imshow(image)
    axis('off')

# %% [markdown]
# We want to compare the movies that were rated highest by userID = 3 to the movies that were recommended by our recommender.

# %%
user3 = result.loc[(result.userId==3) & (result.rating==5) ].sort_values(by='rating',ascending=False)
user3
# Out:
#           movieId                                              title  \
# 582575         50                         Usual Suspects, The (1995)
# 7603900      1374             Star Trek II: The Wrath of Khan (1982)
# 9661379      2076                                 Blue Velvet (1986)
# 9584202      2046                     Flight of the Navigator (1986)
# 9419513      2009                               Soylent Green (1973)
# 8990032      1909              X-Files: Fight the Future, The (1998)
# 8878650      1831                               Lost in Space (1998)
# 8519623      1676                           Starship Troopers (1997)
# 7619792      1375         Star Trek III: The Search for Spock (1984)
# 7500762      1356                    Star Trek: First Contact (1996)
# 1272800       175                                        Kids (1995)
# 7406190      1321             American Werewolf in London, An (1981)
# 7350231      1304          Butch Cassidy and the Sundance Kid (1969)
# 7160997      1278                          Young Frankenstein (1974)
# 7145544      1276                              Cool Hand Luke (1967)
# 7064775      1270                          Back to the Future (1985)
# 7031562      1266                                  Unforgiven (1992)
# 6967623      1261                 Evil Dead II (Dead by Dawn) (1987)
# 9740298      2093                                Return to Oz (1985)
# 9838780      2117                 1984 (Nineteen Eighty-Four) (1984)
# 9842188      2118                              Dead Zone, The (1983)
# 9947775      2150                     Gods Must Be Crazy, The (1980)
# 12383305     3039                              Trading Places (1983)
# 12358957     3033                                  Spaceballs (1987)
# 12209463     2985                                     RoboCop (1987)
# 12184574     2968                                Time Bandits (1981)
# 12027212     2918                    Ferris Bueller's Day Off (1986)
# 11930377     2872                                   Excalibur (1981)
# 11720859     2791                                   Airplane! (1980)
# 11713223     2788  Monty Python's And Now for Something Completel...
# ...           ...                                                ...
# 4012561       593                   Silence of the Lambs, The (1991)
# 3612354       541                                Blade Runner (1982)
# 3292917       490                                      Malice (1993)
# 3205478       480                               Jurassic Park (1993)
# 3076534       457                               Fugitive, The (1993)
# 2216364       329                      Star Trek: Generations (1994)
# 2129168       318                   Shawshank Redemption, The (1994)
# 2081185       316                                    Stargate (1994)
# 1693179       260          Star Wars: Episode IV - A New Hope (1977)
# 1461603       223                                      Clerks (1994)
# 5612117      1073         Willy Wonka & the Chocolate Factory (1971)
# 5726685      1089                              Reservoir Dogs (1992)
# 6832858      1247                               Graduate, The (1967)
# 5816074      1097                  E.T. the Extra-Terrestrial (1982)
# 6781750      1242                                       Glory (1989)
# 6745746      1240                             Terminator, The (1984)
# 6675915      1230                                  Annie Hall (1977)
# 6604789      1222                           Full Metal Jacket (1987)
# 6577390      1221                     Godfather: Part II, The (1974)
# 6557566      1220                         Blues Brothers, The (1980)
# 6485116      1214                                       Alien (1979)
# 6458708      1213                                  Goodfellas (1990)
# 6401651      1210  Star Wars: Episode VI - Return of the Jedi (1983)
# 6374154      1208                              Apocalypse Now (1979)
# 6334690      1206                         Clockwork Orange, A (1971)
# 6208929      1198  Raiders of the Lost Ark (Indiana Jones and the...
# 6176342      1197                         Princess Bride, The (1987)
# 6131031      1196  Star Wars: Episode V - The Empire Strikes Back...
# 5936136      1129                        Escape from New York (1981)
# 15410243     5060                       M*A*S*H (a.k.a. MASH) (1970)
#
#                                            genres                   poster  \
# 582575                     Crime|Mystery|Thriller    ml-20m/posters/50.jpg
# 7603900          Action|Adventure|Sci-Fi|Thriller  ml-20m/posters/1374.jpg
# 9661379                    Drama|Mystery|Thriller  ml-20m/posters/2076.jpg
# 9584202                 Adventure|Children|Sci-Fi  ml-20m/posters/2046.jpg
# 9419513             Drama|Mystery|Sci-Fi|Thriller  ml-20m/posters/2009.jpg
# 8990032      Action|Crime|Mystery|Sci-Fi|Thriller  ml-20m/posters/1909.jpg
# 8878650                   Action|Adventure|Sci-Fi  ml-20m/posters/1831.jpg
# 8519623                             Action|Sci-Fi  ml-20m/posters/1676.jpg
# 7619792                   Action|Adventure|Sci-Fi  ml-20m/posters/1375.jpg
# 7500762          Action|Adventure|Sci-Fi|Thriller  ml-20m/posters/1356.jpg
# 1272800                                     Drama   ml-20m/posters/175.jpg
# 7406190                    Comedy|Horror|Thriller  ml-20m/posters/1321.jpg
# 7350231                            Action|Western  ml-20m/posters/1304.jpg
# 7160997                            Comedy|Fantasy  ml-20m/posters/1278.jpg
# 7145544                                     Drama  ml-20m/posters/1276.jpg
# 7064775                   Adventure|Comedy|Sci-Fi  ml-20m/posters/1270.jpg
# 7031562                             Drama|Western  ml-20m/posters/1266.jpg
# 6967623              Action|Comedy|Fantasy|Horror  ml-20m/posters/1261.jpg
# 9740298                Adventure|Children|Fantasy  ml-20m/posters/2093.jpg
# 9838780                              Drama|Sci-Fi  ml-20m/posters/2117.jpg
# 9842188                                  Thriller  ml-20m/posters/2118.jpg
# 9947775                          Adventure|Comedy  ml-20m/posters/2150.jpg
# 12383305                                   Comedy  ml-20m/posters/3039.jpg
# 12358957                            Comedy|Sci-Fi  ml-20m/posters/3033.jpg
# 12209463       Action|Crime|Drama|Sci-Fi|Thriller  ml-20m/posters/2985.jpg
# 12184574          Adventure|Comedy|Fantasy|Sci-Fi  ml-20m/posters/2968.jpg
# 12027212                                   Comedy  ml-20m/posters/2918.jpg
# 11930377                        Adventure|Fantasy  ml-20m/posters/2872.jpg
# 11720859                                   Comedy  ml-20m/posters/2791.jpg
# 11713223                                   Comedy  ml-20m/posters/2788.jpg
# ...                                           ...                      ...
# 4012561                     Crime|Horror|Thriller   ml-20m/posters/593.jpg
# 3612354                    Action|Sci-Fi|Thriller   ml-20m/posters/541.jpg
# 3292917                                  Thriller   ml-20m/posters/490.jpg
# 3205478          Action|Adventure|Sci-Fi|Thriller   ml-20m/posters/480.jpg
# 3076534                                  Thriller   ml-20m/posters/457.jpg
# 2216364                    Adventure|Drama|Sci-Fi   ml-20m/posters/329.jpg
# 2129168                               Crime|Drama   ml-20m/posters/318.jpg
# 2081185                   Action|Adventure|Sci-Fi   ml-20m/posters/316.jpg
# 1693179                   Action|Adventure|Sci-Fi   ml-20m/posters/260.jpg
# 1461603                                    Comedy   ml-20m/posters/223.jpg
# 5612117           Children|Comedy|Fantasy|Musical  ml-20m/posters/1073.jpg
# 5726685                    Crime|Mystery|Thriller  ml-20m/posters/1089.jpg
# 6832858                      Comedy|Drama|Romance  ml-20m/posters/1247.jpg
# 5816074                     Children|Drama|Sci-Fi  ml-20m/posters/1097.jpg
# 6781750                                 Drama|War  ml-20m/posters/1242.jpg
# 6745746                    Action|Sci-Fi|Thriller  ml-20m/posters/1240.jpg
# 6675915                            Comedy|Romance  ml-20m/posters/1230.jpg
# 6604789                                 Drama|War  ml-20m/posters/1222.jpg
# 6577390                               Crime|Drama  ml-20m/posters/1221.jpg
# 6557566                     Action|Comedy|Musical  ml-20m/posters/1220.jpg
# 6485116                             Horror|Sci-Fi  ml-20m/posters/1214.jpg
# 6458708                               Crime|Drama  ml-20m/posters/1213.jpg
# 6401651                   Action|Adventure|Sci-Fi  ml-20m/posters/1210.jpg
# 6374154                          Action|Drama|War  ml-20m/posters/1208.jpg
# 6334690               Crime|Drama|Sci-Fi|Thriller  ml-20m/posters/1206.jpg
# 6208929                          Action|Adventure  ml-20m/posters/1198.jpg
# 6176342   Action|Adventure|Comedy|Fantasy|Romance  ml-20m/posters/1197.jpg
# 6131031                   Action|Adventure|Sci-Fi  ml-20m/posters/1196.jpg
# 5936136          Action|Adventure|Sci-Fi|Thriller  ml-20m/posters/1129.jpg
# 15410243                         Comedy|Drama|War  ml-20m/posters/5060.jpg
#
#           year  userId  rating
# 582575    1995       3     5.0
# 7603900   1982       3     5.0
# 9661379   1986       3     5.0
# 9584202   1986       3     5.0
# 9419513   1973       3     5.0
# 8990032   1998       3     5.0
# 8878650   1998       3     5.0
# 8519623   1997       3     5.0
# 7619792   1984       3     5.0
# 7500762   1996       3     5.0
# 1272800   1995       3     5.0
# 7406190   1981       3     5.0
# 7350231   1969       3     5.0
# 7160997   1974       3     5.0
# 7145544   1967       3     5.0
# 7064775   1985       3     5.0
# 7031562   1992       3     5.0
# 6967623   1987       3     5.0
# 9740298   1985       3     5.0
# 9838780   1984       3     5.0
# 9842188   1983       3     5.0
# 9947775   1980       3     5.0
# 12383305  1983       3     5.0
# 12358957  1987       3     5.0
# 12209463  1987       3     5.0
# 12184574  1981       3     5.0
# 12027212  1986       3     5.0
# 11930377  1981       3     5.0
# 11720859  1980       3     5.0
# 11713223  1971       3     5.0
# ...        ...     ...     ...
# 4012561   1991       3     5.0
# 3612354   1982       3     5.0
# 3292917   1993       3     5.0
# 3205478   1993       3     5.0
# 3076534   1993       3     5.0
# 2216364   1994       3     5.0
# 2129168   1994       3     5.0
# 2081185   1994       3     5.0
# 1693179   1977       3     5.0
# 1461603   1994       3     5.0
# 5612117   1971       3     5.0
# 5726685   1992       3     5.0
# 6832858   1967       3     5.0
# 5816074   1982       3     5.0
# 6781750   1989       3     5.0
# 6745746   1984       3     5.0
# 6675915   1977       3     5.0
# 6604789   1987       3     5.0
# 6577390   1974       3     5.0
# 6557566   1980       3     5.0
# 6485116   1979       3     5.0
# 6458708   1990       3     5.0
# 6401651   1983       3     5.0
# 6374154   1979       3     5.0
# 6334690   1971       3     5.0
# 6208929   1981       3     5.0
# 6176342   1987       3     5.0
# 6131031   1980       3     5.0
# 5936136   1981       3     5.0
# 15410243  1970       3     5.0
#
# [76 rows x 7 columns]

# %% [markdown]
# As we can see from the above output, this user gave highest ratings (=5) to SciFi/Thriller/Adventure types of movies (total 76 ratings at scale of 5). Our model correctly recommended the same types of movies for this user.

# %%
#to select 5 posters to print out of 76 posters shown above. 
fig = figure(figsize=(24, 12))

for i in range (5):
    filename=user3['poster'].values[i]
    a=fig.add_subplot(1,5,i+1)
    image = imread(filename)
    imshow(image)
    axis('off')

# %% [markdown]
# <a href="#top">Back to Top</a>
# ### Modeling and Evaluation - Summarize The Ramifications<a id="Modeling_and_Evaluation_Summarize_The_Ramifications"></a>
# * Describe your results. What findings are the most interesting and why?

# %% [markdown]
# 1. From the evaluation of the item-item collaborative filtering (CF) scheme we make some important findings. First, the item-similarity scheme provides better quality of predictions than the ranking-factorization scheme in the movie dataset presented here. The improvement in quality is consistent over different precision and recall pairs. Secondly, due to the model-based approach, it is possible to retain only a small subset of items and produce reasonably good prediction quality. Our results support that claim. Using item_similarity recommender on only 100 users' input data (out of total 138,493 users), we were able to achieve a mean precision at least 30% with recommendation items up to 7 movies. We noticed that the mean precision is at 42% when giving just one movie recommendation. Therefore, the item-similarity scheme is capable in addressing the two most important challenges of recommender systems for E-Commerce: quality of prediction and high performance.
#
# 2. Recommender systems are a powerful technology for extracting additional value for a business from its user databases. These systems help users find items they want to buy from a business. Recommender systems benefit users by enabling them to find items they like. Conversely, they help the business by generating more sales. Recommender systems are rapidly becoming a crucial tool in E-commerce on the Web. Recommender systems are being stressed by the huge volume of user data in existing corporate databases, and will be stressed even more by the increasing volume of user data available on the Web. New technologies are needed that can dramatically improve the scalability of recommender systems.
#
# 3. Here we presented and evaluated item-item based algorithms for CF-based recommender systems. Our results show that item-based techniques hold the promise of allowing CF-based algorithms to scale to large data sets and at the same time produce high-quality recommendations.

# %% [markdown]
# <a href="#top">Back to Top</a>
# ### Deployment<a id="Deployment"></a>
# * Be critical of your performance and tell the reader how you current model might be usable by other parties. Did you achieve your goals? If not, can you reign in the utility of your modeling?
#     - How useful is your model for interested parties (i.e., the companies or organizations that might want to use it)?
#     - How would your deploy your model for interested parties?
#     - What other data should be collected?
#     - How often would the model need to be updated, etc.?

# %% [markdown]
# In online media companies, regular users are looking for ever improving personalized experiences. As they use the system more, the recommendations should become more specific and more accurate. When a new user comes to a site (cold starts) and we know nothing about them we can not give them good recommendations because our model does not have any history or preference for those users. There are some ways to make our recommended system useful such as request user to pick his/her preferences when signing up or rather than having a personalized system, we can collate the behavior of all users to make more general recommendations.
#
# An recommendation system will never be able to match User A to User B with perfect results, as their tastes will diverge at some point. If two users both rate 10 drama movies as good but differ in their opinion of the Comedy, they are still a very strong match.
#
# in reality, recommendation systems don’t set a threshold when looking for compatibility between people; they look for the best possible match. If we have a user, Allen, who has a 95% compatibility with Chad, 80% with Ian, and 30% with Dave, the system will start by looking at Chad when deciding if Allen will like a certain movie. The more users we have in the data set, the more likely it is that a person with a high compatibility will give a response that the system can leverage.
#
# After implementing our recommendation system it is important to make sure that it is working. One of the best approach to test our RS is A/B testing. By creating 2 different versions of our web page — one which utilizes our Recommendation System and one which does not — different customers see different versions of the website and we are able to observe which is more effective, by measuring how many of users watch movies that we recommended to them. We also can use this test to see how often our model need to be updated.

# %% [markdown]
# <a href="#top">Back to Top</a>
# ### Exceptional Work<a id="Exceptional_Work"></a>

# %% [markdown]
# ### 1.  Creating a User-Item Matrices to find movies based on a single selection
# We use SVD (Singular-Value Decomposition) to reduce the matrix.

# %% [markdown]
# #### Convert the Data to a User-Item Matrix

# %%
#the original dataset is too big, more than 20 million entries, causing errors on running.
#so we had to randomly sample 1% entries for this demonstration. 
result2 = result1.sample(frac=0.01, random_state=1)
result2.shape
# Out:
# (200003, 3)

# %%
#import TruncatedSVD from sklearn
from sklearn.decomposition import TruncatedSVD

#convert the Data to a User-Item Matrix based on just the rating, userId and title data
#TruncatedSVD will not allow NULL so using the fill_value to produce 0 for the NULL
rating_pivot = result2.pivot_table(values='rating', index='userId', columns='title', fill_value=0)
#looking at the first 5 entries
rating_pivot.head()
# Out:
# title   "Great Performances" Cats (1998)  $9.99 (2008)  \
# userId
# 1                                    0.0             0
# 3                                    0.0             0
# 6                                    0.0             0
# 7                                    0.0             0
# 11                                   0.0             0
#
# title   'Hellboy': The Seeds of Creation (2004)  'Salem's Lot (2004)  \
# userId
# 1                                           0.0                    0
# 3                                           0.0                    0
# 6                                           0.0                    0
# 7                                           0.0                    0
# 11                                          0.0                    0
#
# title   'Til There Was You (1997)  'burbs, The (1989)  'night Mother (1986)  \
# userId
# 1                               0                 0.0                   0.0
# 3                               0                 0.0                   0.0
# 6                               0                 0.0                   0.0
# 7                               0                 0.0                   0.0
# 11                              0                 0.0                   0.0
#
# title   (500) Days of Summer (2009)  *batteries not included (1987)  \
# userId
# 1                               0.0                             0.0
# 3                               0.0                             0.0
# 6                               0.0                             0.0
# 7                               0.0                             0.0
# 11                              0.0                             0.0
#
# title   ...All the Marbles (California Dolls, The) (1981)  ...  [REC] (2007)  \
# userId                                                     ...
# 1                                                     0.0  ...           0.0
# 3                                                     0.0  ...           0.0
# 6                                                     0.0  ...           0.0
# 7                                                     0.0  ...           0.0
# 11                                                    0.0  ...           0.0
#
# title   [REC]² (2009)  a/k/a Tommy Chong (2005)  eXistenZ (1999)  \
# userId
# 1                   0                       0.0              0.0
# 3                   0                       0.0              0.0
# 6                   0                       0.0              0.0
# 7                   0                       0.0              0.0
# 11                  0                       0.0              0.0
#
# title   iSteve (2013)  loudQUIETloud: A Film About the Pixies (2006)  \
# userId
# 1                 0.0                                            0.0
# 3                 0.0                                            0.0
# 6                 0.0                                            0.0
# 7                 0.0                                            0.0
# 11                0.0                                            0.0
#
# title   xXx (2002)  xXx: State of the Union (2005)  ¡Three Amigos! (1986)  \
# userId
# 1              0.0                             0.0                    0.0
# 3              0.0                             0.0                    0.0
# 6              0.0                             0.0                    0.0
# 7              0.0                             0.0                    0.0
# 11             0.0                             0.0                    0.0
#
# title   À nous la liberté (Freedom for Us) (1931)
# userId
# 1                                               0
# 3                                               0
# 6                                               0
# 7                                               0
# 11                                              0
#
# [5 rows x 10379 columns]

# %%
#looking at the shape of the matrix
rating_pivot.shape
# Out:
# (75277, 10379)

# %%
#transposing the rating_pivot using the T command
rating_transpose = rating_pivot.values.T

#check to see if things flipped
rating_transpose.shape
# Out:
# (10379L, 75277L)

# %% [markdown]
# #### Running SVD (Singular-Value Decomposition) to reduce the matrix

# %%
#using 12 components
rating_SVD = TruncatedSVD(n_components=12, random_state=42)
result_maxrix = rating_SVD.fit_transform(rating_transpose)
#looking at the shape of the smaller matrix
result_maxrix.shape
# Out:
# (10379L, 12L)

# %% [markdown]
# #### Create a Pearson's R Correlation for every movie
# We can use this to compare one movie to others that someone may like based on user preferences.

# %%
result_corr = np.corrcoef(result_maxrix)
#looking at the shape
result_corr.shape
# Out:
# (10379L, 10379L)

# %% [markdown]
# #### Test the system on one of our favorite movies: The Shawshank Redemption

# %%
# create a movie names index
movie_names = rating_pivot.columns
movie_list = list(movie_names)

#pull the index number of the movie you want to find similarities too
Shawshank = movie_list.index('Shawshank Redemption, The (1994)')
#print out the index of our movie
print(Shawshank)
# Out:
# 8227

# %% [markdown]
# #### Get the correlation result of our movie

# %%
corr_Shawshank = result_corr[Shawshank]
#This is shape of the Pearson's R Correlation for one movie.
#It shows 13390 results for this one movie. This is how it compares to all the others in the data set.
corr_Shawshank.shape
# Out:
# (10379L,)

# %% [markdown]
# #### Finding highly correlated movies

# %%
#finding some of the top correlated movies to ours
list(movie_names[(corr_Shawshank < 1.0) & (corr_Shawshank > 0.9995)])
# Out:
# ['Firelight (1997)',
#  'Frank (2014)',
#  'Killing Them Softly (2012)',
#  'Last Days on Mars, The (2013)',
#  'Memory of a Killer, The (Zaak Alzheimer, De) (2003)',
#  'Picture of Dorian Gray, The (1945)',
#  'Rawhead Rex (1986)',
#  'Snow White (1916)',
#  'Sudden Manhattan (1997)',
#  'Triggermen (2002)',
#  'Warlock (1959)']

# %%
#finding the highest correlated movie to ours
MovieList = list(movie_names[(corr_Shawshank < 1.0) & (corr_Shawshank > 0.9998)])
MovieList
# Out:
# ['Frank (2014)',
#  'Killing Them Softly (2012)',
#  'Memory of a Killer, The (Zaak Alzheimer, De) (2003)',
#  'Rawhead Rex (1986)',
#  'Snow White (1916)']

# %% [markdown]
# #### Showing the posters of recommended movies

# %%
#find the movieId for each movie in MovieList
dict = {'title': MovieList}
df = pd.DataFrame(dict)
print(df)

df1 = pd.merge(df, movies) 
print(df1)
# Out:
#                                                title
# 0                                       Frank (2014)
# 1                         Killing Them Softly (2012)
# 2  Memory of a Killer, The (Zaak Alzheimer, De) (...
# 3                                 Rawhead Rex (1986)
# 4                                  Snow White (1916)
#                                                title  movieId  \
# 0                                       Frank (2014)   112421
# 1                         Killing Them Softly (2012)    97860
# 2  Memory of a Killer, The (Zaak Alzheimer, De) (...    27828
# 3                                 Rawhead Rex (1986)     2992
# 4                                  Snow White (1916)    72921
#
#                         genres                     poster  year
# 0         Comedy|Drama|Mystery  ml-20m/posters/112421.jpg  2014
# 1         Crime|Drama|Thriller   ml-20m/posters/97860.jpg  2012
# 2  Action|Crime|Drama|Thriller   ml-20m/posters/27828.jpg  2003
# 3              Horror|Thriller    ml-20m/posters/2992.jpg  1986
# 4              Fantasy|Romance   ml-20m/posters/72921.jpg  1916

# %%
from matplotlib.pyplot import figure, imshow, axis
from matplotlib.image import imread

fig = figure(figsize=(24, 12))

for i in range (len(df1)):
    id = df1.movieId.values[i]
    filename='ml-20m/posters/'+str(id)+'.jpg'
    a=fig.add_subplot(1,len(df1),i+1)
    image = imread(filename)
    imshow(image)
    axis('off')
