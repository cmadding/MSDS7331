# %% [markdown]
# # Data Mining 7331 - Fall 2019
# ## Lab 3 - Use collaborative filtering to build a custom recommendation system
#
# * **Allen Ansari**
# * **Chad Madding**
# * **Yongjun (Ian) Chu**

# %% [markdown]
# ### Table of Contents<a id="top"></a>
# * **[Business Understanding](#Business_Understanding)**
#     * **[10 points]** Describe the purpose of the data set you selected (i.e., why was this data collected in the first place?). How will you measure the effectiveness of a good algorithm? Why does your chosen validation method make sense for this specific dataset and the stakeholders needs?
# * **[Data Understanding - Description](#Data_Understanding_Description)**
#     * **[10 points]** Describe the meaning and type of data (scale, values, etc.) for each attribute in the data file. Verify data quality: Are there missing values? Duplicate data? Outliers? Are those mistakes? How do you deal with these problems?
# * **[Data Understanding - Visualization](#Data_Understanding_Visualization)**
#     * **[10 points]** Visualize any important attributes appropriately. Important: Provide an interpretation for any charts or graphs.
# * **[Modeling and Evaluation - Train & Adjust Parameters](#Modeling_and_Evaluation_Train_and_adjust_parameters)**
#     * **[10 points]** Create user-item matrices or item-item matrices using collaborative filtering.
# * **[Modeling and Evaluation - Evaluate & Compare](#Modeling_and_Evaluation_Evaluate_and_Compare)**
#     * **[10 points]** Determine performance of the recommendations using different performance measures and explain what each measure.
# * **[Modeling and Evaluation - Visualize Results](#Modeling_and_Evaluation_Visualize_Results)**
#     * **[10 points]** Use tables/visualization to discuss the found results. Explain each visualization in detail.
# * **[Modeling and Evaluation - Summarize The Ramifications](#Modeling_and_Evaluation_Summarize_The_Ramifications)**
#     * **[20 points]** Describe your results. What findings are the most interesting and why?
# * **[Deployment](#Deployment)**
#     * **[10 points]** Be critical of your performance and tell the reader how you current model might be usable by other parties. Did you achieve your goals? If not, can you reign in the utility of your modeling?
#         - How useful is your model for interested parties (i.e., the companies or organizations that might want to use it)?
#         - How would your deploy your model for interested parties?
#         - What other data should be collected?
#         - How often would the model need to be updated, etc.?
# * **[Exceptional Work](#Exceptional_Work)**
#     * **[10 points]** You have free reign to provide additional analyses or combine analyses.

# %% [markdown]
# <a href="#top">Back to Top</a>
# ### Business Understanding<a id="Business Understanding"></a>
# * Describe the purpose of the data set you selected (i.e., why was this data collected in the first place?). How will you measure the effectiveness of a good algorithm? Why does your chosen validation method make sense for this specific dataset and the stakeholders needs?

# %% [markdown]
# <a href="#top">Back to Top</a>
# ### Data Understanding - Description<a id="Data_Understanding_Description"></a>
# * Describe the meaning and type of data (scale, values, etc.) for each attribute in the data file. Verify data quality: Are there missing values? Duplicate data? Outliers? Are those mistakes? How do you deal with these problems?
#
# This dataset (ml-20m) describes 5-star rating and free-text tagging activity from [MovieLens](http://movielens.org), a movie recommendation service. It contains 20000263 ratings and 465564 tag applications across 27278 movies. These data were created by 138493 users between January 09, 1995 and March 31, 2015. This dataset was generated on March 31, 2015, and updated on October 17, 2016 to update links.csv and add genome-* files.
#
# Users were selected at random for inclusion. All selected users had rated at least 20 movies. No demographic information is included. Each user is represented by an id, and no other information is provided.
#
# The data are contained in six files, `genome-scores.csv`, `genome-tags.csv`, `links.csv`, `movies.csv`, `ratings.csv` and `tags.csv`. For this projecct, we are only concerned about movies.csv and ratings.csv.
#
# This and other GroupLens data sets are publicly available for download at <http://grouplens.org/datasets/>.

# %%
#import of libraries
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
from scipy import spatial

#enable inline plotting
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

import re
import os

# %%
#import of data
print(os.listdir("ml-20m"))

#genomescores = pd.read_csv("ml-20m/genome-scores.csv")
#genometags = pd.read_csv("ml-20m/genome-tags.csv")
#links = pd.read_csv("ml-20m/links.csv")
movies = pd.read_csv("ml-20m/movies.csv")
ratings = pd.read_csv("ml-20m/ratings.csv")
#tags = pd.read_csv("ml-20m/tags.csv")
# Out:
# ['.gitignore', 'genome-scores.csv', 'genome-tags.csv', 'graphlabDF.csv', 'links.csv', 'mergedDF.csv', 'movies.csv', 'posters', 'ratings.csv', 'README.txt', 'result1.csv', 'tags.csv']

# %%
print(movies.head())
print(movies.info())
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27278 entries, 0 to 27277
# Data columns (total 3 columns):
# movieId    27278 non-null int64
# title      27278 non-null object
# genres     27278 non-null object
# dtypes: int64(1), object(2)
# memory usage: 639.4+ KB
# None

# %%
print(ratings.head())
print(ratings.info())
# Out:
#    userId  movieId  rating   timestamp
# 0       1        2     3.5  1112486027
# 1       1       29     3.5  1112484676
# 2       1       32     3.5  1112484819
# 3       1       47     3.5  1112484727
# 4       1       50     3.5  1112484580
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000263 entries, 0 to 20000262
# Data columns (total 4 columns):
# userId       int64
# movieId      int64
# rating       float64
# timestamp    int64
# dtypes: float64(1), int64(3)
# memory usage: 610.4 MB
# None

# %%
result = pd.merge(movies,
                 ratings[['userId', 'movieId', 'rating']],
                 on='movieId', how='inner')
print(result.head())
print(result.info())
# Out:
#    movieId             title                                       genres  \
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 2        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 3        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 4        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
#
#    userId  rating
# 0       3     4.0
# 1       6     5.0
# 2       8     4.0
# 3      10     4.0
# 4      11     4.5
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20000263 entries, 0 to 20000262
# Data columns (total 5 columns):
# movieId    int64
# title      object
# genres     object
# userId     int64
# rating     float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 915.5+ MB
# None

# %%
result1= result[["userId", "title", "rating"]]
print(result1.head())
print(result1.info())
# Out:
#    userId             title  rating
# 0       3  Toy Story (1995)     4.0
# 1       6  Toy Story (1995)     5.0
# 2       8  Toy Story (1995)     4.0
# 3      10  Toy Story (1995)     4.0
# 4      11  Toy Story (1995)     4.5
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20000263 entries, 0 to 20000262
# Data columns (total 3 columns):
# userId    int64
# title     object
# rating    float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 610.4+ MB
# None

# %%
#find what movies got the most ratings
result1.groupby('title')['rating'].count().sort_values(ascending=False).head(10)
# Out:
# title
# Pulp Fiction (1994)                          67310
# Forrest Gump (1994)                          66172
# Shawshank Redemption, The (1994)             63366
# Silence of the Lambs, The (1991)             63299
# Jurassic Park (1993)                         59715
# Star Wars: Episode IV - A New Hope (1977)    54502
# Braveheart (1995)                            53769
# Terminator 2: Judgment Day (1991)            52244
# Matrix, The (1999)                           51334
# Schindler's List (1993)                      50054
# Name: rating, dtype: int64

# %%
#Export our data set to use for GraphLab
result1.to_csv(r'ml-20m\result1.csv', index = None, header=True)

# %% [markdown]
# <a href="#top">Back to Top</a>
# ### Data Understanding - Visualization<a id="Data_Understanding_Visualization"></a>
# * Visualize any important attributes appropriately. Important: Provide an interpretation for any charts or graphs.

# %%
#looking at the rating averages
avg_ratings= result1.groupby('title', as_index=False).mean()

avg_ratings.hist(column='rating', figsize=(10,5))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000000000A8FF8C8>]],
#       dtype=object)

# %%
avg_ratings.head()
# Out:
#                                                title        userId    rating
# 0                   "Great Performances" Cats (1998)  66414.658065  2.748387
# 1  #chicagoGirl: The Social Network Takes on a Di...  65392.666667  3.666667
# 2                                 $ (Dollars) (1971)  83316.958333  2.833333
# 3                                    $5 a Day (2008)  57626.461538  2.871795
# 4                                       $9.99 (2008)  73360.909091  3.009091

# %%
#looking at the distribution of the ratings
result1.hist(column='rating', figsize=(10,5))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000000000B11D4C8>]],
#       dtype=object)

# %% [markdown]
# <a href="#top">Back to Top</a>
# ### Modeling and Evaluation - Train & Adjust Parameters<a id="Modeling_and_Evaluation_Train_and_adjust_parameters"></a>
# * Create user-item matrices or item-item matrices using collaborative filtering.
#
# We will be using a user-item matrices for our recommendation system. The utility matrices will be sparce due to the fact that every user did not review every movie. So in the data we are more likely to see mostly null values.
#
# We will use matrix factorization to build recommender systems. Specifically, we will use item_similarity and ranking_factorization recommenders from GraphLab Create. First, we would like to find the best parameter setting for each recommender.

# %%
# Import Graphlab and load the data file to build a recommendation system

import graphlab as gl

data = gl.SFrame.read_csv("ml-20m/result1.csv", 
                          column_type_hints={"rating":float})
#model = gl.recommender.create(data, user_id="userId", item_id="movieId", target="rating")
#results = model.recommend(users=None, k=5)
#model.save("my_model")
# Out:
# This non-commercial license of GraphLab Create for academic use is assigned to cmadding@smu.edu and will expire on November 18, 2020.
# [INFO] graphlab.cython.cy_server: GraphLab Create v2.1 started. Logging: C:\Users\04616598\AppData\Local\Temp\graphlab_server_1574684403.log.0
# Finished parsing file C:\Users\04616598\BSync\Box Sync\Documents\Data Sciance\msds_7331MachineLearningI\MSDS7331\Lab03\ml-20m\result1.csv
# Parsing completed. Parsed 100 lines in 0.643321 secs.
# Read 1528914 lines. Lines per second: 2.23471e+006
# Finished parsing file C:\Users\04616598\BSync\Box Sync\Documents\Data Sciance\msds_7331MachineLearningI\MSDS7331\Lab03\ml-20m\result1.csv
# Parsing completed. Parsed 20000263 lines in 5.48337 secs.

# %%
#generate a train and a test sub-datasets for parameter tuning and performance comparison
train, test = gl.recommender.util.random_split_by_user(data, random_seed = 75205,
                                                    user_id="userId", item_id="title",
                                                    max_num_users=100, item_test_proportion=0.2)

# %%
print(test)
# Out:
# +--------+-------------------------------+--------+
# | userId |             title             | rating |
# +--------+-------------------------------+--------+
# | 29110  |        Toy Story (1995)       |  5.0   |
# | 75676  |        Toy Story (1995)       |  5.0   |
# | 115585 |        Toy Story (1995)       |  4.0   |
# | 118929 |        Toy Story (1995)       |  4.0   |
# | 120813 |        Toy Story (1995)       |  4.0   |
# | 49190  |         Jumanji (1995)        |  3.0   |
# | 63232  |         Jumanji (1995)        |  2.5   |
# | 104017 |    Grumpier Old Men (1995)    |  1.5   |
# | 104017 |    Waiting to Exhale (1995)   |  1.5   |
# | 37402  | Father of the Bride Part I... |  3.0   |
# +--------+-------------------------------+--------+
# [2512 rows x 3 columns]
# Note: Only the head of the SFrame is printed.
# You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.

# %% [markdown]
# #### Find the best parameters for item_similarity recommender

# %% [markdown]
# The graphlab method, "model_paramter_search", doesn't support the item_similarity_recommender currently.
# We have to manually find the best parameters. There are essentially only two parameters that may need to be optimized: only_top_k and similarity_type. Since our user_item matrix obtained is sparse, choosing "cosine" is the best choice. Therefore, we only need to optimized the values for only_top_k. Here we are to find which one gives the best validation results among 5 values: 5,10,15,20,25. The default value is 64. However, bigger value will require significantly more computational power. We feel like that choosing 5 to 25 is a reasonable range.

# %%
#find the best parameter for only_top_k
from IPython.display import display
from IPython.display import Image

gl.canvas.set_target('ipynb')

top_k = [5,10,15,20,25]
item_item = []

for i in range(len(top_k)):
    item_simi = gl.recommender.item_similarity_recommender.create(train, 
                                  user_id="userId", 
                                  item_id="title", 
                                  target="rating",
                                  only_top_k= top_k[i],
                                  similarity_type="cosine")
    
    item_item.append(item_simi)
# Out:
# Recsys training: model = item_similarity
# Preparing data set.
#     Data has 19997751 observations with 138493 users and 26729 items.
#     Data prepared in: 10.5271s
# Training model from provided data.
# Gathering per-item and per-user statistics.
# +--------------------------------+------------+
# | Elapsed Time (Item Statistics) | % Complete |
# +--------------------------------+------------+
# | 2.991ms                        | 0.5        |
# | 160.578ms                      | 100        |
# +--------------------------------+------------+
# Setting up lookup tables.
# Processing data in one pass using dense lookup tables.
# +-------------------------------------+------------------+-----------------+
# | Elapsed Time (Constructing Lookups) | Total % Complete | Items Processed |
# +-------------------------------------+------------------+-----------------+
# | 1.68s                               | 0                | 0               |
# | 2.68s                               | 2.25             | 605             |
# | 3.68s                               | 5                | 1384            |
# | 4.68s                               | 7.75             | 2104            |
# | 5.68s                               | 10.5             | 2812            |
# | 6.68s                               | 13.25            | 3543            |
# | 7.69s                               | 15.75            | 4263            |
# | 8.68s                               | 18.5             | 4983            |
# | 9.68s                               | 21.5             | 5771            |
# | 10.68s                              | 24               | 6466            |
# | 11.68s                              | 26.75            | 7172            |
# | 12.68s                              | 29.5             | 7892            |
# | 13.69s                              | 33               | 8858            |
# | 14.69s                              | 36               | 9629            |
# | 15.68s                              | 39               | 10439           |
# | 16.69s                              | 41.5             | 11118           |
# | 17.68s                              | 44.5             | 11955           |
# | 18.69s                              | 48               | 12858           |
# | 19.69s                              | 51               | 13669           |
# | 20.68s                              | 54               | 14465           |
# | 21.68s                              | 57               | 15261           |
# | 22.68s                              | 59.75            | 16032           |
# | 23.68s                              | 62.75            | 16796           |
# | 24.68s                              | 65.5             | 17533           |
# | 25.68s                              | 68               | 18225           |
# | 26.68s                              | 70.5             | 18888           |
# | 27.68s                              | 73               | 19568           |
# | 28.68s                              | 75.5             | 20213           |
# | 29.68s                              | 78               | 20901           |
# | 30.68s                              | 80.5             | 21563           |
# | 31.68s                              | 82.75            | 22137           |
# | 32.68s                              | 85               | 22740           |
# | 33.68s                              | 87               | 23304           |
# | 34.68s                              | 89               | 23850           |
# | 35.68s                              | 91               | 24370           |
# | 36.68s                              | 93               | 24907           |
# | 37.68s                              | 95.25            | 25459           |
# | 38.68s                              | 97.25            | 26018           |
# | 39.68s                              | 99.25            | 26580           |
# | 41.97s                              | 100              | 26729           |
# +-------------------------------------+------------------+-----------------+
# Finalizing lookup tables.
# Generating candidate set for working with new users.
# Finished training in 43.5625s
# Recsys training: model = item_similarity
# Preparing data set.
#     Data has 19997751 observations with 138493 users and 26729 items.
#     Data prepared in: 11.0793s
# Training model from provided data.
# Gathering per-item and per-user statistics.
# +--------------------------------+------------+
# | Elapsed Time (Item Statistics) | % Complete |
# +--------------------------------+------------+
# | 1.995ms                        | 0.5        |
# | 171.541ms                      | 100        |
# +--------------------------------+------------+
# Setting up lookup tables.
# Processing data in one pass using dense lookup tables.
# +-------------------------------------+------------------+-----------------+
# | Elapsed Time (Constructing Lookups) | Total % Complete | Items Processed |
# +-------------------------------------+------------------+-----------------+
# | 1.74s                               | 0                | 0               |
# | 2.74s                               | 2.25             | 664             |
# | 3.74s                               | 5.25             | 1433            |
# | 4.74s                               | 8                | 2153            |
# | 5.74s                               | 10.25            | 2791            |
# | 6.74s                               | 12.75            | 3449            |
# | 7.74s                               | 15.25            | 4085            |
# | 8.74s                               | 17.75            | 4765            |
# | 9.74s                               | 20.75            | 5562            |
# | 10.74s                              | 22.75            | 6086            |
# | 11.74s                              | 24.5             | 6614            |
# | 12.74s                              | 26.75            | 7203            |
# | 13.74s                              | 29.5             | 7941            |
# | 14.74s                              | 32.5             | 8747            |
# | 15.74s                              | 36               | 9650            |
# | 16.75s                              | 39.75            | 10681           |
# | 17.74s                              | 43.25            | 11568           |
# | 18.74s                              | 46.25            | 12426           |
# | 19.74s                              | 49.5             | 13251           |
# | 20.74s                              | 52.5             | 14046           |
# | 21.74s                              | 55               | 14754           |
# | 22.74s                              | 57.25            | 15303           |
# | 23.74s                              | 59.5             | 15961           |
# | 24.74s                              | 62.25            | 16659           |
# | 25.74s                              | 64.5             | 17291           |
# | 26.74s                              | 67.5             | 18063           |
# | 27.74s                              | 70               | 18769           |
# | 28.74s                              | 72.75            | 19446           |
# | 29.74s                              | 75               | 20061           |
# | 30.74s                              | 77               | 20621           |
# | 31.74s                              | 79.5             | 21306           |
# | 32.74s                              | 82               | 21935           |
# | 33.74s                              | 84.25            | 22565           |
# | 34.74s                              | 86.5             | 23171           |
# | 35.74s                              | 88.5             | 23698           |
# | 36.74s                              | 90.75            | 24256           |
# | 37.74s                              | 92.75            | 24815           |
# | 38.74s                              | 94.75            | 25367           |
# | 39.74s                              | 97               | 25936           |
# | 40.74s                              | 98.75            | 26452           |
# | 42.95s                              | 100              | 26729           |
# +-------------------------------------+------------------+-----------------+
# Finalizing lookup tables.
# Generating candidate set for working with new users.
# Finished training in 43.4899s
# Recsys training: model = item_similarity
# Preparing data set.
#     Data has 19997751 observations with 138493 users and 26729 items.
#     Data prepared in: 11.3077s
# Training model from provided data.
# Gathering per-item and per-user statistics.
# +--------------------------------+------------+
# | Elapsed Time (Item Statistics) | % Complete |
# +--------------------------------+------------+
# | 2.992ms                        | 0.5        |
# | 193.482ms                      | 100        |
# +--------------------------------+------------+
# Setting up lookup tables.
# Processing data in one pass using dense lookup tables.
# +-------------------------------------+------------------+-----------------+
# | Elapsed Time (Constructing Lookups) | Total % Complete | Items Processed |
# +-------------------------------------+------------------+-----------------+
# | 1.57s                               | 0                | 0               |
# | 2.57s                               | 2.5              | 711             |
# | 3.57s                               | 5                | 1391            |
# | 4.57s                               | 7.5              | 2015            |
# | 5.57s                               | 9.75             | 2617            |
# | 6.57s                               | 12               | 3236            |
# | 7.57s                               | 14.5             | 3920            |
# | 8.57s                               | 17.25            | 4627            |
# | 9.57s                               | 19.75            | 5299            |
# | 10.57s                              | 22.25            | 5949            |
# | 11.56s                              | 24.5             | 6591            |
# | 12.56s                              | 27               | 7240            |
# | 13.57s                              | 29.75            | 7991            |
# | 14.57s                              | 33               | 8857            |
# | 15.56s                              | 36               | 9640            |
# | 16.57s                              | 39               | 10431           |
# | 17.56s                              | 41.75            | 11162           |
# | 18.56s                              | 44.5             | 11940           |
# | 19.57s                              | 47.5             | 12708           |
# | 20.57s                              | 50.75            | 13569           |
# | 21.56s                              | 53.75            | 14385           |
# | 22.56s                              | 56.5             | 15113           |
# | 23.56s                              | 58.75            | 15749           |
# | 24.56s                              | 61.25            | 16387           |
# | 25.56s                              | 63.75            | 17053           |
# | 26.56s                              | 66               | 17680           |
# | 27.56s                              | 68.75            | 18394           |
# | 28.56s                              | 71               | 19026           |
# | 29.56s                              | 73.5             | 19678           |
# | 30.56s                              | 76               | 20337           |
# | 31.56s                              | 78.25            | 20964           |
# | 32.56s                              | 80.75            | 21625           |
# | 33.56s                              | 83               | 22228           |
# | 34.56s                              | 85               | 22728           |
# | 35.56s                              | 87               | 23282           |
# | 36.56s                              | 89.25            | 23876           |
# | 37.57s                              | 91               | 24366           |
# | 38.56s                              | 92.75            | 24848           |
# | 39.56s                              | 94.75            | 25350           |
# | 40.56s                              | 96.75            | 25871           |
# | 41.56s                              | 98.75            | 26414           |
# | 43.93s                              | 100              | 26729           |
# +-------------------------------------+------------------+-----------------+
# Finalizing lookup tables.
# Generating candidate set for working with new users.
# Finished training in 44.4985s
# Recsys training: model = item_similarity
# Preparing data set.
#     Data has 19997751 observations with 138493 users and 26729 items.
#     Data prepared in: 11.202s
# Training model from provided data.
# Gathering per-item and per-user statistics.
# +--------------------------------+------------+
# | Elapsed Time (Item Statistics) | % Complete |
# +--------------------------------+------------+
# | 1.994ms                        | 0.5        |
# | 180.514ms                      | 100        |
# +--------------------------------+------------+
# Setting up lookup tables.
# Processing data in one pass using dense lookup tables.
# +-------------------------------------+------------------+-----------------+
# | Elapsed Time (Constructing Lookups) | Total % Complete | Items Processed |
# +-------------------------------------+------------------+-----------------+
# | 1.53s                               | 0                | 0               |
# | 2.53s                               | 2.5              | 705             |
# | 3.54s                               | 5.5              | 1476            |
# | 4.53s                               | 8.25             | 2220            |
# | 5.53s                               | 10.75            | 2910            |
# | 6.53s                               | 13.5             | 3673            |
# | 7.53s                               | 16.5             | 4417            |
# | 8.53s                               | 19               | 5118            |
# | 9.53s                               | 21.75            | 5858            |
# | 10.53s                              | 24.5             | 6561            |
# | 11.53s                              | 27               | 7237            |
# | 12.53s                              | 29.75            | 7989            |
# | 13.53s                              | 33.25            | 8915            |
# | 14.53s                              | 36.25            | 9737            |
# | 15.53s                              | 39.25            | 10552           |
# | 16.53s                              | 42.5             | 11374           |
# | 17.53s                              | 45.75            | 12275           |
# | 18.53s                              | 48.75            | 13080           |
# | 19.53s                              | 51.75            | 13880           |
# | 20.53s                              | 55               | 14703           |
# | 21.53s                              | 57.5             | 15434           |
# | 22.53s                              | 60               | 16065           |
# | 23.53s                              | 62.5             | 16755           |
# | 24.53s                              | 65.25            | 17468           |
# | 25.53s                              | 67.75            | 18157           |
# | 26.54s                              | 70.25            | 18840           |
# | 27.53s                              | 73               | 19527           |
# | 28.53s                              | 75.5             | 20205           |
# | 29.53s                              | 78               | 20908           |
# | 30.53s                              | 80.5             | 21518           |
# | 31.53s                              | 82.75            | 22177           |
# | 32.53s                              | 85               | 22768           |
# | 33.53s                              | 87.25            | 23364           |
# | 34.53s                              | 89.5             | 23955           |
# | 35.53s                              | 91.75            | 24525           |
# | 36.53s                              | 93.75            | 25099           |
# | 37.53s                              | 95.75            | 25644           |
# | 38.53s                              | 97.75            | 26172           |
# | 39.53s                              | 99.5             | 26638           |
# | 41.40s                              | 100              | 26729           |
# +-------------------------------------+------------------+-----------------+
# Finalizing lookup tables.
# Generating candidate set for working with new users.
# Finished training in 41.9884s
# Recsys training: model = item_similarity
# Preparing data set.
#     Data has 19997751 observations with 138493 users and 26729 items.
#     Data prepared in: 10.5736s
# Training model from provided data.
# Gathering per-item and per-user statistics.
# +--------------------------------+------------+
# | Elapsed Time (Item Statistics) | % Complete |
# +--------------------------------+------------+
# | 2.992ms                        | 0.5        |
# | 165.555ms                      | 100        |
# +--------------------------------+------------+
# Setting up lookup tables.
# Processing data in one pass using dense lookup tables.
# +-------------------------------------+------------------+-----------------+
# | Elapsed Time (Constructing Lookups) | Total % Complete | Items Processed |
# +-------------------------------------+------------------+-----------------+
# | 1.50s                               | 0                | 0               |
# | 2.50s                               | 2.75             | 758             |
# | 3.50s                               | 5.5              | 1493            |
# | 4.50s                               | 8.25             | 2240            |
# | 5.50s                               | 11               | 2978            |
# | 6.50s                               | 13.75            | 3739            |
# | 7.50s                               | 16.75            | 4538            |
# | 8.50s                               | 19.5             | 5260            |
# | 9.50s                               | 22.25            | 5986            |
# | 10.50s                              | 24.75            | 6634            |
# | 11.50s                              | 27.5             | 7372            |
# | 12.50s                              | 30.75            | 8224            |
# | 13.50s                              | 33.75            | 9065            |
# | 14.50s                              | 37               | 9939            |
# | 15.50s                              | 39.75            | 10657           |
# | 16.50s                              | 43               | 11515           |
# | 17.50s                              | 46.5             | 12481           |
# | 18.50s                              | 49.25            | 13198           |
# | 19.50s                              | 52               | 13947           |
# | 20.50s                              | 54.5             | 14625           |
# | 21.50s                              | 56.75            | 15222           |
# | 22.50s                              | 59.25            | 15881           |
# | 23.50s                              | 62               | 16631           |
# | 24.50s                              | 64.5             | 17263           |
# | 25.50s                              | 67.25            | 17977           |
# | 26.50s                              | 69.25            | 18553           |
# | 27.50s                              | 71.75            | 19239           |
# | 28.50s                              | 74.5             | 19928           |
# | 29.50s                              | 76.75            | 20532           |
# | 30.50s                              | 79               | 21149           |
# | 31.50s                              | 81.25            | 21718           |
# | 32.50s                              | 83.5             | 22367           |
# | 33.50s                              | 85.75            | 22961           |
# | 34.50s                              | 88               | 23572           |
# | 35.50s                              | 90.25            | 24169           |
# | 36.50s                              | 92.25            | 24720           |
# | 37.50s                              | 94.5             | 25300           |
# | 38.50s                              | 96.75            | 25865           |
# | 39.50s                              | 98.75            | 26398           |
# | 41.97s                              | 100              | 26729           |
# +-------------------------------------+------------------+-----------------+
# Finalizing lookup tables.
# Generating candidate set for working with new users.
# Finished training in 42.4741s

# %% [markdown]
# We want to compare which model gives the best perfromance overall. So we decided to use graphlab compare( ) method for comparison.

# %%
comparisonstruct = gl.compare(test,item_item)
# Out:
# PROGRESS: Evaluate model M0
#
# Precision and recall summary statistics by cutoff
# +--------+----------------+-----------------+
# | cutoff | mean_precision |   mean_recall   |
# +--------+----------------+-----------------+
# |   1    |      0.4       | 0.0249419397119 |
# |   2    |      0.37      | 0.0489566333539 |
# |   3    | 0.366666666667 | 0.0741145947527 |
# |   4    |     0.3375     | 0.0965850576226 |
# |   5    |      0.33      |  0.112465286335 |
# |   6    |     0.315      |  0.127160240434 |
# |   7    | 0.307142857143 |  0.140920945026 |
# |   8    |     0.2975     |  0.152092585364 |
# |   9    | 0.286666666667 |  0.164326895845 |
# |   10   |     0.283      |  0.174471299917 |
# +--------+----------------+-----------------+
# [10 rows x 3 columns]
#
# PROGRESS: Evaluate model M1
#
# Precision and recall summary statistics by cutoff
# +--------+----------------+-----------------+
# | cutoff | mean_precision |   mean_recall   |
# +--------+----------------+-----------------+
# |   1    |      0.39      | 0.0362787468212 |
# |   2    |      0.38      | 0.0611798100028 |
# |   3    |      0.35      | 0.0785967112019 |
# |   4    |     0.335      | 0.0955315320872 |
# |   5    |     0.318      |  0.111091884608 |
# |   6    | 0.308333333333 |  0.126693113459 |
# |   7    | 0.295714285714 |  0.136291529991 |
# |   8    |      0.29      |  0.149501584612 |
# |   9    | 0.282222222222 |  0.15975485854  |
# |   10   |     0.268      |  0.167309241509 |
# +--------+----------------+-----------------+
# [10 rows x 3 columns]
#
# PROGRESS: Evaluate model M2
#
# Precision and recall summary statistics by cutoff
# +--------+----------------+-----------------+
# | cutoff | mean_precision |   mean_recall   |
# +--------+----------------+-----------------+
# |   1    |      0.41      | 0.0357730700385 |
# |   2    |     0.365      | 0.0606466231358 |
# |   3    |      0.34      | 0.0773020519677 |
# |   4    |      0.32      | 0.0917717745604 |
# |   5    |     0.314      |  0.108127035049 |
# |   6    | 0.313333333333 |  0.126690317254 |
# |   7    | 0.298571428571 |  0.136906171146 |
# |   8    |    0.29125     |  0.150007262976 |
# |   9    |      0.28      |  0.160142592576 |
# |   10   |     0.275      |  0.171115836749 |
# +--------+----------------+-----------------+
# [10 rows x 3 columns]
#
# PROGRESS: Evaluate model M3
#
# Precision and recall summary statistics by cutoff
# +--------+----------------+-----------------+
# | cutoff | mean_precision |   mean_recall   |
# +--------+----------------+-----------------+
# |   1    |      0.36      | 0.0283310133882 |
# |   2    |     0.355      | 0.0599799773066 |
# |   3    |      0.34      | 0.0805713981698 |
# |   4    |     0.3225     |  0.095213054521 |
# |   5    |     0.312      |  0.109163380346 |
# |   6    | 0.306666666667 |  0.123031069561 |
# |   7    | 0.295714285714 |  0.133555357842 |
# |   8    |    0.28375     |  0.144992958931 |
# |   9    | 0.277777777778 |  0.158522796385 |
# |   10   |     0.271      |  0.165376453633 |
# +--------+----------------+-----------------+
# [10 rows x 3 columns]
#
# PROGRESS: Evaluate model M4
#
# Precision and recall summary statistics by cutoff
# +--------+----------------+-----------------+
# | cutoff | mean_precision |   mean_recall   |
# +--------+----------------+-----------------+
# |   1    |      0.36      |  0.035208791166 |
# |   2    |      0.36      | 0.0611963416665 |
# |   3    | 0.336666666667 | 0.0818667284236 |
# |   4    |      0.33      |  0.098828327969 |
# |   5    |      0.32      |  0.112224231556 |
# |   6    | 0.308333333333 |  0.126860477313 |
# |   7    | 0.297142857143 |  0.13871331387  |
# |   8    |      0.29      |  0.151530615909 |
# |   9    | 0.282222222222 |  0.159540247392 |
# |   10   |     0.272      |  0.170736387827 |
# +--------+----------------+-----------------+
# [10 rows x 3 columns]
#
# Model compare metric: precision_recall

# %% [markdown]
# We want to compare which model gives the best perfromance overall.

# %%
gl.show_comparison(comparisonstruct,item_item)

# %% [markdown]
# From the above graph, it is clear that all five models performed equally well based on the overall precision and recall values for all 18 cutoff vlaues chosen. Since with only_top_k equal to 5 requires the least memory and computation time, we chose "only_top_k = 5" for all the following item_similarity recommender.

# %% [markdown]
# #### Find the best parameters for ranking_factorization recommender

# %% [markdown]
# A RankingFactorizationRecommender learns latent factors for each user and item and uses them to rank recommended items according to the likelihood of observing those (user, item) pairs. This is commonly desired when performing collaborative filtering for implicit feedback datasets or datasets with explicit ratings for which ranking prediction is desired.
#
# RankingFactorizationRecommender contains a number of options that tailor to a variety of datasets and evaluation metrics, making this one of the most powerful models in the GraphLab Create recommender toolkit.

# %%
#optimize parameters to find the best model parameters
params = {'user_id': 'userId', 
          'item_id': 'title', 
          'target': 'rating',
          'num_factors': [8, 12, 16, 24, 32], 
          'regularization':[0.001] ,
          'linear_regularization': [0.001]}

job = gl.model_parameter_search.create( (train,test),
        gl.recommender.ranking_factorization_recommender.create,
        params,
        max_models=5,
        environment=None)
# Out:
# [INFO] graphlab.deploy.job: Validating job.
# [INFO] graphlab.deploy.job: Creating a LocalAsync environment called 'async'.
# [INFO] graphlab.deploy.map_job: Validation complete. Job: 'Model-Parameter-Search-Nov-25-2019-06-24-5600000' ready for execution
# [INFO] graphlab.deploy.map_job: Job: 'Model-Parameter-Search-Nov-25-2019-06-24-5600000' scheduled.
# [INFO] graphlab.deploy.job: Validating job.
# [INFO] graphlab.deploy.map_job: A job with name 'Model-Parameter-Search-Nov-25-2019-06-24-5600000' already exists. Renaming the job to 'Model-Parameter-Search-Nov-25-2019-06-24-5600000-7fdf1'.
# [INFO] graphlab.deploy.map_job: Validation complete. Job: 'Model-Parameter-Search-Nov-25-2019-06-24-5600000-7fdf1' ready for execution
# [INFO] graphlab.deploy.map_job: Job: 'Model-Parameter-Search-Nov-25-2019-06-24-5600000-7fdf1' scheduled.

# %%
job.get_status()
# Out:
# {'Canceled': 0, 'Completed': 0, 'Failed': 0, 'Pending': 5, 'Running': 0}

# %%
job_result = job.get_results()

job_result.head()
# Out:
# Columns:
# 	model_id	int
# 	item_id	str
# 	linear_regularization	float
# 	max_iterations	int
# 	num_factors	int
# 	num_sampled_negative_examples	int
# 	ranking_regularization	float
# 	regularization	float
# 	target	str
# 	user_id	str
# 	training_precision@5	float
# 	training_recall@5	float
# 	training_rmse	float
# 	validation_precision@5	float
# 	validation_recall@5	float
# 	validation_rmse	float
#
# Rows: 5
#
# Data:
# +----------+---------+-----------------------+----------------+-------------+-------------------------------+
# | model_id | item_id | linear_regularization | max_iterations | num_factors | num_sampled_negative_examples |
# +----------+---------+-----------------------+----------------+-------------+-------------------------------+
# |    1     |  title  |         0.001         |       25       |      8      |               8               |
# |    0     |  title  |         0.001         |       25       |      16     |               4               |
# |    3     |  title  |         0.001         |       50       |      12     |               8               |
# |    2     |  title  |         0.001         |       50       |      32     |               8               |
# |    4     |  title  |         0.001         |       25       |      24     |               4               |
# +----------+---------+-----------------------+----------------+-------------+-------------------------------+
# +------------------------+----------------+--------+---------+----------------------+
# | ranking_regularization | regularization | target | user_id | training_precision@5 |
# +------------------------+----------------+--------+---------+----------------------+
# |          0.5           |     0.001      | rating |  userId |    0.388517831226    |
# |          0.1           |     0.001      | rating |  userId |    0.388517831226    |
# |          0.5           |     0.001      | rating |  userId |    0.388517831226    |
# |          0.1           |     0.001      | rating |  userId |    0.388517831226    |
# |          0.1           |     0.001      | rating |  userId |    0.388517831226    |
# +------------------------+----------------+--------+---------+----------------------+
# +-------------------+----------------+------------------------+---------------------+
# | training_recall@5 | training_rmse  | validation_precision@5 | validation_recall@5 |
# +-------------------+----------------+------------------------+---------------------+
# |   0.023685956787  | 0.997850374414 |         0.174          |    0.035810831233   |
# |   0.023685956787  | 0.984118841279 |         0.176          |   0.0362479412494   |
# |   0.023685956787  | 0.997852044324 |         0.174          |    0.035810831233   |
# |   0.023685956787  | 0.986024123536 |         0.176          |   0.0362479412494   |
# |   0.023685956787  | 0.984182405731 |         0.176          |   0.0362479412494   |
# +-------------------+----------------+------------------------+---------------------+
# +-----------------+
# | validation_rmse |
# +-----------------+
# |  1.00921007822  |
# |  0.994803119892 |
# |  1.00937561211  |
# |  0.996687111338 |
# |  0.994724283851 |
# +-----------------+
# [5 rows x 16 columns]

# %%
bst_prms = job.get_best_params()
bst_prms
# Out:
# {'item_id': 'title',
#  'linear_regularization': 0.001,
#  'max_iterations': 25,
#  'num_factors': 24,
#  'num_sampled_negative_examples': 4,
#  'ranking_regularization': 0.1,
#  'regularization': 0.001,
#  'target': 'rating',
#  'user_id': 'userId'}

# %%
models = job.get_models()
models
# Out:
# [Class                            : RankingFactorizationRecommender
#
#  Schema
#  ------
#  User ID                          : userId
#  Item ID                          : title
#  Target                           : rating
#  Additional observation features  : 0
#  User side features               : []
#  Item side features               : []
#
#  Statistics
#  ----------
#  Number of observations           : 19997751
#  Number of users                  : 138493
#  Number of items                  : 26729
#
#  Training summary
#  ----------------
#  Training time                    : 146.6233
#
#  Model Parameters
#  ----------------
#  Model class                      : RankingFactorizationRecommender
#  num_factors                      : 16
#  binary_target                    : 0
#  side_data_factorization          : 1
#  solver                           : auto
#  nmf                              : 0
#  max_iterations                   : 25
#
#  Regularization Settings
#  -----------------------
#  regularization                   : 0.001
#  regularization_type              : normal
#  linear_regularization            : 0.001
#  ranking_regularization           : 0.1
#  unobserved_rating_value          : -1.79769313486e+308
#  num_sampled_negative_examples    : 4
#  ials_confidence_scaling_type     : auto
#  ials_confidence_scaling_factor   : 1
#
#  Optimization Settings
#  ---------------------
#  init_random_sigma                : 0.01
#  sgd_convergence_interval         : 4
#  sgd_convergence_threshold        : 0.0
#  sgd_max_trial_iterations         : 5
#  sgd_sampling_block_size          : 131072
#  sgd_step_adjustment_interval     : 4
#  sgd_step_size                    : 0.0
#  sgd_trial_sample_minimum_size    : 10000
#  sgd_trial_sample_proportion      : 0.125
#  step_size_decrease_rate          : 0.75
#  additional_iterations_if_unhealthy : 5
#  adagrad_momentum_weighting       : 0.9
#  num_tempering_iterations         : 4
#  tempering_regularization_start_value : 0.0
#  track_exact_loss                 : 0,
#  Class                            : RankingFactorizationRecommender
#
#  Schema
#  ------
#  User ID                          : userId
#  Item ID                          : title
#  Target                           : rating
#  Additional observation features  : 0
#  User side features               : []
#  Item side features               : []
#
#  Statistics
#  ----------
#  Number of observations           : 19997751
#  Number of users                  : 138493
#  Number of items                  : 26729
#
#  Training summary
#  ----------------
#  Training time                    : 168.949
#
#  Model Parameters
#  ----------------
#  Model class                      : RankingFactorizationRecommender
#  num_factors                      : 8
#  binary_target                    : 0
#  side_data_factorization          : 1
#  solver                           : auto
#  nmf                              : 0
#  max_iterations                   : 25
#
#  Regularization Settings
#  -----------------------
#  regularization                   : 0.001
#  regularization_type              : normal
#  linear_regularization            : 0.001
#  ranking_regularization           : 0.5
#  unobserved_rating_value          : -1.79769313486e+308
#  num_sampled_negative_examples    : 8
#  ials_confidence_scaling_type     : auto
#  ials_confidence_scaling_factor   : 1
#
#  Optimization Settings
#  ---------------------
#  init_random_sigma                : 0.01
#  sgd_convergence_interval         : 4
#  sgd_convergence_threshold        : 0.0
#  sgd_max_trial_iterations         : 5
#  sgd_sampling_block_size          : 131072
#  sgd_step_adjustment_interval     : 4
#  sgd_step_size                    : 0.0
#  sgd_trial_sample_minimum_size    : 10000
#  sgd_trial_sample_proportion      : 0.125
#  step_size_decrease_rate          : 0.75
#  additional_iterations_if_unhealthy : 5
#  adagrad_momentum_weighting       : 0.9
#  num_tempering_iterations         : 4
#  tempering_regularization_start_value : 0.0
#  track_exact_loss                 : 0,
#  Class                            : RankingFactorizationRecommender
#
#  Schema
#  ------
#  User ID                          : userId
#  Item ID                          : title
#  Target                           : rating
#  Additional observation features  : 0
#  User side features               : []
#  Item side features               : []
#
#  Statistics
#  ----------
#  Number of observations           : 19997751
#  Number of users                  : 138493
#  Number of items                  : 26729
#
#  Training summary
#  ----------------
#  Training time                    : 257.9504
#
#  Model Parameters
#  ----------------
#  Model class                      : RankingFactorizationRecommender
#  num_factors                      : 32
#  binary_target                    : 0
#  side_data_factorization          : 1
#  solver                           : auto
#  nmf                              : 0
#  max_iterations                   : 50
#
#  Regularization Settings
#  -----------------------
#  regularization                   : 0.001
#  regularization_type              : normal
#  linear_regularization            : 0.001
#  ranking_regularization           : 0.1
#  unobserved_rating_value          : -1.79769313486e+308
#  num_sampled_negative_examples    : 8
#  ials_confidence_scaling_type     : auto
#  ials_confidence_scaling_factor   : 1
#
#  Optimization Settings
#  ---------------------
#  init_random_sigma                : 0.01
#  sgd_convergence_interval         : 4
#  sgd_convergence_threshold        : 0.0
#  sgd_max_trial_iterations         : 5
#  sgd_sampling_block_size          : 131072
#  sgd_step_adjustment_interval     : 4
#  sgd_step_size                    : 0.0
#  sgd_trial_sample_minimum_size    : 10000
#  sgd_trial_sample_proportion      : 0.125
#  step_size_decrease_rate          : 0.75
#  additional_iterations_if_unhealthy : 5
#  adagrad_momentum_weighting       : 0.9
#  num_tempering_iterations         : 4
#  tempering_regularization_start_value : 0.0
#  track_exact_loss                 : 0,
#  Class                            : RankingFactorizationRecommender
#
#  Schema
#  ------
#  User ID                          : userId
#  Item ID                          : title
#  Target                           : rating
#  Additional observation features  : 0
#  User side features               : []
#  Item side features               : []
#
#  Statistics
#  ----------
#  Number of observations           : 19997751
#  Number of users                  : 138493
#  Number of items                  : 26729
#
#  Training summary
#  ----------------
#  Training time                    : 228.8983
#
#  Model Parameters
#  ----------------
#  Model class                      : RankingFactorizationRecommender
#  num_factors                      : 12
#  binary_target                    : 0
#  side_data_factorization          : 1
#  solver                           : auto
#  nmf                              : 0
#  max_iterations                   : 50
#
#  Regularization Settings
#  -----------------------
#  regularization                   : 0.001
#  regularization_type              : normal
#  linear_regularization            : 0.001
#  ranking_regularization           : 0.5
#  unobserved_rating_value          : -1.79769313486e+308
#  num_sampled_negative_examples    : 8
#  ials_confidence_scaling_type     : auto
#  ials_confidence_scaling_factor   : 1
#
#  Optimization Settings
#  ---------------------
#  init_random_sigma                : 0.01
#  sgd_convergence_interval         : 4
#  sgd_convergence_threshold        : 0.0
#  sgd_max_trial_iterations         : 5
#  sgd_sampling_block_size          : 131072
#  sgd_step_adjustment_interval     : 4
#  sgd_step_size                    : 0.0
#  sgd_trial_sample_minimum_size    : 10000
#  sgd_trial_sample_proportion      : 0.125
#  step_size_decrease_rate          : 0.75
#  additional_iterations_if_unhealthy : 5
#  adagrad_momentum_weighting       : 0.9
#  num_tempering_iterations         : 4
#  tempering_regularization_start_value : 0.0
#  track_exact_loss                 : 0,
#  Class                            : RankingFactorizationRecommender
#
#  Schema
#  ------
#  User ID                          : userId
#  Item ID                          : title
#  Target                           : rating
#  Additional observation features  : 0
#  User side features               : []
#  Item side features               : []
#
#  Statistics
#  ----------
#  Number of observations           : 19997751
#  Number of users                  : 138493
#  Number of items                  : 26729
#
#  Training summary
#  ----------------
#  Training time                    : 136.0952
#
#  Model Parameters
#  ----------------
#  Model class                      : RankingFactorizationRecommender
#  num_factors                      : 24
#  binary_target                    : 0
#  side_data_factorization          : 1
#  solver                           : auto
#  nmf                              : 0
#  max_iterations                   : 25
#
#  Regularization Settings
#  -----------------------
#  regularization                   : 0.001
#  regularization_type              : normal
#  linear_regularization            : 0.001
#  ranking_regularization           : 0.1
#  unobserved_rating_value          : -1.79769313486e+308
#  num_sampled_negative_examples    : 4
#  ials_confidence_scaling_type     : auto
#  ials_confidence_scaling_factor   : 1
#
#  Optimization Settings
#  ---------------------
#  init_random_sigma                : 0.01
#  sgd_convergence_interval         : 4
#  sgd_convergence_threshold        : 0.0
#  sgd_max_trial_iterations         : 5
#  sgd_sampling_block_size          : 131072
#  sgd_step_adjustment_interval     : 4
#  sgd_step_size                    : 0.0
#  sgd_trial_sample_minimum_size    : 10000
#  sgd_trial_sample_proportion      : 0.125
#  step_size_decrease_rate          : 0.75
#  additional_iterations_if_unhealthy : 5
#  adagrad_momentum_weighting       : 0.9
#  num_tempering_iterations         : 4
#  tempering_regularization_start_value : 0.0
#  track_exact_loss                 : 0]

# %%
comparisonstruct = gl.compare(test,models)
gl.show_comparison(comparisonstruct,models)
# Out:
# PROGRESS: Evaluate model M0
#
# Precision and recall summary statistics by cutoff
# +--------+----------------+-----------------+
# | cutoff | mean_precision |   mean_recall   |
# +--------+----------------+-----------------+
# |   1    |      0.23      | 0.0100477230193 |
# |   2    |     0.205      | 0.0185206829317 |
# |   3    |      0.19      | 0.0258405534522 |
# |   4    |     0.1875     | 0.0323531375112 |
# |   5    |     0.176      | 0.0362479412494 |
# |   6    | 0.166666666667 | 0.0388332849138 |
# |   7    | 0.162857142857 | 0.0449372005518 |
# |   8    |    0.15125     | 0.0501890404482 |
# |   9    | 0.141111111111 | 0.0517024139916 |
# |   10   |     0.129      | 0.0520663484179 |
# +--------+----------------+-----------------+
# [10 rows x 3 columns]
#
# PROGRESS: Evaluate model M1
#
# Precision and recall summary statistics by cutoff
# +--------+----------------+-----------------+
# | cutoff | mean_precision |   mean_recall   |
# +--------+----------------+-----------------+
# |   1    |      0.24      | 0.0113905801622 |
# |   2    |      0.2       | 0.0183541468816 |
# |   3    |      0.2       | 0.0266636765753 |
# |   4    |     0.2025     | 0.0332824336046 |
# |   5    |     0.174      |  0.035810831233 |
# |   6    |     0.175      | 0.0412111686616 |
# |   7    | 0.164285714286 | 0.0473932165289 |
# |   8    |    0.15125     | 0.0496683442041 |
# |   9    | 0.144444444444 | 0.0516206712032 |
# |   10   |     0.142      | 0.0610592070601 |
# +--------+----------------+-----------------+
# [10 rows x 3 columns]
#
# PROGRESS: Evaluate model M2
#
# Precision and recall summary statistics by cutoff
# +--------+----------------+-----------------+
# | cutoff | mean_precision |   mean_recall   |
# +--------+----------------+-----------------+
# |   1    |      0.23      | 0.0100477230193 |
# |   2    |      0.2       | 0.0178956829317 |
# |   3    | 0.196666666667 | 0.0265961090077 |
# |   4    |      0.19      | 0.0325255513043 |
# |   5    |     0.176      | 0.0362479412494 |
# |   6    |      0.17      |  0.040778311777 |
# |   7    | 0.162857142857 |  0.047925706299 |
# |   8    |      0.15      |  0.049844212862 |
# |   9    | 0.141111111111 | 0.0517024139916 |
# |   10   |     0.131      | 0.0565663484179 |
# +--------+----------------+-----------------+
# [10 rows x 3 columns]
#
# PROGRESS: Evaluate model M3
#
# Precision and recall summary statistics by cutoff
# +--------+----------------+-----------------+
# | cutoff | mean_precision |   mean_recall   |
# +--------+----------------+-----------------+
# |   1    |      0.24      | 0.0113905801622 |
# |   2    |      0.2       | 0.0183541468816 |
# |   3    |      0.2       | 0.0266636765753 |
# |   4    |     0.2025     | 0.0332824336046 |
# |   5    |     0.174      |  0.035810831233 |
# |   6    |     0.175      | 0.0412111686616 |
# |   7    | 0.164285714286 | 0.0473932165289 |
# |   8    |    0.15125     | 0.0496683442041 |
# |   9    | 0.144444444444 | 0.0516206712032 |
# |   10   |     0.142      | 0.0610592070601 |
# +--------+----------------+-----------------+
# [10 rows x 3 columns]
#
# PROGRESS: Evaluate model M4
#
# Precision and recall summary statistics by cutoff
# +--------+----------------+-----------------+
# | cutoff | mean_precision |   mean_recall   |
# +--------+----------------+-----------------+
# |   1    |      0.23      | 0.0100477230193 |
# |   2    |     0.205      | 0.0185206829317 |
# |   3    |      0.19      | 0.0258405534522 |
# |   4    |     0.1875     | 0.0323531375112 |
# |   5    |     0.176      | 0.0362479412494 |
# |   6    | 0.166666666667 | 0.0388332849138 |
# |   7    | 0.162857142857 | 0.0449372005518 |
# |   8    |    0.15125     | 0.0501890404482 |
# |   9    | 0.141111111111 | 0.0517024139916 |
# |   10   |     0.129      | 0.0520663484179 |
# +--------+----------------+-----------------+
# [10 rows x 3 columns]
#
# Model compare metric: precision_recall

# %% [markdown]
# From the above graph, it appears that all five models performed equally well based on the overall precision and recall values for all cutoff vlaues chosen. We chose to use the best parameters obtained above for the ranking_factorization_recommender in the following sections.

# %% [markdown]
# <a href="#top">Back to Top</a>
# ### Modeling and Evaluation - Evaluate & Compare<a id="Modeling_and_Evaluation_Evaluate_and_Compare"></a>
# * Determine performance of the recommendations using different performance measures and explain what each measure.

# %% [markdown]
# #### Evaluate item_similarity recommender using the optimal parameter settings

# %%
from IPython.display import display
from IPython.display import Image

gl.canvas.set_target('ipynb')

item_item = gl.recommender.item_similarity_recommender.create(train, 
                                  user_id="userId", 
                                  item_id="title", 
                                  target="rating",
                                  only_top_k= 5,
                                  similarity_type="cosine")
    
rmse_results = item_item.evaluate(test)
# Out:
# Recsys training: model = item_similarity
# Preparing data set.
#     Data has 19997751 observations with 138493 users and 26729 items.
#     Data prepared in: 9.55838s
# Training model from provided data.
# Gathering per-item and per-user statistics.
# +--------------------------------+------------+
# | Elapsed Time (Item Statistics) | % Complete |
# +--------------------------------+------------+
# | 1.995ms                        | 0.5        |
# | 147.604ms                      | 100        |
# +--------------------------------+------------+
# Setting up lookup tables.
# Processing data in one pass using dense lookup tables.
# +-------------------------------------+------------------+-----------------+
# | Elapsed Time (Constructing Lookups) | Total % Complete | Items Processed |
# +-------------------------------------+------------------+-----------------+
# | 1.54s                               | 0                | 0               |
# | 2.55s                               | 2.5              | 725             |
# | 3.55s                               | 5.75             | 1591            |
# | 4.54s                               | 8.5              | 2312            |
# | 5.55s                               | 11.5             | 3100            |
# | 6.55s                               | 14.25            | 3849            |
# | 7.54s                               | 17               | 4556            |
# | 8.55s                               | 19.75            | 5294            |
# | 9.55s                               | 22.75            | 6088            |
# | 10.54s                              | 25.5             | 6819            |
# | 11.54s                              | 28.5             | 7633            |
# | 12.54s                              | 32               | 8557            |
# | 13.54s                              | 35               | 9408            |
# | 14.54s                              | 38               | 10169           |
# | 15.54s                              | 41               | 11001           |
# | 16.54s                              | 44               | 11802           |
# | 17.54s                              | 47               | 12615           |
# | 18.54s                              | 50.5             | 13553           |
# | 19.54s                              | 54               | 14471           |
# | 20.54s                              | 57.25            | 15332           |
# | 21.54s                              | 60               | 16053           |
# | 22.54s                              | 62.5             | 16740           |
# | 23.54s                              | 65               | 17417           |
# | 24.54s                              | 68               | 18182           |
# | 25.54s                              | 70.75            | 18938           |
# | 26.54s                              | 73.5             | 19661           |
# | 27.54s                              | 76               | 20341           |
# | 28.54s                              | 78.5             | 21007           |
# | 29.54s                              | 81               | 21694           |
# | 30.54s                              | 83.75            | 22390           |
# | 31.54s                              | 86.25            | 23058           |
# | 32.54s                              | 88.5             | 23671           |
# | 33.54s                              | 90.75            | 24304           |
# | 34.54s                              | 93.25            | 24925           |
# | 35.54s                              | 95.5             | 25546           |
# | 36.54s                              | 97.75            | 26153           |
# | 39.13s                              | 100              | 26729           |
# +-------------------------------------+------------------+-----------------+
# Finalizing lookup tables.
# Generating candidate set for working with new users.
# Finished training in 39.6348s
# Precision and recall summary statistics by cutoff
# +--------+----------------+-----------------+
# | cutoff | mean_precision |   mean_recall   |
# +--------+----------------+-----------------+
# |   1    |      0.42      | 0.0279419397119 |
# |   2    |      0.37      | 0.0503316333539 |
# |   3    | 0.376666666667 | 0.0751362749695 |
# |   4    |     0.345      |  0.098162293395 |
# |   5    |     0.332      |  0.113004968875 |
# |   6    | 0.321666666667 |  0.130562668072 |
# |   7    | 0.308571428571 |  0.141651655492 |
# |   8    |    0.29625     |  0.152489962496 |
# |   9    | 0.283333333333 |  0.160851257104 |
# |   10   |     0.281      |  0.173339265285 |
# +--------+----------------+-----------------+
# [10 rows x 3 columns]
#
# ('\nOverall RMSE: ', 3.6458417295253907)
#
# Per User RMSE (best)
# +--------+-------+---------------+
# | userId | count |      rmse     |
# +--------+-------+---------------+
# | 100197 |   4   | 2.06026246036 |
# +--------+-------+---------------+
# [1 rows x 3 columns]
#
#
# Per User RMSE (worst)
# +--------+-------+---------------+
# | userId | count |      rmse     |
# +--------+-------+---------------+
# | 135464 |   5   | 4.89666418689 |
# +--------+-------+---------------+
# [1 rows x 3 columns]
#
#
# Per Item RMSE (best)
# +------------------+-------+----------------+
# |      title       | count |      rmse      |
# +------------------+-------+----------------+
# | Rambo III (1988) |   1   | 0.489602827078 |
# +------------------+-------+----------------+
# [1 rows x 3 columns]
#
#
# Per Item RMSE (worst)
# +-------------------------------+-------+------+
# |             title             | count | rmse |
# +-------------------------------+-------+------+
# | Battle of Algiers, The (La... |   1   | 5.0  |
# +-------------------------------+-------+------+
# [1 rows x 3 columns]

# %%
print rmse_results.viewkeys()
# Out:
# dict_keys(['rmse_by_user', 'precision_recall_overall', 'rmse_by_item', 'precision_recall_by_user', 'rmse_overall'])

# %%
rmse_results['rmse_by_user']
# Out:
# Columns:
# 	userId	int
# 	count	int
# 	rmse	float
#
# Rows: 100
#
# Data:
# +--------+-------+---------------+
# | userId | count |      rmse     |
# +--------+-------+---------------+
# | 100197 |   4   | 2.06026246036 |
# |  4414  |   8   | 3.11828692372 |
# | 132030 |   13  |  4.2785598324 |
# | 102179 |   10  | 3.19382118875 |
# | 29110  |   12  | 3.87944036265 |
# | 120458 |  193  | 3.72131540322 |
# | 60041  |   8   |  3.5881750236 |
# | 17734  |   32  | 3.76246012417 |
# | 118929 |   8   | 3.64119865069 |
# |  6105  |   7   | 4.15458177393 |
# +--------+-------+---------------+
# [100 rows x 3 columns]
# Note: Only the head of the SFrame is printed.
# You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.

# %%
from matplotlib import pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')

rmsevals = rmse_results['rmse_by_user']['rmse']
rmsevals = rmsevals[rmse_results['rmse_by_user']['count']>10]

plt.hist(rmsevals,bins=20)
plt.title('RMSE by User')
plt.show()

# %%
rmse_results['precision_recall_by_user']
# Out:
# Columns:
# 	userId	int
# 	cutoff	int
# 	precision	float
# 	recall	float
# 	count	int
#
# Rows: 1800
#
# Data:
# +--------+--------+----------------+--------+-------+
# | userId | cutoff |   precision    | recall | count |
# +--------+--------+----------------+--------+-------+
# |  3014  |   1    |      0.0       |  0.0   |   10  |
# |  3014  |   2    |      0.0       |  0.0   |   10  |
# |  3014  |   3    |      0.0       |  0.0   |   10  |
# |  3014  |   4    |      0.0       |  0.0   |   10  |
# |  3014  |   5    |      0.0       |  0.0   |   10  |
# |  3014  |   6    | 0.166666666667 |  0.1   |   10  |
# |  3014  |   7    | 0.142857142857 |  0.1   |   10  |
# |  3014  |   8    |     0.125      |  0.1   |   10  |
# |  3014  |   9    | 0.111111111111 |  0.1   |   10  |
# |  3014  |   10   |      0.2       |  0.2   |   10  |
# +--------+--------+----------------+--------+-------+
# [1800 rows x 5 columns]
# Note: Only the head of the SFrame is printed.
# You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.

# %%
import graphlab.aggregate as agg

# we will be using these aggregations
agg_list = [agg.AVG('precision'),agg.STD('precision'),agg.AVG('recall'),agg.STD('recall')]

# apply these functions to each group (we will group the results by 'k' which is the cutoff)
# the cutoff is the number of top items to look for see the following URL for the actual equation
# https://dato.com/products/create/docs/generated/graphlab.recommender.util.precision_recall_by_user.html#graphlab.recommender.util.precision_recall_by_user
rmse_results['precision_recall_by_user'].groupby('cutoff',agg_list)
# Out:
# Columns:
# 	cutoff	int
# 	Avg of precision	float
# 	Stdv of precision	float
# 	Avg of recall	float
# 	Stdv of recall	float
#
# Rows: 18
#
# Data:
# +--------+------------------+-------------------+-----------------+
# | cutoff | Avg of precision | Stdv of precision |  Avg of recall  |
# +--------+------------------+-------------------+-----------------+
# |   16   |      0.2525      |   0.209709620666  |  0.237018046036 |
# |   10   |      0.281       |   0.242773557044  |  0.173339265285 |
# |   36   |  0.173055555556  |   0.160960418031  |  0.332112275962 |
# |   26   |  0.200384615385  |   0.175267757965  |  0.293169281761 |
# |   41   |  0.164634146341  |   0.156568458931  |  0.353227458041 |
# |   3    |  0.376666666667  |   0.342068868959  | 0.0751362749695 |
# |   1    |       0.42       |   0.49355850717   | 0.0279419397119 |
# |   6    |  0.321666666667  |   0.274119803492  |  0.130562668072 |
# |   11   |  0.272727272727  |   0.233195551607  |  0.185498969348 |
# |   2    |       0.37       |   0.403856410126  | 0.0503316333539 |
# +--------+------------------+-------------------+-----------------+
# +-----------------+
# |  Stdv of recall |
# +-----------------+
# |  0.199643461501 |
# |  0.174519054188 |
# |  0.224267004534 |
# |  0.218864807388 |
# |  0.221697260607 |
# | 0.0991193031367 |
# | 0.0513360831219 |
# |  0.157792295384 |
# |  0.178433326432 |
# | 0.0841485839242 |
# +-----------------+
# [18 rows x 5 columns]
# Note: Only the head of the SFrame is printed.
# You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.

# %% [markdown]
# #### Evaluate ranking_factorization recommender

# %% [markdown]
# We use the best parameters obtained above for the following ranking_factorization_recommender.

# %%
rec1 = gl.recommender.ranking_factorization_recommender.create(train, 
                                  user_id="userId", 
                                  item_id="title", 
                                  target="rating",
                                  num_factors=12,                 # override the default value
                                  regularization=1e-03,           # override the default value
                                  linear_regularization = 1e-3,   # override the default value
                                  ranking_regularization = 0.1,   # override the default value
                                  num_sampled_negative_examples = 4, # override the default value
                                  max_iterations = 50   )   # override the default value

rmse_results = rec1.evaluate(test)
# Out:
# Recsys training: model = ranking_factorization_recommender
# Preparing data set.
#     Data has 19997751 observations with 138493 users and 26729 items.
#     Data prepared in: 10.7791s
# Training ranking_factorization_recommender for recommendations.
# +--------------------------------+--------------------------------------------------+----------+
# | Parameter                      | Description                                      | Value    |
# +--------------------------------+--------------------------------------------------+----------+
# | num_factors                    | Factor Dimension                                 | 12       |
# | regularization                 | L2 Regularization on Factors                     | 0.001    |
# | solver                         | Solver used for training                         | sgd      |
# | linear_regularization          | L2 Regularization on Linear Coefficients         | 0.001    |
# | ranking_regularization         | Rank-based Regularization Weight                 | 0.1      |
# | max_iterations                 | Maximum Number of Iterations                     | 50       |
# +--------------------------------+--------------------------------------------------+----------+
#   Optimizing model using SGD; tuning step size.
#   Using 2499718 / 19997751 points for tuning the step size.
# +---------+-------------------+------------------------------------------+
# | Attempt | Initial Step Size | Estimated Objective Value                |
# +---------+-------------------+------------------------------------------+
# | 0       | 0.00368454        | Not Viable                               |
# | 1       | 0.000921136       | 1.48741                                  |
# | 2       | 0.000460568       | 1.47716                                  |
# | 3       | 0.000230284       | 1.46964                                  |
# | 4       | 0.000115142       | 1.46788                                  |
# | 5       | 5.7571e-005       | 1.4715                                   |
# | 6       | 2.87855e-005      | 1.47996                                  |
# | 7       | 1.43927e-005      | 1.49572                                  |
# +---------+-------------------+------------------------------------------+
# | Final   | 0.000115142       | 1.46788                                  |
# +---------+-------------------+------------------------------------------+
# Starting Optimization.
# +---------+--------------+-------------------+-----------------------+-------------+
# | Iter.   | Elapsed Time | Approx. Objective | Approx. Training RMSE | Step Size   |
# +---------+--------------+-------------------+-----------------------+-------------+
# | Initial | 0us          | 1.53195           | 1.05198               |             |
# +---------+--------------+-------------------+-----------------------+-------------+
# | 1       | 5.12s        | 1.50165           | 0.992148              | 0.000115142 |
# | 2       | 10.09s       | 1.48142           | 0.984113              |             |
# | 3       | 14.99s       | 1.48077           | 0.98409               |             |
# | 4       | 20.36s       | 1.48124           | 0.984253              |             |
# | 5       | 25.26s       | 1.48104           | 0.984186              |             |
# | 6       | 30.26s       | 1.48138           | 0.984264              |             |
# | 7       | 35.31s       | 1.48134           | 0.984211              |             |
# | 8       | 40.26s       | 1.48121           | 0.984153              |             |
# | 9       | 45.30s       | 1.48132           | 0.984163              |             |
# | 10      | 50.34s       | 1.48126           | 0.984134              |             |
# | 11      | 55.36s       | 1.48126           | 0.984141              |             |
# | 12      | 1m 0s        | 1.48127           | 0.984129              |             |
# | 13      | 1m 5s        | 1.48137           | 0.984164              |             |
# | 14      | 1m 10s       | 1.48134           | 0.984142              | 1.8807e-006 |
# | 15      | 1m 15s       | 1.4813            | 0.984124              |             |
# | 16      | 1m 20s       | 1.4813            | 0.984127              |             |
# | 17      | 1m 25s       | 1.48132           | 0.984129              |             |
# | 18      | 1m 30s       | 1.48131           | 0.984119              |             |
# | 19      | 1m 35s       | 1.4813            | 0.984117              |             |
# | 20      | 1m 40s       | 1.48131           | 0.984123              |             |
# | 21      | 1m 45s       | 1.48132           | 0.984123              |             |
# | 22      | 1m 50s       | 1.48133           | 0.984124              |             |
# | 23      | 1m 55s       | 1.48131           | 0.984119              |             |
# | 24      | 2m 0s        | 1.48132           | 0.984118              |             |
# | 25      | 2m 5s        | 1.48132           | 0.984117              |             |
# | 26      | 2m 10s       | 1.48131           | 0.984116              | 9.8822e-008 |
# | 27      | 2m 15s       | 1.48132           | 0.984116              |             |
# | 28      | 2m 20s       | 1.48131           | 0.984115              |             |
# | 29      | 2m 25s       | 1.48132           | 0.984114              |             |
# | 30      | 2m 30s       | 1.48132           | 0.984114              |             |
# +---------+--------------+-------------------+-----------------------+-------------+
# Optimization Complete: Convergence on objective within bounds.
# Computing final objective value and training RMSE.
#        Final objective value: 1.48153
#        Final training RMSE: 0.984155
# Precision and recall summary statistics by cutoff
# +--------+----------------+-----------------+
# | cutoff | mean_precision |   mean_recall   |
# +--------+----------------+-----------------+
# |   1    |      0.23      | 0.0100477230193 |
# |   2    |     0.205      | 0.0185206829317 |
# |   3    | 0.193333333333 | 0.0263961090077 |
# |   4    |      0.19      | 0.0325255513043 |
# |   5    |     0.176      | 0.0362479412494 |
# |   6    |     0.165      | 0.0384638860067 |
# |   7    | 0.162857142857 | 0.0449372005518 |
# |   8    |    0.15125     | 0.0501890404482 |
# |   9    | 0.141111111111 | 0.0517024139916 |
# |   10   |     0.131      | 0.0565663484179 |
# +--------+----------------+-----------------+
# [10 rows x 3 columns]
#
# ('\nOverall RMSE: ', 0.9947983100005658)
#
# Per User RMSE (best)
# +--------+-------+----------------+
# | userId | count |      rmse      |
# +--------+-------+----------------+
# | 11658  |   4   | 0.357630973374 |
# +--------+-------+----------------+
# [1 rows x 3 columns]
#
#
# Per User RMSE (worst)
# +--------+-------+---------------+
# | userId | count |      rmse     |
# +--------+-------+---------------+
# | 17686  |   16  | 2.24361563213 |
# +--------+-------+---------------+
# [1 rows x 3 columns]
#
#
# Per Item RMSE (best)
# +-----------------------+-------+-------------------+
# |         title         | count |        rmse       |
# +-----------------------+-------+-------------------+
# | Tropic Thunder (2008) |   1   | 3.95779365183e-05 |
# +-----------------------+-------+-------------------+
# [1 rows x 3 columns]
#
#
# Per Item RMSE (worst)
# +---------------------+-------+---------------+
# |        title        | count |      rmse     |
# +---------------------+-------+---------------+
# | Hotel Rwanda (2004) |   1   | 3.23338376194 |
# +---------------------+-------+---------------+
# [1 rows x 3 columns]

# %%
rmse_results['precision_recall_by_user'].groupby('cutoff',[agg.AVG('precision'),agg.STD('precision'),agg.AVG('recall'),agg.STD('recall')])
# Out:
# Columns:
# 	cutoff	int
# 	Avg of precision	float
# 	Stdv of precision	float
# 	Avg of recall	float
# 	Stdv of recall	float
#
# Rows: 18
#
# Data:
# +--------+------------------+-------------------+-----------------+
# | cutoff | Avg of precision | Stdv of precision |  Avg of recall  |
# +--------+------------------+-------------------+-----------------+
# |   16   |     0.10875      |   0.151456470644  | 0.0712800858058 |
# |   10   |      0.131       |   0.187986701657  | 0.0565663484179 |
# |   36   | 0.0788888888889  |   0.106263706451  |  0.118167431729 |
# |   26   | 0.0911538461538  |   0.124112828035  | 0.0951163665888 |
# |   41   | 0.0741463414634  |   0.098163990073  |  0.128656531963 |
# |   3    |  0.193333333333  |   0.302508034788  | 0.0263961090077 |
# |   1    |       0.23       |   0.42083250825   | 0.0100477230193 |
# |   6    |      0.165       |   0.238624530731  | 0.0384638860067 |
# |   11   |  0.125454545455  |   0.179889773413  | 0.0584808131054 |
# |   2    |      0.205       |   0.332377797092  | 0.0185206829317 |
# +--------+------------------+-------------------+-----------------+
# +-----------------+
# |  Stdv of recall |
# +-----------------+
# | 0.0936888604259 |
# | 0.0878857698864 |
# |  0.112192897548 |
# |  0.10301767905  |
# |  0.117092904906 |
# | 0.0543116502936 |
# |  0.024177012241 |
# | 0.0612394426096 |
# |  0.087955217893 |
# | 0.0412839576855 |
# +-----------------+
# [18 rows x 5 columns]
# Note: Only the head of the SFrame is printed.
# You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.

# %% [markdown]
# #### Which recommender is doing better: item_similarity or ranking_factorization?

# %%
comparison = gl.recommender.util.compare_models(test, [item_item, rec1])
# Out:
# PROGRESS: Evaluate model M0
#
# Precision and recall summary statistics by cutoff
# +--------+----------------+-----------------+
# | cutoff | mean_precision |   mean_recall   |
# +--------+----------------+-----------------+
# |   1    |      0.42      | 0.0279419397119 |
# |   2    |      0.37      | 0.0503316333539 |
# |   3    | 0.376666666667 | 0.0751362749695 |
# |   4    |     0.345      |  0.098162293395 |
# |   5    |     0.332      |  0.113004968875 |
# |   6    | 0.321666666667 |  0.130562668072 |
# |   7    | 0.308571428571 |  0.141651655492 |
# |   8    |    0.29625     |  0.152489962496 |
# |   9    | 0.283333333333 |  0.160851257104 |
# |   10   |     0.281      |  0.173339265285 |
# +--------+----------------+-----------------+
# [10 rows x 3 columns]
#
# ('\nOverall RMSE: ', 3.6458417295253907)
#
# Per User RMSE (best)
# +--------+-------+---------------+
# | userId | count |      rmse     |
# +--------+-------+---------------+
# | 100197 |   4   | 2.06026246036 |
# +--------+-------+---------------+
# [1 rows x 3 columns]
#
#
# Per User RMSE (worst)
# +--------+-------+---------------+
# | userId | count |      rmse     |
# +--------+-------+---------------+
# | 135464 |   5   | 4.89666418689 |
# +--------+-------+---------------+
# [1 rows x 3 columns]
#
#
# Per Item RMSE (best)
# +------------------+-------+----------------+
# |      title       | count |      rmse      |
# +------------------+-------+----------------+
# | Rambo III (1988) |   1   | 0.489602827078 |
# +------------------+-------+----------------+
# [1 rows x 3 columns]
#
#
# Per Item RMSE (worst)
# +-------------------------------+-------+------+
# |             title             | count | rmse |
# +-------------------------------+-------+------+
# | Battle of Algiers, The (La... |   1   | 5.0  |
# +-------------------------------+-------+------+
# [1 rows x 3 columns]
#
# PROGRESS: Evaluate model M1
#
# Precision and recall summary statistics by cutoff
# +--------+----------------+-----------------+
# | cutoff | mean_precision |   mean_recall   |
# +--------+----------------+-----------------+
# |   1    |      0.23      | 0.0100477230193 |
# |   2    |     0.205      | 0.0185206829317 |
# |   3    | 0.193333333333 | 0.0263961090077 |
# |   4    |      0.19      | 0.0325255513043 |
# |   5    |     0.176      | 0.0362479412494 |
# |   6    |     0.165      | 0.0384638860067 |
# |   7    | 0.162857142857 | 0.0449372005518 |
# |   8    |    0.15125     | 0.0501890404482 |
# |   9    | 0.141111111111 | 0.0517024139916 |
# |   10   |     0.131      | 0.0565663484179 |
# +--------+----------------+-----------------+
# [10 rows x 3 columns]
#
# ('\nOverall RMSE: ', 0.9947983100005658)
#
# Per User RMSE (best)
# +--------+-------+----------------+
# | userId | count |      rmse      |
# +--------+-------+----------------+
# | 11658  |   4   | 0.357630973374 |
# +--------+-------+----------------+
# [1 rows x 3 columns]
#
#
# Per User RMSE (worst)
# +--------+-------+---------------+
# | userId | count |      rmse     |
# +--------+-------+---------------+
# | 17686  |   16  | 2.24361563213 |
# +--------+-------+---------------+
# [1 rows x 3 columns]
#
#
# Per Item RMSE (best)
# +-----------------------+-------+-------------------+
# |         title         | count |        rmse       |
# +-----------------------+-------+-------------------+
# | Tropic Thunder (2008) |   1   | 3.95779365183e-05 |
# +-----------------------+-------+-------------------+
# [1 rows x 3 columns]
#
#
# Per Item RMSE (worst)
# +---------------------+-------+---------------+
# |        title        | count |      rmse     |
# +---------------------+-------+---------------+
# | Hotel Rwanda (2004) |   1   | 3.23338376194 |
# +---------------------+-------+---------------+
# [1 rows x 3 columns]

# %%
 comparisonstruct = gl.compare(test,[item_item, rec1])
# Out:
# PROGRESS: Evaluate model M0
#
# Precision and recall summary statistics by cutoff
# +--------+----------------+-----------------+
# | cutoff | mean_precision |   mean_recall   |
# +--------+----------------+-----------------+
# |   1    |      0.42      | 0.0279419397119 |
# |   2    |      0.37      | 0.0503316333539 |
# |   3    | 0.376666666667 | 0.0751362749695 |
# |   4    |     0.345      |  0.098162293395 |
# |   5    |     0.332      |  0.113004968875 |
# |   6    | 0.321666666667 |  0.130562668072 |
# |   7    | 0.308571428571 |  0.141651655492 |
# |   8    |    0.29625     |  0.152489962496 |
# |   9    | 0.283333333333 |  0.160851257104 |
# |   10   |     0.281      |  0.173339265285 |
# +--------+----------------+-----------------+
# [10 rows x 3 columns]
#
# PROGRESS: Evaluate model M1
#
# Precision and recall summary statistics by cutoff
# +--------+----------------+-----------------+
# | cutoff | mean_precision |   mean_recall   |
# +--------+----------------+-----------------+
# |   1    |      0.23      | 0.0100477230193 |
# |   2    |     0.205      | 0.0185206829317 |
# |   3    | 0.193333333333 | 0.0263961090077 |
# |   4    |      0.19      | 0.0325255513043 |
# |   5    |     0.176      | 0.0362479412494 |
# |   6    |     0.165      | 0.0384638860067 |
# |   7    | 0.162857142857 | 0.0449372005518 |
# |   8    |    0.15125     | 0.0501890404482 |
# |   9    | 0.141111111111 | 0.0517024139916 |
# |   10   |     0.131      | 0.0565663484179 |
# +--------+----------------+-----------------+
# [10 rows x 3 columns]
#
# Model compare metric: precision_recall

# %%
gl.show_comparison(comparisonstruct,[item_item, rec1])

# %% [markdown]
# From the above graph, it is obvious that item_similarity recommender is doing better than ranking_facotorization recommender in our dataset.

# %% [markdown]
# #### We use the best recommender, item_similarity recommender, on the whole dataset for recommendations.

# %%
# This is a well known graphlab example that builds a recommendation system in 5 lines of code
from IPython.display import display
from IPython.display import Image

gl.canvas.set_target('ipynb')

model = gl.recommender.item_similarity_recommender.create(data, 
                                  user_id="userId", 
                                  item_id="title", 
                                  target="rating",
                                  only_top_k= 5,
                                  similarity_type="cosine")
    
results = model.recommend(users=None, k=5)
#model.save("my_model")
# Out:
# Recsys training: model = item_similarity
# Preparing data set.
#     Data has 20000263 observations with 138493 users and 26729 items.
#     Data prepared in: 10.8659s
# Training model from provided data.
# Gathering per-item and per-user statistics.
# +--------------------------------+------------+
# | Elapsed Time (Item Statistics) | % Complete |
# +--------------------------------+------------+
# | 2.013ms                        | 0.5        |
# | 168.549ms                      | 100        |
# +--------------------------------+------------+
# Setting up lookup tables.
# Processing data in one pass using dense lookup tables.
# +-------------------------------------+------------------+-----------------+
# | Elapsed Time (Constructing Lookups) | Total % Complete | Items Processed |
# +-------------------------------------+------------------+-----------------+
# | 1.61s                               | 0                | 0               |
# | 2.62s                               | 2.5              | 724             |
# | 3.62s                               | 5.5              | 1524            |
# | 4.62s                               | 8.25             | 2248            |
# | 5.62s                               | 11               | 2985            |
# | 6.61s                               | 13.75            | 3710            |
# | 7.61s                               | 16.5             | 4456            |
# | 8.61s                               | 19.25            | 5156            |
# | 9.61s                               | 22               | 5941            |
# | 10.61s                              | 24.5             | 6588            |
# | 11.61s                              | 27               | 7273            |
# | 12.61s                              | 30.5             | 8205            |
# | 13.62s                              | 34.5             | 9245            |
# | 14.62s                              | 38.5             | 10291           |
# | 15.62s                              | 42               | 11228           |
# | 16.62s                              | 45               | 12056           |
# | 17.61s                              | 48               | 12830           |
# | 18.61s                              | 50.5             | 13556           |
# | 19.61s                              | 53.25            | 14238           |
# | 20.61s                              | 55.75            | 14935           |
# | 21.61s                              | 58.5             | 15640           |
# | 22.61s                              | 61               | 16340           |
# | 23.61s                              | 63.75            | 17063           |
# | 24.61s                              | 66.25            | 17769           |
# | 25.61s                              | 69               | 18479           |
# | 26.61s                              | 71.5             | 19149           |
# | 27.61s                              | 74               | 19836           |
# | 28.61s                              | 76.5             | 20507           |
# | 29.61s                              | 79               | 21122           |
# | 30.61s                              | 81.25            | 21758           |
# | 31.61s                              | 83.5             | 22383           |
# | 32.61s                              | 85.75            | 22986           |
# | 33.61s                              | 88.25            | 23592           |
# | 34.61s                              | 90.25            | 24180           |
# | 35.61s                              | 92.5             | 24776           |
# | 36.61s                              | 94.75            | 25353           |
# | 37.61s                              | 97               | 25941           |
# | 38.61s                              | 99               | 26505           |
# | 40.66s                              | 100              | 26729           |
# +-------------------------------------+------------------+-----------------+
# Finalizing lookup tables.
# Generating candidate set for working with new users.
# Finished training in 41.2016s
# recommendations finished on 1000/138493 queries. users per second: 16437.4
# recommendations finished on 2000/138493 queries. users per second: 19282.3
# recommendations finished on 3000/138493 queries. users per second: 20324.7
# recommendations finished on 4000/138493 queries. users per second: 20673.8
# recommendations finished on 5000/138493 queries. users per second: 21243.2
# recommendations finished on 6000/138493 queries. users per second: 21486
# recommendations finished on 7000/138493 queries. users per second: 21662.8
# recommendations finished on 8000/138493 queries. users per second: 21563
# recommendations finished on 9000/138493 queries. users per second: 21486
# recommendations finished on 10000/138493 queries. users per second: 21288.3
# recommendations finished on 11000/138493 queries. users per second: 21088.9
# recommendations finished on 12000/138493 queries. users per second: 20961.9
# recommendations finished on 13000/138493 queries. users per second: 20889.2
# recommendations finished on 14000/138493 queries. users per second: 20889.2
# recommendations finished on 15000/138493 queries. users per second: 20831.3
# recommendations finished on 16000/138493 queries. users per second: 20754
# recommendations finished on 17000/138493 queries. users per second: 20736.7
# recommendations finished on 18000/138493 queries. users per second: 20745.1
# recommendations finished on 19000/138493 queries. users per second: 20730
# recommendations finished on 20000/138493 queries. users per second: 20673.8
# recommendations finished on 21000/138493 queries. users per second: 20684
# recommendations finished on 22000/138493 queries. users per second: 20712.6
# recommendations finished on 23000/138493 queries. users per second: 20813.8
# recommendations finished on 24000/138493 queries. users per second: 20907.3
# recommendations finished on 25000/138493 queries. users per second: 20941.5
# recommendations finished on 26000/138493 queries. users per second: 21040.9
# recommendations finished on 27000/138493 queries. users per second: 21117.3
# recommendations finished on 28000/138493 queries. users per second: 21156.8
# recommendations finished on 29000/138493 queries. users per second: 21147.4
# recommendations finished on 30000/138493 queries. users per second: 21138.7
# recommendations finished on 31000/138493 queries. users per second: 21073.3
# recommendations finished on 32000/138493 queries. users per second: 21067.5
# recommendations finished on 33000/138493 queries. users per second: 21048.6
# recommendations finished on 34000/138493 queries. users per second: 21030.9
# recommendations finished on 35000/138493 queries. users per second: 21001.7
# recommendations finished on 36000/138493 queries. users per second: 20974.1
# recommendations finished on 37000/138493 queries. users per second: 20924.5
# recommendations finished on 38000/138493 queries. users per second: 20843.5
# recommendations finished on 39000/138493 queries. users per second: 20811.4
# recommendations finished on 40000/138493 queries. users per second: 20770.2
# recommendations finished on 41000/138493 queries. users per second: 20689.4
# recommendations finished on 42000/138493 queries. users per second: 20633.3
# recommendations finished on 43000/138493 queries. users per second: 20599.7
# recommendations finished on 44000/138493 queries. users per second: 20615.9
# recommendations finished on 45000/138493 queries. users per second: 20565.5
# recommendations finished on 46000/138493 queries. users per second: 20563.2
# recommendations finished on 47000/138493 queries. users per second: 20552.1
# recommendations finished on 48000/138493 queries. users per second: 20550.2
# recommendations finished on 49000/138493 queries. users per second: 20471.4
# recommendations finished on 50000/138493 queries. users per second: 20429.5
# recommendations finished on 51000/138493 queries. users per second: 20381.3
# recommendations finished on 52000/138493 queries. users per second: 20351
# recommendations finished on 53000/138493 queries. users per second: 20314.2
# recommendations finished on 54000/138493 queries. users per second: 20286.5
# recommendations finished on 55000/138493 queries. users per second: 20282.2
# recommendations finished on 56000/138493 queries. users per second: 20270.8
# recommendations finished on 57000/138493 queries. users per second: 20252.6
# recommendations finished on 58000/138493 queries. users per second: 20192.9
# recommendations finished on 59000/138493 queries. users per second: 20135.5
# recommendations finished on 60000/138493 queries. users per second: 20147.6
# recommendations finished on 61000/138493 queries. users per second: 20159.4
# recommendations finished on 62000/138493 queries. users per second: 20177.3
# recommendations finished on 63000/138493 queries. users per second: 20214
# recommendations finished on 64000/138493 queries. users per second: 20256.2
# recommendations finished on 65000/138493 queries. users per second: 20284.5
# recommendations finished on 66000/138493 queries. users per second: 20324.6
# recommendations finished on 67000/138493 queries. users per second: 20363.6
# recommendations finished on 68000/138493 queries. users per second: 20389.4
# recommendations finished on 69000/138493 queries. users per second: 20402.5
# recommendations finished on 70000/138493 queries. users per second: 20391.5
# recommendations finished on 71000/138493 queries. users per second: 20380.8
# recommendations finished on 72000/138493 queries. users per second: 20382
# recommendations finished on 73000/138493 queries. users per second: 20383.1
# recommendations finished on 74000/138493 queries. users per second: 20395.4
# recommendations finished on 75000/138493 queries. users per second: 20385.2
# recommendations finished on 76000/138493 queries. users per second: 20391.7
# recommendations finished on 77000/138493 queries. users per second: 20387.2
# recommendations finished on 78000/138493 queries. users per second: 20398.8
# recommendations finished on 79000/138493 queries. users per second: 20389.1
# recommendations finished on 80000/138493 queries. users per second: 20390
# recommendations finished on 81000/138493 queries. users per second: 20390.9
# recommendations finished on 82000/138493 queries. users per second: 20396.9
# recommendations finished on 83000/138493 queries. users per second: 20392.7
# recommendations finished on 84000/138493 queries. users per second: 20378.7
# recommendations finished on 85000/138493 queries. users per second: 20374.8
# recommendations finished on 86000/138493 queries. users per second: 20366.2
# recommendations finished on 87000/138493 queries. users per second: 20372.1
# recommendations finished on 88000/138493 queries. users per second: 20368.4
# recommendations finished on 89000/138493 queries. users per second: 20341.6
# recommendations finished on 90000/138493 queries. users per second: 20320
# recommendations finished on 91000/138493 queries. users per second: 20303.5
# recommendations finished on 92000/138493 queries. users per second: 20300.7
# recommendations finished on 93000/138493 queries. users per second: 20280.4
# recommendations finished on 94000/138493 queries. users per second: 20273.6
# recommendations finished on 95000/138493 queries. users per second: 20266.9
# recommendations finished on 96000/138493 queries. users per second: 20269
# recommendations finished on 97000/138493 queries. users per second: 20266.7
# recommendations finished on 98000/138493 queries. users per second: 20268.7
# recommendations finished on 99000/138493 queries. users per second: 20266.5
# recommendations finished on 100000/138493 queries. users per second: 20268.5
# recommendations finished on 101000/138493 queries. users per second: 20270.4
# recommendations finished on 102000/138493 queries. users per second: 20260.2
# recommendations finished on 103000/138493 queries. users per second: 20242.3
# recommendations finished on 104000/138493 queries. users per second: 20232.6
# recommendations finished on 105000/138493 queries. users per second: 20227
# recommendations finished on 106000/138493 queries. users per second: 20225.3
# recommendations finished on 107000/138493 queries. users per second: 20227.5
# recommendations finished on 108000/138493 queries. users per second: 20229.7
# recommendations finished on 109000/138493 queries. users per second: 20228
# recommendations finished on 110000/138493 queries. users per second: 20226.5
# recommendations finished on 111000/138493 queries. users per second: 20228.6
# recommendations finished on 112000/138493 queries. users per second: 20230.6
# recommendations finished on 113000/138493 queries. users per second: 20232.7
# recommendations finished on 114000/138493 queries. users per second: 20234.7
# recommendations finished on 115000/138493 queries. users per second: 20233.1
# recommendations finished on 116000/138493 queries. users per second: 20235
# recommendations finished on 117000/138493 queries. users per second: 20226.5
# recommendations finished on 118000/138493 queries. users per second: 20225
# recommendations finished on 119000/138493 queries. users per second: 20227
# recommendations finished on 120000/138493 queries. users per second: 20222.1
# recommendations finished on 121000/138493 queries. users per second: 20224.1
# recommendations finished on 122000/138493 queries. users per second: 20226
# recommendations finished on 123000/138493 queries. users per second: 20221.3
# recommendations finished on 124000/138493 queries. users per second: 20226.5
# recommendations finished on 125000/138493 queries. users per second: 20228.4
# recommendations finished on 126000/138493 queries. users per second: 20230.2
# recommendations finished on 127000/138493 queries. users per second: 20238.5
# recommendations finished on 128000/138493 queries. users per second: 20243.4
# recommendations finished on 129000/138493 queries. users per second: 20245.1
# recommendations finished on 130000/138493 queries. users per second: 20240.4
# recommendations finished on 131000/138493 queries. users per second: 20226.5
# recommendations finished on 132000/138493 queries. users per second: 20203.6
# recommendations finished on 133000/138493 queries. users per second: 20196.4
# recommendations finished on 134000/138493 queries. users per second: 20189.2
# recommendations finished on 135000/138493 queries. users per second: 20161.1
# recommendations finished on 136000/138493 queries. users per second: 20109.8
# recommendations finished on 137000/138493 queries. users per second: 19969.1
# recommendations finished on 138000/138493 queries. users per second: 19502.4

# %%
results # the recommendation output
# Out:
# Columns:
# 	userId	int
# 	title	str
# 	score	float
# 	rank	int
#
# Rows: 692465
#
# Data:
# +--------+-------------------------------+-----------------+------+
# | userId |             title             |      score      | rank |
# +--------+-------------------------------+-----------------+------+
# |   3    | Men in Black (a.k.a. MIB) ... |  0.150093262846 |  1   |
# |   3    |      Pulp Fiction (1994)      |  0.132451495704 |  2   |
# |   3    | Indiana Jones and the Last... |  0.116173562838 |  3   |
# |   3    | Ghostbusters (a.k.a. Ghost... | 0.0855018442327 |  4   |
# |   3    | Star Trek: The Motion Pict... | 0.0738446208882 |  5   |
# |   6    |         Eraser (1996)         |  0.470481909811 |  1   |
# |   6    | Star Wars: Episode VI - Re... |  0.245952243606 |  2   |
# |   6    |      Broken Arrow (1996)      |  0.238403196136 |  3   |
# |   6    | Father of the Bride Part I... |  0.227094131211 |  4   |
# |   6    |   Back to the Future (1985)   |  0.214899217089 |  5   |
# +--------+-------------------------------+-----------------+------+
# [692465 rows x 4 columns]
# Note: Only the head of the SFrame is printed.
# You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.

# %% [markdown]
# In the above model creation, we have found the top five highest ranking items for each user. Two users are shown with their corresponding highest ranking items (that they have not rated).

# %% [markdown]
# <a href="#top">Back to Top</a>
# ### Modeling and Evaluation - Visualize Results<a id="Modeling_and_Evaluation_Visualize_Results"></a>
# * Use tables/visualization to discuss the found results. Explain each visualization in detail.

# %% [markdown]
# <a href="#top">Back to Top</a>
# ### Modeling and Evaluation - Summarize The Ramifications<a id="Modeling_and_Evaluation_Summarize_The_Ramifications"></a>
# * Describe your results. What findings are the most interesting and why?

# %% [markdown]
# 1. The model comparison results suggest that item_similarity recommender is a better fit for our dataset than ranking_factorization recommender.
#
# 2. Using item_similarity recommender, we were able to achieve a mean precision at least 30% with recommendation items up to 7 movies. We noticed that the mean precision is at 42% when giving just one movie recommendation.
#
# 3.

# %% [markdown]
# <a href="#top">Back to Top</a>
# ### Deployment<a id="Deployment"></a>
# * Be critical of your performance and tell the reader how you current model might be usable by other parties. Did you achieve your goals? If not, can you reign in the utility of your modeling?
#     - How useful is your model for interested parties (i.e., the companies or organizations that might want to use it)?
#     - How would your deploy your model for interested parties?
#     - What other data should be collected?
#     - How often would the model need to be updated, etc.?

# %% [markdown]
# <a href="#top">Back to Top</a>
# ### Exceptional Work<a id="Exceptional_Work"></a>

# %% [markdown]
# ## 1.  Creating a User-Item Matrices to find movies based on a single selection
# ### Using SVD (Singular-Value Decomposition) to reduce the matrix

# %% [markdown]
# #### Convert the Data to a User-Item Matrix

# %%
result1 = pd.read_csv("ml-20m/result1.csv")

# %%
#the original dataset is too big, more than 20 million entries, causing errors on running.
#so we had to randomly sample 1% entries for this demonstration. 
result2 = result1.sample(frac=0.001, random_state=1)
result2.shape
# Out:
# (20000, 3)

# %%
#import TruncatedSVD from sklearn
from sklearn.decomposition import TruncatedSVD

#convert the Data to a User-Item Matrix based on just the rating, userId and title data
#TruncatedSVD will not allow NULL so using the fill_value to produce 0 for the NULL
rating_pivot = result2.pivot_table(values='rating', index='userId', columns='title', fill_value=0)
#looking at the first 5 entries
rating_pivot.head()
# Out:
# title   'Hellboy': The Seeds of Creation (2004)  'burbs, The (1989)  \
# userId
# 11                                          0.0                 0.0
# 20                                          0.0                 0.0
# 22                                          0.0                 0.0
# 34                                          0.0                 0.0
# 54                                          0.0                 0.0
#
# title   (500) Days of Summer (2009)  *batteries not included (1987)  \
# userId
# 11                                0                             0.0
# 20                                0                             0.0
# 22                                0                             0.0
# 34                                0                             0.0
# 54                                0                             0.0
#
# title   ...All the Marbles (California Dolls, The) (1981)  \
# userId
# 11                                                    0.0
# 20                                                    0.0
# 22                                                    0.0
# 34                                                    0.0
# 54                                                    0.0
#
# title   ...And God Spoke (1993)  1-900 (06) (1994)  10 Items or Less (2006)  \
# userId
# 11                            0                  0                      0.0
# 20                            0                  0                      0.0
# 22                            0                  0                      0.0
# 34                            0                  0                      0.0
# 54                            0                  0                      0.0
#
# title   10 Things I Hate About You (1999)  10,000 BC (2008)  ...  Zoo (2007)  \
# userId                                                       ...
# 11                                    0.0                 0  ...           0
# 20                                    0.0                 0  ...           0
# 22                                    0.0                 0  ...           0
# 34                                    0.0                 0  ...           0
# 54                                    0.0                 0  ...           0
#
# title   Zoolander (2001)  Zorba the Greek (Alexis Zorbas) (1964)  Zulu (1964)  \
# userId
# 11                   0.0                                     0.0          0.0
# 20                   0.0                                     0.0          0.0
# 22                   0.0                                     0.0          0.0
# 34                   0.0                                     0.0          0.0
# 54                   0.0                                     0.0          0.0
#
# title   [REC] (2007)  a/k/a Tommy Chong (2005)  eXistenZ (1999)  xXx (2002)  \
# userId
# 11               0.0                       0.0              0.0         0.0
# 20               0.0                       0.0              0.0         0.0
# 22               0.0                       0.0              0.0         0.0
# 34               0.0                       0.0              0.0         0.0
# 54               0.0                       0.0              0.0         0.0
#
# title   xXx: State of the Union (2005)  ¡Three Amigos! (1986)
# userId
# 11                                   0                    0.0
# 20                                   0                    0.0
# 22                                   0                    0.0
# 34                                   0                    0.0
# 54                                   0                    0.0
#
# [5 rows x 4676 columns]

# %%
#looking at the shape of the matrix
rating_pivot.shape
# Out:
# (16399, 4676)

# %%
#transposing the rating_pivot using the T command
rating_transpose = rating_pivot.values.T

#check to see if things flipped
rating_transpose.shape
# Out:
# (4676L, 16399L)

# %% [markdown]
# #### Running SVD (Singular-Value Decomposition) to reduce the matrix

# %%
#using 12 components
rating_SVD = TruncatedSVD(n_components=12, random_state=42)
result_maxrix = rating_SVD.fit_transform(rating_transpose)
#looking at the shape of the smaller matrix
result_maxrix.shape
# Out:
# (4676L, 12L)

# %% [markdown]
# #### Create a Pearson's R Correlation for every movie
# We can use this to compare one movie to others that someone may like based on user preferences.

# %%
result_corr = np.corrcoef(result_maxrix)
#looking at the shape
result_corr.shape
# Out:
# (4676L, 4676L)

# %% [markdown]
# #### Test the system on one of our favorite movies: The Shawshank Redemption

# %%
# create a movie names index
movie_names = rating_pivot.columns
movie_list = list(movie_names)

#pull the index number of the movie you want to find similarities too
Shawshank = movie_list.index('Shawshank Redemption, The (1994)')
#print out the index of our movie
print(Shawshank)
# Out:
# 3758

# %% [markdown]
# #### Get the correlation result of our movie

# %%
corr_Shawshank = result_corr[Shawshank]
#This is shape of the Pearson's R Correlation for one movie.
#It shows 13390 results for this one movie. This is how it compares to all the others in the data set.
corr_Shawshank.shape
# Out:
# (4676L,)

# %% [markdown]
# #### Finding highly correlated movies

# %%
#finding some of the top correlated movies to ours
list(movie_names[(corr_Shawshank < 1.0) & (corr_Shawshank > 0.99)])
# Out:
# ['Big Chill, The (1983)',
#  'Bye Bye, Love (1995)',
#  'Dark Crystal, The (1982)',
#  'Departed, The (2006)',
#  'From Hell (2001)',
#  'Kicking and Screaming (1995)',
#  'Lives of Others, The (Das leben der Anderen) (2006)',
#  'Mariachi, El (1992)',
#  'Mary Poppins (1964)',
#  'My Life in Pink (Ma vie en rose) (1997)',
#  'Next (2007)',
#  'Peter Pan (1953)',
#  'Rambo (Rambo 4) (2008)',
#  'Young Guns II (1990)']

# %%
#finding the highest correlated movie to ours
list(movie_names[(corr_Shawshank < 1.0) & (corr_Shawshank > 0.9997)])
# Out:
# ['Big Chill, The (1983)',
#  'From Hell (2001)',
#  'Lives of Others, The (Das leben der Anderen) (2006)',
#  'Mary Poppins (1964)',
#  'My Life in Pink (Ma vie en rose) (1997)',
#  'Peter Pan (1953)',
#  'Rambo (Rambo 4) (2008)']

# %% [markdown]
# ### 2. Showing movie posters for all the movies in this 20M dataset

# %%
from matplotlib.pyplot import figure, imshow, axis
from matplotlib.image import imread


fig = figure(figsize=(24, 12))

for i in range (0,len(listId)):
    id = listId.values[i]
    filename='ml-20m/posters/'+str(id)+'.jpg'
    a=fig.add_subplot(1,len(listId),i+1)
    image = imread(filename)
    imshow(image)
    axis('off')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-8e2009f55cd0> in <module>()
#       5 fig = figure(figsize=(24, 12))
#       6
# ----> 7 for i in range (0,len(listId)):
#       8     id = listId.values[i]
#       9     filename='ml-20m/posters/'+str(id)+'.jpg'
#
# NameError: name 'listId' is not defined
